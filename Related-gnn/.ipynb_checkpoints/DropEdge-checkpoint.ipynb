# %%
import DeviceDir

DIR, RESULTS_DIR = DeviceDir.get_directory()
device, NUM_PROCESSORS = DeviceDir.get_device()

# %%
all_dataset = [
    "Cornell",
    "Texas",
    "Wisconsin",
    "reed98",
    "amherst41",
    "penn94",
    "Roman-empire",
    "cornell5",
    "Squirrel",
    "johnshopkins55",
    "Actor",
    "Minesweeper",
    "Questions",
    "Chameleon",
    "Tolokers",
    "Amazon-ratings",
    "genius",
    "pokec",
    "arxiv-year",
    "snap-patents",
    "ogbn-proteins",
    "Cora",
    "DBLP",
    "Computers",
    "PubMed",
    "Cora_ML",
    "SmallCora",
    "CS",
    "Photo",
    "Physics",
    "CiteSeer",
    "wiki",
    "Reddit"
]

# %%
from ipynb.fs.full.SGSLoadDataset import LOAD_DATASET

DATASET_NAME = "SmallCora"
# data, dataset  = LOAD_DATASET(DIR, DATASET_NAME)
# num_classes = max(data.y).item()+1

# %% [markdown]
# Early stoppings dot py

# %%
from __future__ import division
from __future__ import print_function
import time
import argparse
import numpy as np
import torch
import torch.nn.functional as F
import torch.optim as optim
from scipy.sparse import coo_matrix
from __future__ import division
from __future__ import print_function

import time
import argparse
import numpy as np

import torch
import torch.nn.functional as F
import torch.optim as optim
#from ipynb.fs.full.Dataset import get_data_from_dataset

# %%
#!/usr/bin/env python
# coding=utf-8
import numpy as np
import torch
import random,string
import datetime
import os

# TODO: hard coding the model path here.
folder = DIR+DATASET_NAME+"tmpmodel"
if not os.path.exists(folder):
    os.mkdir(folder)

class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""

    def __init__(self, datasets="tmp", patience=7, fname=None, clean=False, verbose=False):
        """ 
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
        """

        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        timstr = datetime.datetime.now().strftime("%m%d-%H%M%S")
        if fname is None:
            fname = datasets + "-" + timstr + "-" + self._random_str() + ".pt"
        self.fname = os.path.join(folder, fname)
        self.clean = clean
    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score:
            self.counter += 1
            if self.verbose:
                print("EarlyStopping counter: %d out of %d"%(self.counter, self.patience))
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def _random_str(self, randomlength=3):
        a = list(string.ascii_letters)
        random.shuffle(a)
        return ''.join(a[:randomlength])

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            print('Validation loss decreased (%.6f --> %.6f).  Saving model ...'%(self.val_loss_min, val_loss))
        torch.save(model.state_dict(), self.fname)
        self.val_loss_min = val_loss

    def load_checkpoint(self):
        return  torch.load(self.fname)

# %% [markdown]
# normalization .py file

# %%
import numpy as np
import scipy.sparse as sp

def normalized_laplacian(adj):
   adj = sp.coo_matrix(adj)
   row_sum = np.array(adj.sum(1))
   d_inv_sqrt = np.power(row_sum, -0.5).flatten()
   d_inv_sqrt[np.isinf(d_inv_sqrt)] = 0.
   d_mat_inv_sqrt = sp.diags(d_inv_sqrt)
   return (sp.eye(adj.shape[0]) - d_mat_inv_sqrt.dot(adj).dot(d_mat_inv_sqrt)).tocoo()


def laplacian(adj):
   adj = sp.coo_matrix(adj)
   row_sum = np.array(adj.sum(1)).flatten()
   d_mat = sp.diags(row_sum)
   return (d_mat - adj).tocoo()


def gcn(adj):
   adj = sp.coo_matrix(adj)
   row_sum = np.array(adj.sum(1))
   d_inv_sqrt = np.power(row_sum, -0.5).flatten()
   d_inv_sqrt[np.isinf(d_inv_sqrt)] = 0.
   d_mat_inv_sqrt = sp.diags(d_inv_sqrt)
   return (sp.eye(adj.shape[0]) + d_mat_inv_sqrt.dot(adj).dot(d_mat_inv_sqrt)).tocoo()


def aug_normalized_adjacency(adj):
   adj = adj + sp.eye(adj.shape[0])
   adj = sp.coo_matrix(adj)
   row_sum = np.array(adj.sum(1))
   d_inv_sqrt = np.power(row_sum, -0.5).flatten()
   d_inv_sqrt[np.isinf(d_inv_sqrt)] = 0.
   d_mat_inv_sqrt = sp.diags(d_inv_sqrt)
   return d_mat_inv_sqrt.dot(adj).dot(d_mat_inv_sqrt).tocoo()

def bingge_norm_adjacency(adj):
   adj = adj + sp.eye(adj.shape[0])
   adj = sp.coo_matrix(adj)
   row_sum = np.array(adj.sum(1))
   d_inv_sqrt = np.power(row_sum, -0.5).flatten()
   d_inv_sqrt[np.isinf(d_inv_sqrt)] = 0.
   d_mat_inv_sqrt = sp.diags(d_inv_sqrt)
   return (d_mat_inv_sqrt.dot(adj).dot(d_mat_inv_sqrt) +  sp.eye(adj.shape[0])).tocoo()

def normalized_adjacency(adj):
   adj = sp.coo_matrix(adj)
   row_sum = np.array(adj.sum(1))
   d_inv_sqrt = np.power(row_sum, -0.5).flatten()
   d_inv_sqrt[np.isinf(d_inv_sqrt)] = 0.
   d_mat_inv_sqrt = sp.diags(d_inv_sqrt)
   return (d_mat_inv_sqrt.dot(adj).dot(d_mat_inv_sqrt)).tocoo()

def random_walk_laplacian(adj):
   adj = sp.coo_matrix(adj)
   row_sum = np.array(adj.sum(1))
   d_inv = np.power(row_sum, -1.0).flatten()
   d_mat = sp.diags(d_inv)
   return (sp.eye(adj.shape[0]) - d_mat.dot(adj)).tocoo()


def aug_random_walk(adj):
   adj = adj + sp.eye(adj.shape[0])
   adj = sp.coo_matrix(adj)
   row_sum = np.array(adj.sum(1))
   d_inv = np.power(row_sum, -1.0).flatten()
   d_mat = sp.diags(d_inv)
   return (d_mat.dot(adj)).tocoo()

def random_walk(adj):
   adj = sp.coo_matrix(adj)
   row_sum = np.array(adj.sum(1))
   d_inv = np.power(row_sum, -1.0).flatten()
   d_mat = sp.diags(d_inv)
   return d_mat.dot(adj).tocoo()

def no_norm(adj):
   adj = sp.coo_matrix(adj)
   return adj


def i_norm(adj):
    adj = adj + sp.eye(adj.shape[0])
    adj = sp.coo_matrix(adj)
    return adj
  
def fetch_normalization(type):
   switcher = {
       'NormLap': normalized_laplacian,  # A' = I - D^-1/2 * A * D^-1/2
       'Lap': laplacian,  # A' = D - A
       'RWalkLap': random_walk_laplacian,  # A' = I - D^-1 * A
       'FirstOrderGCN': gcn,   # A' = I + D^-1/2 * A * D^-1/2
       'AugNormAdj': aug_normalized_adjacency,  # A' = (D + I)^-1/2 * ( A + I ) * (D + I)^-1/2
       'BingGeNormAdj': bingge_norm_adjacency, # A' = I + (D + I)^-1/2 * (A + I) * (D + I)^-1/2
       'NormAdj': normalized_adjacency,  # D^-1/2 * A * D^-1/2
       'RWalk': random_walk,  # A' = D^-1*A
       'AugRWalk': aug_random_walk,  # A' = (D + I)^-1*(A + I)
       'NoNorm': no_norm, # A' = A
       'INorm': i_norm,  # A' = A + I
   }
   func = switcher.get(type, lambda: "Invalid normalization technique.")
   return func

def row_normalize(mx):
    """Row-normalize sparse matrix"""
    rowsum = np.array(mx.sum(1))
    r_inv = np.power(rowsum, -1).flatten()
    r_inv[np.isinf(r_inv)] = 0.
    r_mat_inv = sp.diags(r_inv)
    mx = r_mat_inv.dot(mx)
    return mx

# %% [markdown]
# utils. py file

# %% [markdown]
# metric . py

# %%
import numpy as np
import scipy.sparse as sp
import torch
def encode_onehot(labels):
    classes = set(labels)
    classes_dict = {c: np.identity(len(classes))[i, :] for i, c in
                    enumerate(classes)}
    labels_onehot = np.array(list(map(classes_dict.get, labels)),
                             dtype=np.int32)
    return labels_onehot

def accuracy(output, labels):
    preds = output.max(1)[1].type_as(labels)
    correct = preds.eq(labels).double()
    correct = correct.sum()
    return correct / len(labels)

def roc_auc_compute_fn(y_preds, y_targets):
    try:
        from sklearn.metrics import roc_auc_score
    except ImportError:
        raise RuntimeError("This contrib module requires sklearn to be installed.")

    y_true = y_targets.cpu().numpy()
    y_true = encode_onehot(y_true)
    y_pred = y_preds.cpu().detach().numpy()
    return roc_auc_score(y_true, y_pred)

def prec_recall_n(output, labels, topn):
    preds = output.detach().numpy()[-1]
    pass

# %%
import pickle as pkl
import sys
import os
import networkx as nx
import numpy as np
import scipy.sparse as sp
import torch

datadir = "data"

def parse_index_file(filename):
    """Parse index file."""
    index = []
    for line in open(filename):
        index.append(int(line.strip()))
    return index

def preprocess_citation(adj, features, normalization="FirstOrderGCN"):
    adj_normalizer = fetch_normalization(normalization)
    adj = adj_normalizer(adj)
    features = row_normalize(features)
    return adj, features

def sparse_mx_to_torch_sparse_tensor(sparse_mx):
    """Convert a scipy sparse matrix to a torch sparse tensor."""
    sparse_mx = sparse_mx.tocoo().astype(np.float32)
    indices = torch.from_numpy(
        np.vstack((sparse_mx.row, sparse_mx.col)).astype(np.int64))
    values = torch.from_numpy(sparse_mx.data)
    shape = torch.Size(sparse_mx.shape)
    return torch.sparse.FloatTensor(indices, values, shape)


def load_citation(dataset_str="cora", normalization="AugNormAdj", porting_to_torch=True,data_path=datadir, task_type="full"):
    """
    Load Citation Networks Datasets.
    """
    names = ['x', 'y', 'tx', 'ty', 'allx', 'ally', 'graph']
    objects = []
    for i in range(len(names)):
        with open(os.path.join(data_path, "ind.{}.{}".format(dataset_str.lower(), names[i])), 'rb') as f:
            if sys.version_info > (3, 0):
                objects.append(pkl.load(f, encoding='latin1'))
            else:
                objects.append(pkl.load(f))

    x, y, tx, ty, allx, ally, graph = tuple(objects)
    test_idx_reorder = parse_index_file(os.path.join(data_path, "ind.{}.test.index".format(dataset_str)))
    test_idx_range = np.sort(test_idx_reorder)

    if dataset_str == 'citeseer':
        # Fix citeseer dataset (there are some isolated nodes in the graph)
        # Find isolated nodes, add them as zero-vecs into the right position
        test_idx_range_full = range(min(test_idx_reorder), max(test_idx_reorder)+1)
        tx_extended = sp.lil_matrix((len(test_idx_range_full), x.shape[1]))
        tx_extended[test_idx_range-min(test_idx_range), :] = tx
        tx = tx_extended
        ty_extended = np.zeros((len(test_idx_range_full), y.shape[1]))
        ty_extended[test_idx_range-min(test_idx_range), :] = ty
        ty = ty_extended

    features = sp.vstack((allx, tx)).tolil()
    features[test_idx_reorder, :] = features[test_idx_range, :]
    G = nx.from_dict_of_lists(graph)
    adj = nx.adjacency_matrix(G)
    adj = adj + adj.T.multiply(adj.T > adj) - adj.multiply(adj.T > adj)
    # degree = np.asarray(G.degree)
    degree = np.sum(adj, axis=1)

    labels = np.vstack((ally, ty))
    labels[test_idx_reorder, :] = labels[test_idx_range, :]
    
    if task_type == "full":
        print("Load full supervised task.")
        #supervised setting
        idx_test = test_idx_range.tolist()
        idx_train = range(len(ally)- 500)
        idx_val = range(len(ally) - 500, len(ally))
    elif task_type == "semi":
        print("Load semi-supervised task.")
        #semi-supervised setting
        idx_test = test_idx_range.tolist()
        idx_train = range(len(y))
        idx_val = range(len(y), len(y)+500)
    else:
        raise ValueError("Task type: %s is not supported. Available option: full and semi.")

    adj, features = preprocess_citation(adj, features, normalization)
    features = np.array(features.todense())
    labels = np.argmax(labels, axis=1)
    print(porting_to_torch)
    # porting to pytorch
    if porting_to_torch:
        print("HELLLO WORLDLLLDLSD")
        features = torch.FloatTensor(features).float()
        labels = torch.LongTensor(labels)
        # labels = torch.max(labels, dim=1)[1]
        adj = sparse_mx_to_torch_sparse_tensor(adj).float()
        idx_train = torch.LongTensor(idx_train)
        idx_val = torch.LongTensor(idx_val)
        idx_test = torch.LongTensor(idx_test)
        degree = torch.LongTensor(degree)
    learning_type = "transductive"
    return adj, features, labels, idx_train, idx_val, idx_test, degree, learning_type

def sgc_precompute(features, adj, degree):
    #t = perf_counter()
    for i in range(degree):
        features = torch.spmm(adj, features)
    precompute_time = 0 #perf_counter()-t
    return features, precompute_time

def set_seed(seed, cuda):
    np.random.seed(seed)
    torch.manual_seed(seed)
    if cuda: torch.cuda.manual_seed(seed)


def loadRedditFromNPZ(dataset_dir=datadir):
    adj = sp.load_npz(dataset_dir+"reddit_adj.npz")
    data = np.load(dataset_dir +"reddit.npz")

    return adj, data['feats'], data['y_train'], data['y_val'], data['y_test'], data['train_index'], data['val_index'], data['test_index']


def load_reddit_data(normalization="AugNormAdj", porting_to_torch=True, data_path=datadir):
    adj, features, y_train, y_val, y_test, train_index, val_index, test_index = loadRedditFromNPZ(data_path)
    labels = np.zeros(adj.shape[0])
    labels[train_index]  = y_train
    labels[val_index]  = y_val
    labels[test_index]  = y_test
    adj = adj + adj.T + sp.eye(adj.shape[0])
    train_adj = adj[train_index, :][:, train_index]
    degree = np.sum(train_adj, axis=1)

    features = torch.FloatTensor(np.array(features))
    features = (features-features.mean(dim=0))/features.std(dim=0)
    train_features = torch.index_select(features, 0, torch.LongTensor(train_index))
    if not porting_to_torch:
        features = features.numpy()
        train_features = train_features.numpy()

    adj_normalizer = fetch_normalization(normalization)
    adj = adj_normalizer(adj)
    train_adj = adj_normalizer(train_adj)

    if porting_to_torch:
        train_adj = sparse_mx_to_torch_sparse_tensor(train_adj).float()
        labels = torch.LongTensor(labels)
        adj = sparse_mx_to_torch_sparse_tensor(adj).float()
        degree = torch.LongTensor(degree)
        train_index = torch.LongTensor(train_index)
        val_index = torch.LongTensor(val_index)
        test_index = torch.LongTensor(test_index)
    learning_type = "inductive"
    return adj, train_adj, features, train_features, labels, train_index, val_index, test_index, degree, learning_type

def data_loader(dataset, data_path=datadir, normalization="AugNormAdj", porting_to_torch=True, task_type = "full"):
    if dataset == "reddit":
        return load_reddit_data(normalization, porting_to_torch, data_path)
    else:
        data, dataset = LOAD_DATASET(DIR, dataset)
        # Extract features and adjacency matrix
        features = data.x  # Features of nodes
        train_features = features
        edge_index = data.edge_index  # Edge list (PyTorch Geometric format)
        num_nodes = edge_index.max().item() + 1

        # Create adjacency matrix (COO format)
        values = torch.ones(edge_index.size(1), dtype=torch.float32)  # All edges have weight 1
        row = edge_index[0].numpy()
        col = edge_index[1].numpy()
        adj = coo_matrix((values.numpy(), (row, col)), shape=(num_nodes, num_nodes))
        train_adj = adj

        # Degree of nodes
        degree = np.array(adj.sum(axis=1)).flatten()

        # Labels
        labels = data.y.cpu().numpy()
        
        idx_train = torch.nonzero(data.train_mask).squeeze().tolist()
        idx_val = torch.nonzero(data.val_mask).squeeze().tolist()
        idx_test = torch.nonzero(data.test_mask).squeeze().tolist()

#         # Train/Validation/Test split
#         if task_type == "full":
#             print("Load full supervised task.")
#             idx_train = range(len(labels) - 500)
#             idx_val = range(len(labels) - 500, len(labels))
#             idx_test = range(len(labels))
#         elif task_type == "semi":
#             print("Load semi-supervised task.")
#             idx_train = range(len(labels) - 1000)
#             idx_val = range(len(labels) - 500, len(labels))
#             idx_test = range(len(labels))
#         else:
#             raise ValueError("Task type: %s is not supported. Available options: full and semi." % task_type)
        
        print(idx_train)
        
        # Normalize adjacency matrix and features (optional, mimic `preprocess_citation`)
        if normalization == "AugNormAdj":
            adj = adj + coo_matrix(np.eye(adj.shape[0]))
            degree = np.array(adj.sum(axis=1)).flatten()
            degree = np.maximum(degree, 1)
            d_inv_sqrt = np.power(degree, -0.5).flatten()
            d_mat_inv_sqrt = coo_matrix(np.diag(d_inv_sqrt))
            adj = d_mat_inv_sqrt @ adj @ d_mat_inv_sqrt

        features = features.numpy()

        # Convert labels to integer class indices if not already
        if labels.ndim > 1:
            labels = np.argmax(labels, axis=1)
        learning_type = "transductive"
    # else:
    #     (adj,
    #      features,
    #      labels,
    #      idx_train,
    #      idx_val,
    #      idx_test,
    #      degree,
    #      learning_type) = load_citation(dataset, normalization, porting_to_torch, data_path, task_type)
    #     train_adj = adj
    #     train_features = features

        return adj, train_adj, features, train_features, labels, idx_train, idx_val, idx_test, degree, learning_type

# %%
# 
# import torch

# data, dataset = get_data_from_dataset('Cora')  #feature = data.x , train_feature = data.x, adj = adj, train_adj = adj #labels_ = data.y.cpu().numpy() degree = np.sum(adj, axis=1)
# feature = data.x 
# train_feature = data.x 

# edge_index = data.edge_index
# num_nodes = edge_index.max().item() + 1
# values = torch.ones(edge_index.size(1), dtype=torch.float32)
# row = edge_index[0].numpy()
# col = edge_index[1].numpy()
# adj = coo_matrix((values.numpy(), (row, col)), shape=(num_nodes, num_nodes))
# train_adj = adj 
# labels_ = data.y.cpu().numpy()



# dataset_name = 'Cora'
# task_type = 'full'
# normalization = 'AugNormAdj'
# porting_to_torch = False 

# data, dataset = get_data_from_dataset(dataset_name)

# # Extract features and adjacency matrix
# features = data.x  # Features of nodes
# edge_index = data.edge_index  # Edge list (PyTorch Geometric format)
# num_nodes = edge_index.max().item() + 1

# # Create adjacency matrix (COO format)
# values = torch.ones(edge_index.size(1), dtype=torch.float32)  # All edges have weight 1
# row = edge_index[0].numpy()
# col = edge_index[1].numpy()
# adj = coo_matrix((values.numpy(), (row, col)), shape=(num_nodes, num_nodes))

# # Degree of nodes
# degree = np.array(adj.sum(axis=1)).flatten()

# # Labels
# labels = data.y.cpu().numpy()

# # Train/Validation/Test split
# if task_type == "full":
#     print("Load full supervised task.")
#     idx_train = range(len(labels) - 500)
#     idx_val = range(len(labels) - 500, len(labels))
#     idx_test = range(len(labels))
# elif task_type == "semi":
#     print("Load semi-supervised task.")
#     idx_train = range(len(labels) - 1000)
#     idx_val = range(len(labels) - 500, len(labels))
#     idx_test = range(len(labels))
# else:
#     raise ValueError("Task type: %s is not supported. Available options: full and semi." % task_type)

# # Normalize adjacency matrix and features (optional, mimic `preprocess_citation`)
# if normalization == "AugNormAdj":
#     adj = adj + coo_matrix(np.eye(adj.shape[0]))
#     degree = np.array(adj.sum(axis=1)).flatten()
#     degree = np.maximum(degree, 1)
#     d_inv_sqrt = np.power(degree, -0.5).flatten()
#     d_mat_inv_sqrt = coo_matrix(np.diag(d_inv_sqrt))
#     adj = d_mat_inv_sqrt @ adj @ d_mat_inv_sqrt

# features = features.numpy()

# # Convert labels to integer class indices if not already
# if labels.ndim > 1:
#     labels = np.argmax(labels, axis=1)
# learning_type = "transductive"

# %% [markdown]
# Sample . py

# %%
# coding=utf-8
import numpy as np
import torch
import scipy.sparse as sp

class Sampler:
    """Sampling the input graph data."""
    def __init__(self, dataset, data_path="data", task_type="full"):
        self.dataset = dataset
        self.data_path = data_path
        (self.adj,
         self.train_adj,
         self.features,
         self.train_features,
         self.labels,
         self.idx_train, 
         self.idx_val,
         self.idx_test, 
         self.degree,
         self.learning_type) = data_loader(dataset, data_path, "NoNorm", False, task_type)
        
        #convert some data to torch tensor ---- may be not the best practice here.
        self.features = torch.FloatTensor(self.features).float()
        self.train_features = torch.FloatTensor(self.train_features).float()
        # self.train_adj = self.train_adj.tocsr()

        self.labels_torch = torch.LongTensor(self.labels)
        self.idx_train_torch = torch.LongTensor(self.idx_train)
        self.idx_val_torch = torch.LongTensor(self.idx_val)
        self.idx_test_torch = torch.LongTensor(self.idx_test)

        # vertex_sampler cache
        # where return a tuple
        self.pos_train_idx = np.where(self.labels[self.idx_train] == 1)[0]
        self.neg_train_idx = np.where(self.labels[self.idx_train] == 0)[0]
        # self.pos_train_neighbor_idx = np.where
        
        self.nfeat = self.features.shape[1]
        self.nclass = int(self.labels.max().item() + 1)
        self.trainadj_cache = {}
        self.adj_cache = {}
        #print(type(self.train_adj))
        self.degree_p = None

    def _preprocess_adj(self, normalization, adj, cuda):
        adj_normalizer = fetch_normalization(normalization)
        r_adj = adj_normalizer(adj)
        r_adj = sparse_mx_to_torch_sparse_tensor(r_adj).float()
        if cuda:
            r_adj = r_adj.cuda()
        return r_adj

    def _preprocess_fea(self, fea, cuda):
        if cuda:
            return fea.cuda()
        else:
            return fea

    def stub_sampler(self, normalization, cuda):
        """
        The stub sampler. Return the original data. 
        """
        if normalization in self.trainadj_cache:
            r_adj = self.trainadj_cache[normalization]
        else:
            r_adj = self._preprocess_adj(normalization, self.train_adj, cuda)
            self.trainadj_cache[normalization] = r_adj
        fea = self._preprocess_fea(self.train_features, cuda)
        return r_adj, fea

    def randomedge_sampler(self, percent, normalization, cuda):
        """
        Randomly drop edge and preserve percent% edges.
        """
        "Opt here"
        if percent >= 1.0:
            return self.stub_sampler(normalization, cuda)
        
        nnz = self.train_adj.nnz
        perm = np.random.permutation(nnz)
        preserve_nnz = int(nnz*percent)
        perm = perm[:preserve_nnz]
        r_adj = sp.coo_matrix((self.train_adj.data[perm],
                               (self.train_adj.row[perm],
                                self.train_adj.col[perm])),
                              shape=self.train_adj.shape)
        r_adj = self._preprocess_adj(normalization, r_adj, cuda)
        fea = self._preprocess_fea(self.train_features, cuda)
        return r_adj, fea

    def vertex_sampler(self, percent, normalization, cuda):
        """
        Randomly drop vertexes.
        """
        if percent >= 1.0:
            return self.stub_sampler(normalization, cuda)
        self.learning_type = "inductive"
        pos_nnz = len(self.pos_train_idx)
        # neg_neighbor_nnz = 0.4 * percent
        neg_no_neighbor_nnz = len(self.neg_train_idx)
        pos_perm = np.random.permutation(pos_nnz)
        neg_perm = np.random.permutation(neg_no_neighbor_nnz)
        pos_perseve_nnz = int(0.9 * percent * pos_nnz)
        neg_perseve_nnz = int(0.1 * percent * neg_no_neighbor_nnz)
        # print(pos_perseve_nnz)
        # print(neg_perseve_nnz)
        pos_samples = self.pos_train_idx[pos_perm[:pos_perseve_nnz]]
        neg_samples = self.neg_train_idx[neg_perm[:neg_perseve_nnz]]
        all_samples = np.concatenate((pos_samples, neg_samples))
        r_adj = self.train_adj
        r_adj = r_adj[all_samples, :]
        r_adj = r_adj[:, all_samples]
        r_fea = self.train_features[all_samples, :]
        # print(r_fea.shape)
        # print(r_adj.shape)
        # print(len(all_samples))
        r_adj = self._preprocess_adj(normalization, r_adj, cuda)
        r_fea = self._preprocess_fea(r_fea, cuda)
        return r_adj, r_fea, all_samples

    def degree_sampler(self, percent, normalization, cuda):
        """
        Randomly drop edge wrt degree (high degree, low probility).
        """
        if percent >= 0:
            return self.stub_sampler(normalization, cuda)
        if self.degree_p is None:
            degree_adj = self.train_adj.multiply(self.degree)
            self.degree_p = degree_adj.data / (1.0 * np.sum(degree_adj.data))
        # degree_adj = degree_adj.multi degree_adj.sum()
        nnz = self.train_adj.nnz
        preserve_nnz = int(nnz * percent)
        perm = np.random.choice(nnz, preserve_nnz, replace=False, p=self.degree_p)
        r_adj = sp.coo_matrix((self.train_adj.data[perm],
                               (self.train_adj.row[perm],
                                self.train_adj.col[perm])),
                              shape=self.train_adj.shape)
        r_adj = self._preprocess_adj(normalization, r_adj, cuda)
        fea = self._preprocess_fea(self.train_features, cuda)
        return r_adj, fea


    def get_test_set(self, normalization, cuda):
        """
        Return the test set. 
        """
        if self.learning_type == "transductive":
            return self.stub_sampler(normalization, cuda)
        else:
            if normalization in self.adj_cache:
                r_adj = self.adj_cache[normalization]
            else:
                r_adj = self._preprocess_adj(normalization, self.adj, cuda)
                self.adj_cache[normalization] = r_adj
            fea = self._preprocess_fea(self.features, cuda)
            return r_adj, fea

    def get_val_set(self, normalization, cuda):
        """
        Return the validataion set. Only for the inductive task.
        Currently behave the same with get_test_set
        """
        return self.get_test_set(normalization, cuda)

    def get_label_and_idxes(self, cuda):
        """
        Return all labels and indexes.
        """
        if cuda:
            return self.labels_torch.cuda(), self.idx_train_torch.cuda(), self.idx_val_torch.cuda(), self.idx_test_torch.cuda()
        return self.labels_torch, self.idx_train_torch, self.idx_val_torch, self.idx_test_torch

# %% [markdown]
# layers . py

# %%
import math
import torch
from torch.nn.parameter import Parameter
from torch.nn.modules.module import Module
from torch import nn
import torch.nn.functional as F

device = torch.device("cuda:0")

class GraphConvolutionBS(Module):
    """
    GCN Layer with BN, Self-loop and Res connection.
    """

    def __init__(self, in_features, out_features, activation=lambda x: x, withbn=True, withloop=True, bias=True,
                 res=False):
        """
        Initial function.
        :param in_features: the input feature dimension.
        :param out_features: the output feature dimension.
        :param activation: the activation function.
        :param withbn: using batch normalization.
        :param withloop: using self feature modeling.
        :param bias: enable bias.
        :param res: enable res connections.
        """
        super(GraphConvolutionBS, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.sigma = activation
        self.res = res

        # Parameter setting.
        self.weight = Parameter(torch.FloatTensor(in_features, out_features))
        # Is this the best practice or not?
        if withloop:
            self.self_weight = Parameter(torch.FloatTensor(in_features, out_features))
        else:
            self.register_parameter("self_weight", None)

        if withbn:
            self.bn = torch.nn.BatchNorm1d(out_features)
        else:
            self.register_parameter("bn", None)

        if bias:
            self.bias = Parameter(torch.FloatTensor(out_features))
        else:
            self.register_parameter('bias', None)

        self.reset_parameters()

    def reset_parameters(self):
        stdv = 1. / math.sqrt(self.weight.size(1))
        self.weight.data.uniform_(-stdv, stdv)
        if self.self_weight is not None:
            stdv = 1. / math.sqrt(self.self_weight.size(1))
            self.self_weight.data.uniform_(-stdv, stdv)
        if self.bias is not None:
            self.bias.data.uniform_(-stdv, stdv)

    def forward(self, input, adj):
        support = torch.mm(input, self.weight)
        output = torch.spmm(adj, support)

        # Self-loop
        if self.self_weight is not None:
            output = output + torch.mm(input, self.self_weight)

        if self.bias is not None:
            output = output + self.bias
        # BN
        if self.bn is not None:
            output = self.bn(output)
        # Res
        if self.res:
            return self.sigma(output) + input
        else:
            return self.sigma(output)

    def __repr__(self):
        return self.__class__.__name__ + ' (' \
               + str(self.in_features) + ' -> ' \
               + str(self.out_features) + ')'

class GraphBaseBlock(Module):
    """
    The base block for Multi-layer GCN / ResGCN / Dense GCN 
    """

    def __init__(self, in_features, out_features, nbaselayer,
                 withbn=True, withloop=True, activation=F.relu, dropout=True,
                 aggrmethod="concat", dense=False):
        """
        The base block for constructing DeepGCN model.
        :param in_features: the input feature dimension.
        :param out_features: the hidden feature dimension.
        :param nbaselayer: the number of layers in the base block.
        :param withbn: using batch normalization in graph convolution.
        :param withloop: using self feature modeling in graph convolution.
        :param activation: the activation function, default is ReLu.
        :param dropout: the dropout ratio.
        :param aggrmethod: the aggregation function for baseblock, can be "concat" and "add". For "resgcn", the default
                           is "add", for others the default is "concat".
        :param dense: enable dense connection
        """
        super(GraphBaseBlock, self).__init__()
        self.in_features = in_features
        self.hiddendim = out_features
        self.nhiddenlayer = nbaselayer
        self.activation = activation
        self.aggrmethod = aggrmethod
        self.dense = dense
        self.dropout = dropout
        self.withbn = withbn
        self.withloop = withloop
        self.hiddenlayers = nn.ModuleList()
        self.__makehidden()

        if self.aggrmethod == "concat" and dense == False:
            self.out_features = in_features + out_features
        elif self.aggrmethod == "concat" and dense == True:
            self.out_features = in_features + out_features * nbaselayer
        elif self.aggrmethod == "add":
            if in_features != self.hiddendim:
                raise RuntimeError("The dimension of in_features and hiddendim should be matched in add model.")
            self.out_features = out_features
        elif self.aggrmethod == "nores":
            self.out_features = out_features
        else:
            raise NotImplementedError("The aggregation method only support 'concat','add' and 'nores'.")

    def __makehidden(self):
        # for i in xrange(self.nhiddenlayer):
        for i in range(self.nhiddenlayer):
            if i == 0:
                layer = GraphConvolutionBS(self.in_features, self.hiddendim, self.activation, self.withbn,
                                           self.withloop)
            else:
                layer = GraphConvolutionBS(self.hiddendim, self.hiddendim, self.activation, self.withbn, self.withloop)
            self.hiddenlayers.append(layer)

    def _doconcat(self, x, subx):
        if x is None:
            return subx
        if self.aggrmethod == "concat":
            return torch.cat((x, subx), 1)
        elif self.aggrmethod == "add":
            return x + subx
        elif self.aggrmethod == "nores":
            return x

    def forward(self, input, adj):
        x = input
        denseout = None
        # Here out is the result in all levels.
        for gc in self.hiddenlayers:
            denseout = self._doconcat(denseout, x)
            x = gc(x, adj)
            x = F.dropout(x, self.dropout, training=self.training)

        if not self.dense:
            return self._doconcat(x, input)
        return self._doconcat(x, denseout)

    def get_outdim(self):
        return self.out_features

    def __repr__(self):
        return "%s %s (%d - [%d:%d] > %d)" % (self.__class__.__name__,
                                              self.aggrmethod,
                                              self.in_features,
                                              self.hiddendim,
                                              self.nhiddenlayer,
                                              self.out_features)

class MultiLayerGCNBlock(Module):
    """
    Muti-Layer GCN with same hidden dimension.
    """

    def __init__(self, in_features, out_features, nbaselayer,
                 withbn=True, withloop=True, activation=F.relu, dropout=True,
                 aggrmethod=None, dense=None):
        """
        The multiple layer GCN block.
        :param in_features: the input feature dimension.
        :param out_features: the hidden feature dimension.
        :param nbaselayer: the number of layers in the base block.
        :param withbn: using batch normalization in graph convolution.
        :param withloop: using self feature modeling in graph convolution.
        :param activation: the activation function, default is ReLu.
        :param dropout: the dropout ratio.
        :param aggrmethod: not applied.
        :param dense: not applied.
        """
        super(MultiLayerGCNBlock, self).__init__()
        self.model = GraphBaseBlock(in_features=in_features,
                                    out_features=out_features,
                                    nbaselayer=nbaselayer,
                                    withbn=withbn,
                                    withloop=withloop,
                                    activation=activation,
                                    dropout=dropout,
                                    dense=False,
                                    aggrmethod="nores")

    def forward(self, input, adj):
        return self.model.forward(input, adj)

    def get_outdim(self):
        return self.model.get_outdim()

    def __repr__(self):
        return "%s %s (%d - [%d:%d] > %d)" % (self.__class__.__name__,
                                              self.aggrmethod,
                                              self.model.in_features,
                                              self.model.hiddendim,
                                              self.model.nhiddenlayer,
                                              self.model.out_features)

class ResGCNBlock(Module):
    """
    The multiple layer GCN with residual connection block.
    """

    def __init__(self, in_features, out_features, nbaselayer,
                 withbn=True, withloop=True, activation=F.relu, dropout=True,
                 aggrmethod=None, dense=None):
        """
        The multiple layer GCN with residual connection block.
        :param in_features: the input feature dimension.
        :param out_features: the hidden feature dimension.
        :param nbaselayer: the number of layers in the base block.
        :param withbn: using batch normalization in graph convolution.
        :param withloop: using self feature modeling in graph convolution.
        :param activation: the activation function, default is ReLu.
        :param dropout: the dropout ratio.
        :param aggrmethod: not applied.
        :param dense: not applied.
        """
        super(ResGCNBlock, self).__init__()
        self.model = GraphBaseBlock(in_features=in_features,
                                    out_features=out_features,
                                    nbaselayer=nbaselayer,
                                    withbn=withbn,
                                    withloop=withloop,
                                    activation=activation,
                                    dropout=dropout,
                                    dense=False,
                                    aggrmethod="add")

    def forward(self, input, adj):
        return self.model.forward(input, adj)

    def get_outdim(self):
        return self.model.get_outdim()

    def __repr__(self):
        return "%s %s (%d - [%d:%d] > %d)" % (self.__class__.__name__,
                                              self.aggrmethod,
                                              self.model.in_features,
                                              self.model.hiddendim,
                                              self.model.nhiddenlayer,
                                              self.model.out_features)

class DenseGCNBlock(Module):
    """
    The multiple layer GCN with dense connection block.
    """

    def __init__(self, in_features, out_features, nbaselayer,
                 withbn=True, withloop=True, activation=F.relu, dropout=True,
                 aggrmethod="concat", dense=True):
        """
        The multiple layer GCN with dense connection block.
        :param in_features: the input feature dimension.
        :param out_features: the hidden feature dimension.
        :param nbaselayer: the number of layers in the base block.
        :param withbn: using batch normalization in graph convolution.
        :param withloop: using self feature modeling in graph convolution.
        :param activation: the activation function, default is ReLu.
        :param dropout: the dropout ratio.
        :param aggrmethod: the aggregation function for the output. For denseblock, default is "concat".
        :param dense: default is True, cannot be changed.
        """
        super(DenseGCNBlock, self).__init__()
        self.model = GraphBaseBlock(in_features=in_features,
                                    out_features=out_features,
                                    nbaselayer=nbaselayer,
                                    withbn=withbn,
                                    withloop=withloop,
                                    activation=activation,
                                    dropout=dropout,
                                    dense=True,
                                    aggrmethod=aggrmethod)

    def forward(self, input, adj):
        return self.model.forward(input, adj)

    def get_outdim(self):
        return self.model.get_outdim()

    def __repr__(self):
        return "%s %s (%d - [%d:%d] > %d)" % (self.__class__.__name__,
                                              self.aggrmethod,
                                              self.model.in_features,
                                              self.model.hiddendim,
                                              self.model.nhiddenlayer,
                                              self.model.out_features)

class InecptionGCNBlock(Module):
    """
    The multiple layer GCN with inception connection block.
    """

    def __init__(self, in_features, out_features, nbaselayer,
                 withbn=True, withloop=True, activation=F.relu, dropout=True,
                 aggrmethod="concat", dense=False):
        """
        The multiple layer GCN with inception connection block.
        :param in_features: the input feature dimension.
        :param out_features: the hidden feature dimension.
        :param nbaselayer: the number of layers in the base block.
        :param withbn: using batch normalization in graph convolution.
        :param withloop: using self feature modeling in graph convolution.
        :param activation: the activation function, default is ReLu.
        :param dropout: the dropout ratio.
        :param aggrmethod: the aggregation function for baseblock, can be "concat" and "add". For "resgcn", the default
                           is "add", for others the default is "concat".
        :param dense: not applied. The default is False, cannot be changed.
        """
        super(InecptionGCNBlock, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.hiddendim = out_features
        self.nbaselayer = nbaselayer
        self.activation = activation
        self.aggrmethod = aggrmethod
        self.dropout = dropout
        self.withbn = withbn
        self.withloop = withloop
        self.midlayers = nn.ModuleList()
        self.__makehidden()

        if self.aggrmethod == "concat":
            self.out_features = in_features + out_features * nbaselayer
        elif self.aggrmethod == "add":
            if in_features != self.hiddendim:
                raise RuntimeError("The dimension of in_features and hiddendim should be matched in 'add' model.")
            self.out_features = out_features
        else:
            raise NotImplementedError("The aggregation method only support 'concat', 'add'.")

    def __makehidden(self):
        # for j in xrange(self.nhiddenlayer):
        for j in range(self.nbaselayer):
            reslayer = nn.ModuleList()
            # for i in xrange(j + 1):
            for i in range(j + 1):
                if i == 0:
                    layer = GraphConvolutionBS(self.in_features, self.hiddendim, self.activation, self.withbn,
                                               self.withloop)
                else:
                    layer = GraphConvolutionBS(self.hiddendim, self.hiddendim, self.activation, self.withbn,
                                               self.withloop)
                reslayer.append(layer)
            self.midlayers.append(reslayer)

    def forward(self, input, adj):
        x = input
        for reslayer in self.midlayers:
            subx = input
            for gc in reslayer:
                subx = gc(subx, adj)
                subx = F.dropout(subx, self.dropout, training=self.training)
            x = self._doconcat(x, subx)
        return x

    def get_outdim(self):
        return self.out_features

    def _doconcat(self, x, subx):
        if self.aggrmethod == "concat":
            return torch.cat((x, subx), 1)
        elif self.aggrmethod == "add":
            return x + subx

    def __repr__(self):
        return "%s %s (%d - [%d:%d] > %d)" % (self.__class__.__name__,
                                              self.aggrmethod,
                                              self.in_features,
                                              self.hiddendim,
                                              self.nbaselayer,
                                              self.out_features)

class Dense(Module):


    """
    Simple Dense layer, Do not consider adj.
    """

    def __init__(self, in_features, out_features, activation=lambda x: x, bias=True, res=False):
        super(Dense, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.sigma = activation
        self.weight = Parameter(torch.FloatTensor(in_features, out_features))
        self.res = res
        self.bn = nn.BatchNorm1d(out_features)
        if bias:
            self.bias = Parameter(torch.FloatTensor(out_features))
        else:
            self.register_parameter('bias', None)
        self.reset_parameters()

    def reset_parameters(self):
        stdv = 1. / math.sqrt(self.weight.size(1))
        self.weight.data.uniform_(-stdv, stdv)
        if self.bias is not None:
            self.bias.data.uniform_(-stdv, stdv)

    def forward(self, input, adj):
        output = torch.mm(input, self.weight)
        if self.bias is not None:
            output = output + self.bias
        output = self.bn(output)
        return self.sigma(output)

    def __repr__(self):
        return self.__class__.__name__ + ' (' \
               + str(self.in_features) + ' -> ' \
               + str(self.out_features) + ')'

class GCNModel(nn.Module):
    def __init__(self,
                 nfeat,
                 nhid,
                 nclass,
                 nhidlayer,
                 dropout,
                 baseblock="mutigcn",
                 inputlayer="gcn",
                 outputlayer="gcn",
                 nbaselayer=0,
                 activation=lambda x: x,
                 withbn=True,
                 withloop=True,
                 aggrmethod="add",
                 mixmode=False):
 
        super(GCNModel, self).__init__()
        self.mixmode = mixmode
        self.dropout = dropout

        if baseblock == "resgcn":
            self.BASEBLOCK = ResGCNBlock
        elif baseblock == "densegcn":
            self.BASEBLOCK = DenseGCNBlock
        elif baseblock == "mutigcn":
            self.BASEBLOCK = MultiLayerGCNBlock
        elif baseblock == "inceptiongcn":
            self.BASEBLOCK = InecptionGCNBlock
        else:
            raise NotImplementedError("Current baseblock %s is not supported." % (baseblock))
        if inputlayer == "gcn":
            # input gc
            self.ingc = GraphConvolutionBS(nfeat, nhid, activation, withbn, withloop)
            baseblockinput = nhid
        elif inputlayer == "none":
            self.ingc = lambda x: x
            baseblockinput = nfeat
        else:
            self.ingc = Dense(nfeat, nhid, activation)
            baseblockinput = nhid

        outactivation = lambda x: x
        if outputlayer == "gcn":
            self.outgc = GraphConvolutionBS(baseblockinput, nclass, outactivation, withbn, withloop)
        # elif outputlayer ==  "none": #here can not be none
        #    self.outgc = lambda x: x 
        else:
            self.outgc = Dense(nhid, nclass, activation)

        # hidden layer
        self.midlayer = nn.ModuleList()

        for i in range(nhidlayer):
            gcb = self.BASEBLOCK(in_features=baseblockinput,
                                 out_features=nhid,
                                 nbaselayer=nbaselayer,
                                 withbn=withbn,
                                 withloop=withloop,
                                 activation=activation,
                                 dropout=dropout,
                                 dense=False,
                                 aggrmethod=aggrmethod)
            self.midlayer.append(gcb)
            baseblockinput = gcb.get_outdim()
        # output gc
        outactivation = lambda x: x  # we donot need nonlinear activation here.
        self.outgc = GraphConvolutionBS(baseblockinput, nclass, outactivation, withbn, withloop)

        self.reset_parameters()
        if mixmode:
            self.midlayer = self.midlayer.to(device)
            self.outgc = self.outgc.to(device)

    def reset_parameters(self):
        pass

    def forward(self, fea, adj):
        # input
        if self.mixmode:
            x = self.ingc(fea, adj.cpu())
        else:
            x = self.ingc(fea, adj)

        x = F.dropout(x, self.dropout, training=self.training)
        if self.mixmode:
            x = x.to(device)

        # mid block connections
        # for i in xrange(len(self.midlayer)):
        for i in range(len(self.midlayer)):
            midgc = self.midlayer[i]
            x = midgc(x, adj)
        # output, no relu and dropput here.
        x = self.outgc(x, adj)
        x = F.log_softmax(x, dim=1)
        return x

class GCNFlatRes(nn.Module):
    """
    (Legacy)
    """
    def __init__(self, nfeat, nhid, nclass, withbn, nreslayer, dropout, mixmode=False):
        super(GCNFlatRes, self).__init__()

        self.nreslayer = nreslayer
        self.dropout = dropout
        self.ingc = GraphConvolution(nfeat, nhid, F.relu)
        self.reslayer = GCFlatResBlock(nhid, nclass, nhid, nreslayer, dropout)
        self.reset_parameters()

    def reset_parameters(self):
        # stdv = 1. / math.sqrt(self.attention.size(1))
        # self.attention.data.uniform_(-stdv, stdv)
        # print(self.attention)
        pass

    def forward(self, input, adj):
        x = self.ingc(input, adj)
        x = F.dropout(x, self.dropout, training=self.training)
        x = self.reslayer(x, adj)
        # x = F.dropout(x, self.dropout, training=self.training)
        return F.log_softmax(x, dim=1)

# %%
from ipynb.fs.full.SGSLoadDataset import LOAD_DATASET

DATASET_NAME = "Cora_ML"
# data, dataset  = LOAD_DATASET(DIR, DATASET_NAME)
# num_classes = max(data.y).item()+1

# %% [markdown]
# Train_new.py

# %%
no_cuda = True  # Disables CUDA training.
fastmode = False  # Disable validation during training.
seed = 42  # Random seed.
epochs =500  # Number of epochs to train.
lr = 0.02  # Initial learning rate.
lradjust = False  # E"nable learning rate adjust. (ReduceLROnPlateau or Linear Reduce)
weight_decay = 5e-4  # Weight decay (L2 loss on parameters).
mixmode = False  # Enable CPU-GPU mixing mode.
warm_start = ""  # The model name to be loaded for warm start.
debug = True  # Enable the detailed training output.

# dataset = "reed98"  # The data set
# datapath = "data_cora/"  # The data path.

dataset = DATASET_NAME  # The data set
datapath = DIR  # The data path.



early_stopping = 0  # The patience of early stopping. Set to 0 to disable.
no_tensorboard = False  # Disable writing logs to TensorBoard.

# Model parameters
model_type = None  # Choose the model to be trained (mutigcn, resgcn, densegcn, inceptiongcn).
inputlayer = "gcn"  # The input layer of the model.
outputlayer = "gcn"  # The output layer of the model.
hidden = 128  # Number of hidden units.
dropout = 0.5  # Dropout rate (1 - keep probability).
withbn = False  # Enable Batch Norm in GCN.
withloop = False  # Enable loop layer in GCN.
nhiddenlayer = 1  # The number of hidden layers.
normalization = "AugNormAdj"  # The normalization on the adjacency matrix.
sampling_percent = 0.20  # The percent of preserved edges. If set to 1, no sampling is done.
nbaseblocklayer = 1  # The number of layers in each base block.
aggrmethod = "default"  # Aggregation method for layer aggregation (add, concat).
task_type = "full"  # The node classification task type (full, semi). Only valid for specific datasets.
_type = 'gcn'

# %%
is_train = True 
cuda = not no_cuda and torch.cuda.is_available()
mixmode = no_cuda and mixmode and torch.cuda.is_available()
if aggrmethod == "default":
    if type == "resgcn":
        aggrmethod = "add"
    else:
        aggrmethod = "concat"
if fastmode and early_stopping > 0:
    early_stopping = 0
    print("In the fast mode, early_stopping is not valid option. Setting early_stopping = 0.")
if _type == "mutigcn":
    print("For the multi-layer gcn model, the aggrmethod is fixed to nores and nhiddenlayers = 1.")
    nhiddenlayer = 1
    aggrmethod = "nores"

# random seed setting
np.random.seed(seed)
torch.manual_seed(seed)
if cuda or mixmode:
    torch.cuda.manual_seed(seed)
""
# should we need fix random seed here?
sampler = Sampler(dataset, datapath,task_type)

# get labels and indexes
labels, idx_train, idx_val, idx_test = sampler.get_label_and_idxes(cuda)
nfeat = sampler.nfeat
nclass = sampler.nclass
print("nclass: %d\tnfea:%d" % (nclass, nfeat))

# The model
model = GCNModel(nfeat=nfeat,
                 nhid=hidden,
                 nclass=nclass,
                 nhidlayer=nhiddenlayer,
                 dropout=dropout,
                 inputlayer=inputlayer,
                 outputlayer=outputlayer,
                 nbaselayer=nbaseblocklayer,
                 activation=F.relu,
                 withbn=withbn,
                 withloop=withloop,
                 aggrmethod=aggrmethod,
                 mixmode=mixmode)

optimizer = optim.Adam(model.parameters(),
                       lr=lr, weight_decay=weight_decay)


scheduler = optim.lr_scheduler.MultiStepLR(optimizer, milestones=[200, 300, 400, 500, 600, 700], gamma=0.5)
if cuda:
    model.cuda()
if cuda or mixmode:
    labels = labels.cuda()
    idx_train = idx_train.cuda()
    idx_val = idx_val.cuda()
    idx_test = idx_test.cuda()

if warm_start is not None and warm_start != "":
    early_stopping = EarlyStopping(fname=warm_start, verbose=False)
    print("Restore checkpoint from %s" % (early_stopping.fname))
    model.load_state_dict(early_stopping.load_checkpoint())
if early_stopping > 0:
    early_stopping = EarlyStopping(patience=early_stopping, verbose=False)
    print("Model is saving to: %s" % (early_stopping.fname))
def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']
# Out:
# Cora_ML N: 2995 E: 16316 F: 2879 C: 7 d: 5.45 lr: 0.20 i: False s: False u: True
# [14, 15, 18, 20, 25, 36, 42, 52, 63, 70, 71, 77, 86, 92, 95, 96, 100, 105, 109, 112, 114, 116, 118, 122, 129, 143, 144, 145, 150, 152, 153, 155, 162, 168, 174, 179, 183, 184, 197, 213, 214, 222, 225, 232, 235, 240, 243, 245, 246, 247, 249, 252, 253, 263, 266, 269, 271, 272, 290, 296, 312, 313, 316, 317, 319, 324, 327, 333, 334, 337, 342, 343, 344, 356, 357, 362, 373, 376, 377, 378, 379, 391, 402, 405, 410, 411, 412, 413, 417, 423, 431, 450, 451, 454, 461, 465, 467, 469, 475, 489, 497, 505, 506, 515, 519, 522, 524, 532, 539, 542, 545, 552, 562, 564, 565, 566, 580, 591, 601, 606, 609, 611, 617, 621, 624, 626, 633, 637, 648, 651, 652, 656, 657, 658, 665, 667, 668, 676, 677, 684, 687, 690, 691, 695, 696, 704, 706, 714, 715, 716, 717, 721, 727, 728, 732, 734, 738, 753, 762, 770, 775, 794, 795, 803, 806, 811, 814, 818, 822, 832, 835, 837, 838, 843, 844, 848, 850, 856, 865, 869, 871, 873, 878, 879, 882, 883, 884, 886, 889, 897, 901, 903, 905, 907, 908, 910, 915, 928, 939, 944, 947, 949, 956, 960, 963, 964, 967, 971, 980, 989, 998, 999, 1018, 1019, 1022, 1025, 1031, 1033, 1042, 1046, 1049, 1052, 1061, 1062, 1063, 1067, 1072, 1075, 1076, 1088, 1095, 1096, 1099, 1106, 1107, 1110, 1111, 1113, 1121, 1133, 1137, 1150, 1154, 1155, 1160, 1168, 1170, 1174, 1175, 1182, 1187, 1191, 1192, 1200, 1202, 1207, 1214, 1235, 1251, 1253, 1254, 1258, 1261, 1275, 1277, 1278, 1284, 1288, 1295, 1300, 1303, 1306, 1309, 1311, 1312, 1313, 1321, 1324, 1327, 1332, 1337, 1345, 1350, 1360, 1366, 1368, 1372, 1376, 1383, 1389, 1393, 1411, 1420, 1423, 1424, 1425, 1431, 1434, 1439, 1445, 1449, 1455, 1460, 1465, 1469, 1472, 1473, 1474, 1478, 1484, 1485, 1486, 1491, 1492, 1493, 1495, 1499, 1521, 1522, 1523, 1527, 1528, 1530, 1538, 1547, 1560, 1571, 1572, 1580, 1581, 1582, 1590, 1594, 1598, 1612, 1615, 1616, 1619, 1620, 1622, 1627, 1630, 1632, 1635, 1638, 1639, 1640, 1666, 1667, 1679, 1686, 1689, 1692, 1693, 1694, 1700, 1706, 1712, 1715, 1717, 1722, 1738, 1740, 1741, 1745, 1752, 1756, 1757, 1762, 1763, 1771, 1774, 1795, 1798, 1799, 1801, 1803, 1806, 1820, 1824, 1830, 1834, 1835, 1838, 1840, 1844, 1845, 1849, 1869, 1871, 1874, 1876, 1878, 1879, 1880, 1883, 1887, 1888, 1890, 1898, 1914, 1920, 1927, 1936, 1939, 1942, 1949, 1968, 1979, 1981, 1982, 1983, 1996, 2012, 2025, 2033, 2052, 2055, 2069, 2072, 2077, 2091, 2092, 2103, 2125, 2127, 2141, 2144, 2148, 2171, 2172, 2176, 2178, 2180, 2186, 2189, 2195, 2197, 2205, 2210, 2214, 2216, 2218, 2219, 2221, 2222, 2224, 2230, 2244, 2247, 2251, 2254, 2257, 2258, 2260, 2261, 2265, 2267, 2269, 2277, 2278, 2283, 2288, 2302, 2309, 2311, 2321, 2326, 2327, 2335, 2365, 2376, 2382, 2386, 2394, 2400, 2405, 2408, 2413, 2417, 2419, 2422, 2432, 2442, 2445, 2446, 2450, 2464, 2465, 2468, 2470, 2486, 2488, 2492, 2498, 2499, 2502, 2504, 2506, 2510, 2516, 2518, 2523, 2524, 2525, 2533, 2536, 2537, 2547, 2548, 2549, 2556, 2559, 2561, 2562, 2566, 2567, 2568, 2574, 2575, 2583, 2588, 2591, 2592, 2617, 2619, 2623, 2628, 2631, 2634, 2643, 2655, 2658, 2663, 2669, 2674, 2675, 2676, 2678, 2684, 2690, 2696, 2705, 2714, 2724, 2729, 2730, 2736, 2737, 2754, 2756, 2760, 2763, 2770, 2795, 2797, 2799, 2803, 2808, 2812, 2817, 2821, 2826, 2831, 2837, 2838, 2840, 2844, 2860, 2863, 2867, 2877, 2878, 2880, 2884, 2895, 2898, 2904, 2915, 2929, 2930, 2933, 2936, 2939, 2943, 2948, 2951, 2955, 2962, 2963, 2964, 2966, 2967, 2969, 2970, 2973, 2975, 2979, 2987]
# nclass: 7	nfea:2879

# %%
# Define convergence parameters
convergence_threshold = 0.001  # Threshold for loss std deviation
last_5_val_losses = []         # To store the last 5 validation losses

# Train model
t_total = time.time()
loss_train = np.zeros((epochs,))
acc_train = np.zeros((epochs,))
loss_val = np.zeros((epochs,))
acc_val = np.zeros((epochs,))

sampling_t = 0
EpochTimes = []

for epoch in range(epochs):
    input_idx_train = idx_train
    sampling_t = time.time()

    # Random edge sampling
    (train_adj, train_fea) = sampler.randomedge_sampler(percent=sampling_percent, normalization=normalization,
                                                        cuda=cuda)
    if mixmode:
        train_adj = train_adj.cuda()

    sampling_t = time.time() - sampling_t
    EpochTimes.append(sampling_t)
    
    # Validation and training
    if is_train:
        outputs = train(epoch, train_adj, train_fea, input_idx_train)
    else:
        (val_adj, val_fea) = sampler.get_test_set(normalization=normalization, cuda=cuda)
        if mixmode:
            val_adj = val_adj.cuda()
        outputs = train(epoch, train_adj, train_fea, input_idx_train, val_adj, val_fea)

    # Debug logs
    if debug and epoch % 1 == 0:
        print('Epoch: {:04d}'.format(epoch + 1),
              'loss_train: {:.4f}'.format(outputs[0]),
              'acc_train: {:.4f}'.format(outputs[1]),
              'loss_val: {:.4f}'.format(outputs[2]),
              'acc_val: {:.4f}'.format(outputs[3]),
              'cur_lr: {:.5f}'.format(outputs[4]),
              's_time: {:.4f}s'.format(sampling_t),
              't_time: {:.4f}s'.format(outputs[5]),
              'v_time: {:.4f}s'.format(outputs[6]))

    # Record losses and accuracies
    loss_train[epoch], acc_train[epoch], loss_val[epoch], acc_val[epoch] = outputs[0], outputs[1], outputs[2], outputs[3]

    # Update last 5 validation losses
    last_5_val_losses.append(loss_train[epoch])
    if len(last_5_val_losses) > 5:
        last_5_val_losses.pop(0)

    # Check convergence
    if len(last_5_val_losses) == 5 and np.std(last_5_val_losses) < convergence_threshold:
        print(f"Convergence achieved at Epoch: {epoch + 1} | Std of Last 5 Validation Losses: {np.std(last_5_val_losses):.4f}")
        model.load_state_dict(early_stopping.load_checkpoint())
        break

    # Early stopping logic
    if early_stopping > 0 and early_stopping.early_stop:
        print("Early stopping.")
        model.load_state_dict(early_stopping.load_checkpoint())
        break

# Final checkpoint load
if early_stopping > 0:
    model.load_state_dict(early_stopping.load_checkpoint())

# Final logs
if debug:
    print("Optimization Finished!")
    print("Total time elapsed: {:.4f}s".format(time.time() - t_total))
    
# Testing
(test_adj, test_fea) = sampler.get_test_set(normalization=normalization, cuda=cuda)
if mixmode:
    test_adj = test_adj.cuda()
(loss_test, acc_test) = test(test_adj, test_fea)
print("%.6f\t%.6f\t%.6f\t%.6f\t%.6f\t%.6f" % (
loss_train[-1], loss_val[-1], loss_test, acc_train[-1], acc_val[-1], acc_test))
print(dataset)
print("Mean Epoch Times:", np.mean(EpochTimes))
# Out:
# Epoch: 0001 loss_train: 2.0742 acc_train: 0.1052 loss_val: 2.3785 acc_val: 0.2721 cur_lr: 0.02000 s_time: 0.0034s t_time: 0.0609s v_time: 0.0251s
# Epoch: 0002 loss_train: 2.4928 acc_train: 0.2855 loss_val: 1.7168 acc_val: 0.3581 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0592s v_time: 0.0251s
# Epoch: 0003 loss_train: 1.7186 acc_train: 0.3556 loss_val: 1.6114 acc_val: 0.5776 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0554s v_time: 0.0258s
# Epoch: 0004 loss_train: 1.5498 acc_train: 0.5175 loss_val: 1.4546 acc_val: 0.6336 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0591s v_time: 0.0256s
# Epoch: 0005 loss_train: 1.3708 acc_train: 0.5977 loss_val: 1.2731 acc_val: 0.6444 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0593s v_time: 0.0257s
# Epoch: 0006 loss_train: 1.1735 acc_train: 0.6845 loss_val: 1.0940 acc_val: 0.6945 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0584s v_time: 0.0260s
# Epoch: 0007 loss_train: 0.9395 acc_train: 0.7446 loss_val: 0.9261 acc_val: 0.7354 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0588s v_time: 0.0256s
# Epoch: 0008 loss_train: 0.6914 acc_train: 0.8230 loss_val: 0.8424 acc_val: 0.7346 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0586s v_time: 0.0260s
# Epoch: 0009 loss_train: 0.6224 acc_train: 0.8097 loss_val: 0.8326 acc_val: 0.7212 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0585s v_time: 0.0259s
# Epoch: 0010 loss_train: 0.6334 acc_train: 0.8130 loss_val: 0.7985 acc_val: 0.7563 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0587s v_time: 0.0256s
# Epoch: 0011 loss_train: 0.5548 acc_train: 0.8331 loss_val: 0.8040 acc_val: 0.7821 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0553s v_time: 0.0248s
# Epoch: 0012 loss_train: 0.5783 acc_train: 0.8447 loss_val: 0.7846 acc_val: 0.7780 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0591s v_time: 0.0256s
# Epoch: 0013 loss_train: 0.4262 acc_train: 0.8631 loss_val: 0.7756 acc_val: 0.7763 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0591s v_time: 0.0258s
# Epoch: 0014 loss_train: 0.5159 acc_train: 0.8748 loss_val: 0.8288 acc_val: 0.7938 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0584s v_time: 0.0262s
# Epoch: 0015 loss_train: 0.4640 acc_train: 0.8681 loss_val: 0.7946 acc_val: 0.7896 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0587s v_time: 0.0256s
# Epoch: 0016 loss_train: 0.4711 acc_train: 0.8781 loss_val: 0.8408 acc_val: 0.7805 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0589s v_time: 0.0260s
# Epoch: 0017 loss_train: 0.4778 acc_train: 0.8564 loss_val: 0.8330 acc_val: 0.7813 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0581s v_time: 0.0259s
# Epoch: 0018 loss_train: 0.3516 acc_train: 0.9015 loss_val: 0.7716 acc_val: 0.7888 cur_lr: 0.02000 s_time: 0.0032s t_time: 0.0585s v_time: 0.0256s
# Epoch: 0019 loss_train: 0.3729 acc_train: 0.8881 loss_val: 0.7961 acc_val: 0.7905 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0562s v_time: 0.0249s
# Epoch: 0020 loss_train: 0.3981 acc_train: 0.8848 loss_val: 0.7981 acc_val: 0.7788 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0579s v_time: 0.0256s
# Epoch: 0021 loss_train: 0.3493 acc_train: 0.9015 loss_val: 0.7503 acc_val: 0.7621 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0581s v_time: 0.0260s
# Epoch: 0022 loss_train: 0.3738 acc_train: 0.8765 loss_val: 0.8004 acc_val: 0.7521 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0587s v_time: 0.0256s
# Epoch: 0023 loss_train: 0.3287 acc_train: 0.8865 loss_val: 0.7499 acc_val: 0.7788 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0589s v_time: 0.0255s
# Epoch: 0024 loss_train: 0.3201 acc_train: 0.9115 loss_val: 0.8783 acc_val: 0.7604 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0583s v_time: 0.0259s
# Epoch: 0025 loss_train: 0.3197 acc_train: 0.9132 loss_val: 0.7779 acc_val: 0.7788 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0590s v_time: 0.0255s
# Epoch: 0026 loss_train: 0.3693 acc_train: 0.8948 loss_val: 0.7629 acc_val: 0.7705 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0592s v_time: 0.0254s
# Epoch: 0027 loss_train: 0.3448 acc_train: 0.8898 loss_val: 0.8380 acc_val: 0.7696 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0580s v_time: 0.0247s
# Epoch: 0028 loss_train: 0.2946 acc_train: 0.9165 loss_val: 0.7858 acc_val: 0.7805 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0574s v_time: 0.0255s
# Epoch: 0029 loss_train: 0.2937 acc_train: 0.9165 loss_val: 0.8891 acc_val: 0.7688 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0583s v_time: 0.0259s
# Epoch: 0030 loss_train: 0.3081 acc_train: 0.9249 loss_val: 0.8142 acc_val: 0.7746 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0582s v_time: 0.0256s
# Epoch: 0031 loss_train: 0.3043 acc_train: 0.9048 loss_val: 0.8365 acc_val: 0.7696 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0587s v_time: 0.0256s
# Epoch: 0032 loss_train: 0.3308 acc_train: 0.9115 loss_val: 0.7745 acc_val: 0.7763 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0592s v_time: 0.0255s
# Epoch: 0033 loss_train: 0.3185 acc_train: 0.8998 loss_val: 0.8010 acc_val: 0.7838 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0584s v_time: 0.0262s
# Epoch: 0034 loss_train: 0.2676 acc_train: 0.9149 loss_val: 0.7772 acc_val: 0.7930 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0586s v_time: 0.0255s
# Epoch: 0035 loss_train: 0.2898 acc_train: 0.9282 loss_val: 0.8076 acc_val: 0.7796 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0579s v_time: 0.0247s
# Epoch: 0036 loss_train: 0.2860 acc_train: 0.9082 loss_val: 0.8156 acc_val: 0.7738 cur_lr: 0.02000 s_time: 0.0026s t_time: 0.0549s v_time: 0.0258s
# Epoch: 0037 loss_train: 0.2571 acc_train: 0.9115 loss_val: 0.8096 acc_val: 0.7780 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0593s v_time: 0.0256s
# Epoch: 0038 loss_train: 0.2429 acc_train: 0.9182 loss_val: 0.8665 acc_val: 0.7813 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0591s v_time: 0.0255s
# Epoch: 0039 loss_train: 0.2726 acc_train: 0.9349 loss_val: 0.7996 acc_val: 0.7855 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0583s v_time: 0.0260s
# Epoch: 0040 loss_train: 0.2874 acc_train: 0.9265 loss_val: 0.7845 acc_val: 0.7755 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0590s v_time: 0.0255s
# Epoch: 0041 loss_train: 0.2721 acc_train: 0.9115 loss_val: 0.8252 acc_val: 0.7821 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0590s v_time: 0.0257s
# Epoch: 0042 loss_train: 0.2234 acc_train: 0.9282 loss_val: 0.8864 acc_val: 0.7563 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0585s v_time: 0.0262s
# Epoch: 0043 loss_train: 0.2779 acc_train: 0.9149 loss_val: 0.8413 acc_val: 0.7654 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0585s v_time: 0.0252s
# Epoch: 0044 loss_train: 0.2242 acc_train: 0.9282 loss_val: 0.9161 acc_val: 0.7571 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0555s v_time: 0.0257s
# Epoch: 0045 loss_train: 0.2607 acc_train: 0.9299 loss_val: 0.8727 acc_val: 0.7638 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0582s v_time: 0.0248s
# Epoch: 0046 loss_train: 0.2680 acc_train: 0.9182 loss_val: 0.8543 acc_val: 0.7538 cur_lr: 0.02000 s_time: 0.0026s t_time: 0.0553s v_time: 0.0261s
# Epoch: 0047 loss_train: 0.2778 acc_train: 0.9249 loss_val: 0.8019 acc_val: 0.7813 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0588s v_time: 0.0256s
# Epoch: 0048 loss_train: 0.2645 acc_train: 0.9082 loss_val: 0.8887 acc_val: 0.7621 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0591s v_time: 0.0255s
# Epoch: 0049 loss_train: 0.2632 acc_train: 0.9232 loss_val: 0.8481 acc_val: 0.7671 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0599s v_time: 0.0259s
# Epoch: 0050 loss_train: 0.2248 acc_train: 0.9332 loss_val: 0.8180 acc_val: 0.7846 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0589s v_time: 0.0254s
# Epoch: 0051 loss_train: 0.2659 acc_train: 0.9265 loss_val: 0.8784 acc_val: 0.7721 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0594s v_time: 0.0263s
# Epoch: 0052 loss_train: 0.2906 acc_train: 0.9149 loss_val: 0.8897 acc_val: 0.7821 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0560s v_time: 0.0246s
# Epoch: 0053 loss_train: 0.2725 acc_train: 0.9199 loss_val: 0.9242 acc_val: 0.7663 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0584s v_time: 0.0254s
# Epoch: 0054 loss_train: 0.2336 acc_train: 0.9316 loss_val: 0.8646 acc_val: 0.7671 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0592s v_time: 0.0256s
# Epoch: 0055 loss_train: 0.2765 acc_train: 0.9282 loss_val: 0.8690 acc_val: 0.7755 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0584s v_time: 0.0260s
# Epoch: 0056 loss_train: 0.2713 acc_train: 0.9032 loss_val: 0.9643 acc_val: 0.7504 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0584s v_time: 0.0254s
# Epoch: 0057 loss_train: 0.2698 acc_train: 0.9182 loss_val: 0.8851 acc_val: 0.7713 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0588s v_time: 0.0254s
# Epoch: 0058 loss_train: 0.2413 acc_train: 0.9282 loss_val: 0.8884 acc_val: 0.7629 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0589s v_time: 0.0258s
# Epoch: 0059 loss_train: 0.2604 acc_train: 0.9182 loss_val: 0.8787 acc_val: 0.7696 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0584s v_time: 0.0260s
# Epoch: 0060 loss_train: 0.2162 acc_train: 0.9349 loss_val: 0.8604 acc_val: 0.7538 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0565s v_time: 0.0245s
# Epoch: 0061 loss_train: 0.2687 acc_train: 0.9199 loss_val: 0.8153 acc_val: 0.7629 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0573s v_time: 0.0289s
# Epoch: 0062 loss_train: 0.2210 acc_train: 0.9232 loss_val: 0.8488 acc_val: 0.7721 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0675s v_time: 0.0305s
# Epoch: 0063 loss_train: 0.2601 acc_train: 0.9199 loss_val: 0.8993 acc_val: 0.7462 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0861s v_time: 0.0282s
# Epoch: 0064 loss_train: 0.2486 acc_train: 0.9182 loss_val: 0.8450 acc_val: 0.7579 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0636s v_time: 0.0349s
# Epoch: 0065 loss_train: 0.2075 acc_train: 0.9316 loss_val: 0.8533 acc_val: 0.7679 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0844s v_time: 0.0367s
# Epoch: 0066 loss_train: 0.2407 acc_train: 0.9232 loss_val: 0.9037 acc_val: 0.7588 cur_lr: 0.02000 s_time: 0.0032s t_time: 0.0838s v_time: 0.0376s
# Epoch: 0067 loss_train: 0.2636 acc_train: 0.9299 loss_val: 0.9083 acc_val: 0.7604 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0630s v_time: 0.0273s
# Epoch: 0068 loss_train: 0.2008 acc_train: 0.9299 loss_val: 0.9644 acc_val: 0.7588 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0842s v_time: 0.0367s
# Epoch: 0069 loss_train: 0.2763 acc_train: 0.9316 loss_val: 0.9078 acc_val: 0.7679 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0832s v_time: 0.0272s
# Epoch: 0070 loss_train: 0.2197 acc_train: 0.9399 loss_val: 0.9293 acc_val: 0.7496 cur_lr: 0.02000 s_time: 0.0047s t_time: 0.0629s v_time: 0.0344s
# Epoch: 0071 loss_train: 0.2568 acc_train: 0.9265 loss_val: 1.0207 acc_val: 0.7513 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0823s v_time: 0.0370s
# Epoch: 0072 loss_train: 0.1840 acc_train: 0.9416 loss_val: 0.9003 acc_val: 0.7496 cur_lr: 0.02000 s_time: 0.0032s t_time: 0.0817s v_time: 0.0366s
# Epoch: 0073 loss_train: 0.2144 acc_train: 0.9366 loss_val: 0.9300 acc_val: 0.7588 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0674s v_time: 0.0271s
# Epoch: 0074 loss_train: 0.2913 acc_train: 0.9182 loss_val: 0.8678 acc_val: 0.7738 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0754s v_time: 0.0359s
# Epoch: 0075 loss_train: 0.2538 acc_train: 0.9265 loss_val: 0.9007 acc_val: 0.7546 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0812s v_time: 0.0357s
# Epoch: 0076 loss_train: 0.2174 acc_train: 0.9299 loss_val: 0.9031 acc_val: 0.7529 cur_lr: 0.02000 s_time: 0.0032s t_time: 0.0813s v_time: 0.0279s
# Epoch: 0077 loss_train: 0.1783 acc_train: 0.9516 loss_val: 0.9198 acc_val: 0.7571 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0618s v_time: 0.0331s
# Epoch: 0078 loss_train: 0.2417 acc_train: 0.9349 loss_val: 0.9302 acc_val: 0.7571 cur_lr: 0.02000 s_time: 0.0032s t_time: 0.0813s v_time: 0.0275s
# Epoch: 0079 loss_train: 0.2477 acc_train: 0.9316 loss_val: 0.8699 acc_val: 0.7738 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0617s v_time: 0.0295s
# Epoch: 0080 loss_train: 0.2616 acc_train: 0.9199 loss_val: 0.9632 acc_val: 0.7554 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0629s v_time: 0.0284s
# Epoch: 0081 loss_train: 0.2723 acc_train: 0.9182 loss_val: 0.9139 acc_val: 0.7554 cur_lr: 0.02000 s_time: 0.0032s t_time: 0.0599s v_time: 0.0256s
# Epoch: 0082 loss_train: 0.2636 acc_train: 0.9165 loss_val: 0.9470 acc_val: 0.7546 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0765s v_time: 0.0271s
# Epoch: 0083 loss_train: 0.2505 acc_train: 0.9232 loss_val: 0.9169 acc_val: 0.7538 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0612s v_time: 0.0322s
# Epoch: 0084 loss_train: 0.2174 acc_train: 0.9332 loss_val: 0.8598 acc_val: 0.7746 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0801s v_time: 0.0350s
# Epoch: 0085 loss_train: 0.2535 acc_train: 0.9265 loss_val: 0.9483 acc_val: 0.7554 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0804s v_time: 0.0273s
# Epoch: 0086 loss_train: 0.2559 acc_train: 0.9349 loss_val: 0.9645 acc_val: 0.7554 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0610s v_time: 0.0328s
# Epoch: 0087 loss_train: 0.2253 acc_train: 0.9282 loss_val: 0.8779 acc_val: 0.7579 cur_lr: 0.02000 s_time: 0.0032s t_time: 0.0594s v_time: 0.0254s
# Epoch: 0088 loss_train: 0.2886 acc_train: 0.9182 loss_val: 0.9384 acc_val: 0.7471 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0756s v_time: 0.0276s
# Epoch: 0089 loss_train: 0.3015 acc_train: 0.9149 loss_val: 0.9566 acc_val: 0.7496 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0612s v_time: 0.0316s
# Epoch: 0090 loss_train: 0.2644 acc_train: 0.9232 loss_val: 0.9199 acc_val: 0.7454 cur_lr: 0.02000 s_time: 0.0032s t_time: 0.0788s v_time: 0.0263s
# Epoch: 0091 loss_train: 0.2774 acc_train: 0.9182 loss_val: 0.9066 acc_val: 0.7446 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0608s v_time: 0.0318s
# Epoch: 0092 loss_train: 0.2999 acc_train: 0.9098 loss_val: 0.9303 acc_val: 0.7354 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0797s v_time: 0.0275s
# Epoch: 0093 loss_train: 0.2614 acc_train: 0.9149 loss_val: 0.8771 acc_val: 0.7629 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0609s v_time: 0.0320s
# Epoch: 0094 loss_train: 0.2144 acc_train: 0.9316 loss_val: 0.9075 acc_val: 0.7554 cur_lr: 0.02000 s_time: 0.0032s t_time: 0.0632s v_time: 0.0254s
# Epoch: 0095 loss_train: 0.2468 acc_train: 0.9182 loss_val: 0.8943 acc_val: 0.7538 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0700s v_time: 0.0255s
# Epoch: 0096 loss_train: 0.1838 acc_train: 0.9516 loss_val: 0.9121 acc_val: 0.7529 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0593s v_time: 0.0305s
# Epoch: 0097 loss_train: 0.2785 acc_train: 0.9182 loss_val: 0.9640 acc_val: 0.7462 cur_lr: 0.02000 s_time: 0.0032s t_time: 0.0784s v_time: 0.0340s
# Epoch: 0098 loss_train: 0.1986 acc_train: 0.9316 loss_val: 0.9205 acc_val: 0.7462 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0790s v_time: 0.0263s
# Epoch: 0099 loss_train: 0.2622 acc_train: 0.9165 loss_val: 0.8964 acc_val: 0.7437 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0607s v_time: 0.0312s
# Epoch: 0100 loss_train: 0.2282 acc_train: 0.9282 loss_val: 0.9431 acc_val: 0.7554 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0786s v_time: 0.0272s
# Epoch: 0101 loss_train: 0.2176 acc_train: 0.9316 loss_val: 1.0129 acc_val: 0.7371 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0613s v_time: 0.0319s
# Epoch: 0102 loss_train: 0.2877 acc_train: 0.9082 loss_val: 0.8675 acc_val: 0.7629 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0773s v_time: 0.0262s
# Epoch: 0103 loss_train: 0.2319 acc_train: 0.9349 loss_val: 0.9442 acc_val: 0.7596 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0608s v_time: 0.0310s
# Epoch: 0104 loss_train: 0.3139 acc_train: 0.9232 loss_val: 0.9226 acc_val: 0.7554 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0777s v_time: 0.0269s
# Epoch: 0105 loss_train: 0.2322 acc_train: 0.9199 loss_val: 0.9510 acc_val: 0.7421 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0605s v_time: 0.0310s
# Epoch: 0106 loss_train: 0.2432 acc_train: 0.9316 loss_val: 0.9292 acc_val: 0.7529 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0767s v_time: 0.0268s
# Epoch: 0107 loss_train: 0.2171 acc_train: 0.9349 loss_val: 0.8705 acc_val: 0.7579 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0603s v_time: 0.0310s
# Epoch: 0108 loss_train: 0.2047 acc_train: 0.9316 loss_val: 0.9895 acc_val: 0.7437 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0656s v_time: 0.0253s
# Epoch: 0109 loss_train: 0.2042 acc_train: 0.9249 loss_val: 0.8642 acc_val: 0.7696 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0672s v_time: 0.0263s
# Epoch: 0110 loss_train: 0.2570 acc_train: 0.9332 loss_val: 0.9206 acc_val: 0.7613 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0609s v_time: 0.0316s
# Epoch: 0111 loss_train: 0.2476 acc_train: 0.9149 loss_val: 0.9563 acc_val: 0.7671 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0780s v_time: 0.0260s
# Epoch: 0112 loss_train: 0.2364 acc_train: 0.9449 loss_val: 0.9715 acc_val: 0.7663 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0604s v_time: 0.0307s
# Epoch: 0113 loss_train: 0.2052 acc_train: 0.9399 loss_val: 0.9077 acc_val: 0.7671 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0769s v_time: 0.0345s
# Epoch: 0114 loss_train: 0.2751 acc_train: 0.9182 loss_val: 0.9361 acc_val: 0.7596 cur_lr: 0.02000 s_time: 0.0032s t_time: 0.0777s v_time: 0.0262s
# Epoch: 0115 loss_train: 0.2582 acc_train: 0.9299 loss_val: 0.9632 acc_val: 0.7621 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0608s v_time: 0.0259s
# Epoch: 0116 loss_train: 0.1792 acc_train: 0.9432 loss_val: 0.9319 acc_val: 0.7579 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0706s v_time: 0.0260s
# Epoch: 0117 loss_train: 0.2606 acc_train: 0.9299 loss_val: 0.8492 acc_val: 0.7838 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0668s v_time: 0.0267s
# Epoch: 0118 loss_train: 0.2474 acc_train: 0.9249 loss_val: 0.9362 acc_val: 0.7604 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0605s v_time: 0.0309s
# Epoch: 0119 loss_train: 0.2206 acc_train: 0.9366 loss_val: 0.9218 acc_val: 0.7646 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0770s v_time: 0.0262s
# Epoch: 0120 loss_train: 0.2630 acc_train: 0.9199 loss_val: 0.8848 acc_val: 0.7679 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0605s v_time: 0.0310s
# Epoch: 0121 loss_train: 0.2945 acc_train: 0.9132 loss_val: 0.8483 acc_val: 0.7780 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0783s v_time: 0.0272s
# Epoch: 0122 loss_train: 0.2229 acc_train: 0.9332 loss_val: 0.8856 acc_val: 0.7671 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0601s v_time: 0.0260s
# Epoch: 0123 loss_train: 0.2366 acc_train: 0.9249 loss_val: 0.8847 acc_val: 0.7671 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0781s v_time: 0.0270s
# Epoch: 0124 loss_train: 0.2231 acc_train: 0.9349 loss_val: 0.8907 acc_val: 0.7755 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0603s v_time: 0.0312s
# Epoch: 0125 loss_train: 0.2527 acc_train: 0.9332 loss_val: 0.8816 acc_val: 0.7780 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0773s v_time: 0.0268s
# Epoch: 0126 loss_train: 0.2565 acc_train: 0.9232 loss_val: 0.8744 acc_val: 0.7788 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0603s v_time: 0.0314s
# Epoch: 0127 loss_train: 0.2530 acc_train: 0.9232 loss_val: 0.8775 acc_val: 0.7721 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0775s v_time: 0.0269s
# Epoch: 0128 loss_train: 0.2065 acc_train: 0.9232 loss_val: 0.9406 acc_val: 0.7546 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0603s v_time: 0.0308s
# Epoch: 0129 loss_train: 0.1935 acc_train: 0.9299 loss_val: 0.9015 acc_val: 0.7596 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0740s v_time: 0.0253s
# Epoch: 0130 loss_train: 0.2245 acc_train: 0.9299 loss_val: 0.8281 acc_val: 0.7830 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0589s v_time: 0.0327s
# Epoch: 0131 loss_train: 0.2469 acc_train: 0.9382 loss_val: 0.9169 acc_val: 0.7596 cur_lr: 0.02000 s_time: 0.0034s t_time: 0.0772s v_time: 0.0338s
# Epoch: 0132 loss_train: 0.2286 acc_train: 0.9349 loss_val: 0.8290 acc_val: 0.7705 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0773s v_time: 0.0333s
# Epoch: 0133 loss_train: 0.1944 acc_train: 0.9382 loss_val: 0.9451 acc_val: 0.7705 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0756s v_time: 0.0333s
# Epoch: 0134 loss_train: 0.2704 acc_train: 0.9182 loss_val: 0.9014 acc_val: 0.7671 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0770s v_time: 0.0267s
# Epoch: 0135 loss_train: 0.1708 acc_train: 0.9466 loss_val: 0.9363 acc_val: 0.7554 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0602s v_time: 0.0311s
# Epoch: 0136 loss_train: 0.2249 acc_train: 0.9265 loss_val: 0.9202 acc_val: 0.7663 cur_lr: 0.02000 s_time: 0.0032s t_time: 0.0684s v_time: 0.0258s
# Epoch: 0137 loss_train: 0.2512 acc_train: 0.9249 loss_val: 0.9555 acc_val: 0.7663 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0678s v_time: 0.0260s
# Epoch: 0138 loss_train: 0.2373 acc_train: 0.9349 loss_val: 0.8888 acc_val: 0.7554 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0606s v_time: 0.0307s
# Epoch: 0139 loss_train: 0.2412 acc_train: 0.9282 loss_val: 0.9222 acc_val: 0.7679 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0764s v_time: 0.0332s
# Epoch: 0140 loss_train: 0.2521 acc_train: 0.9299 loss_val: 0.9343 acc_val: 0.7579 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0772s v_time: 0.0266s
# Epoch: 0141 loss_train: 0.2448 acc_train: 0.9349 loss_val: 0.9175 acc_val: 0.7663 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0598s v_time: 0.0306s
# Epoch: 0142 loss_train: 0.2402 acc_train: 0.9366 loss_val: 0.8953 acc_val: 0.7529 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0776s v_time: 0.0273s
# Epoch: 0143 loss_train: 0.1855 acc_train: 0.9449 loss_val: 0.9391 acc_val: 0.7454 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0611s v_time: 0.0312s
# Epoch: 0144 loss_train: 0.2490 acc_train: 0.9282 loss_val: 0.9127 acc_val: 0.7454 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0753s v_time: 0.0271s
# Epoch: 0145 loss_train: 0.2766 acc_train: 0.9282 loss_val: 0.8763 acc_val: 0.7596 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0591s v_time: 0.0292s
# Epoch: 0146 loss_train: 0.2683 acc_train: 0.9165 loss_val: 0.9111 acc_val: 0.7479 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0768s v_time: 0.0268s
# Epoch: 0147 loss_train: 0.2236 acc_train: 0.9265 loss_val: 0.9406 acc_val: 0.7496 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0601s v_time: 0.0307s
# Epoch: 0148 loss_train: 0.2536 acc_train: 0.9349 loss_val: 0.9356 acc_val: 0.7571 cur_lr: 0.02000 s_time: 0.0032s t_time: 0.0767s v_time: 0.0268s
# Epoch: 0149 loss_train: 0.2636 acc_train: 0.9249 loss_val: 0.8823 acc_val: 0.7571 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0599s v_time: 0.0305s
# Epoch: 0150 loss_train: 0.2169 acc_train: 0.9316 loss_val: 0.9393 acc_val: 0.7571 cur_lr: 0.02000 s_time: 0.0035s t_time: 0.0730s v_time: 0.0259s
# Epoch: 0151 loss_train: 0.2086 acc_train: 0.9399 loss_val: 0.9863 acc_val: 0.7479 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0640s v_time: 0.0258s
# Epoch: 0152 loss_train: 0.2720 acc_train: 0.9299 loss_val: 0.9372 acc_val: 0.7554 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0603s v_time: 0.0307s
# Epoch: 0153 loss_train: 0.2686 acc_train: 0.9265 loss_val: 0.9655 acc_val: 0.7504 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0761s v_time: 0.0266s
# Epoch: 0154 loss_train: 0.2572 acc_train: 0.9215 loss_val: 0.9094 acc_val: 0.7596 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0601s v_time: 0.0307s
# Epoch: 0155 loss_train: 0.2544 acc_train: 0.9316 loss_val: 0.9325 acc_val: 0.7613 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0768s v_time: 0.0332s
# Epoch: 0156 loss_train: 0.3116 acc_train: 0.9265 loss_val: 0.9286 acc_val: 0.7487 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0766s v_time: 0.0268s
# Epoch: 0157 loss_train: 0.2382 acc_train: 0.9299 loss_val: 0.9062 acc_val: 0.7571 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0603s v_time: 0.0312s
# Epoch: 0158 loss_train: 0.2197 acc_train: 0.9432 loss_val: 0.9349 acc_val: 0.7513 cur_lr: 0.02000 s_time: 0.0032s t_time: 0.0778s v_time: 0.0267s
# Epoch: 0159 loss_train: 0.2424 acc_train: 0.9182 loss_val: 0.8658 acc_val: 0.7638 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0603s v_time: 0.0308s
# Epoch: 0160 loss_train: 0.2150 acc_train: 0.9282 loss_val: 0.9827 acc_val: 0.7629 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0766s v_time: 0.0268s
# Epoch: 0161 loss_train: 0.2248 acc_train: 0.9432 loss_val: 0.9327 acc_val: 0.7504 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0602s v_time: 0.0305s
# Epoch: 0162 loss_train: 0.2669 acc_train: 0.9299 loss_val: 0.8929 acc_val: 0.7688 cur_lr: 0.02000 s_time: 0.0035s t_time: 0.0775s v_time: 0.0268s
# Epoch: 0163 loss_train: 0.2015 acc_train: 0.9416 loss_val: 0.9213 acc_val: 0.7604 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0602s v_time: 0.0307s
# Epoch: 0164 loss_train: 0.2366 acc_train: 0.9366 loss_val: 0.9262 acc_val: 0.7621 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0728s v_time: 0.0259s
# Epoch: 0165 loss_train: 0.2171 acc_train: 0.9249 loss_val: 0.9140 acc_val: 0.7604 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0637s v_time: 0.0259s
# Epoch: 0166 loss_train: 0.2748 acc_train: 0.9182 loss_val: 0.9105 acc_val: 0.7638 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0605s v_time: 0.0309s
# Epoch: 0167 loss_train: 0.2459 acc_train: 0.9182 loss_val: 0.9436 acc_val: 0.7613 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0770s v_time: 0.0270s
# Epoch: 0168 loss_train: 0.2894 acc_train: 0.9115 loss_val: 0.9510 acc_val: 0.7579 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0600s v_time: 0.0306s
# Epoch: 0169 loss_train: 0.2404 acc_train: 0.9416 loss_val: 0.9418 acc_val: 0.7513 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0766s v_time: 0.0268s
# Epoch: 0170 loss_train: 0.2448 acc_train: 0.9182 loss_val: 0.9385 acc_val: 0.7596 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0603s v_time: 0.0306s
# Epoch: 0171 loss_train: 0.2384 acc_train: 0.9249 loss_val: 0.9212 acc_val: 0.7679 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0762s v_time: 0.0313s
# Epoch: 0172 loss_train: 0.2201 acc_train: 0.9332 loss_val: 0.9215 acc_val: 0.7513 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0588s v_time: 0.0254s
# Epoch: 0173 loss_train: 0.2543 acc_train: 0.9215 loss_val: 0.9305 acc_val: 0.7571 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0715s v_time: 0.0259s
# Epoch: 0174 loss_train: 0.1861 acc_train: 0.9382 loss_val: 0.9608 acc_val: 0.7613 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0650s v_time: 0.0266s
# Epoch: 0175 loss_train: 0.2203 acc_train: 0.9299 loss_val: 0.9149 acc_val: 0.7646 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0602s v_time: 0.0306s
# Epoch: 0176 loss_train: 0.3066 acc_train: 0.9032 loss_val: 0.9169 acc_val: 0.7629 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0765s v_time: 0.0266s
# Epoch: 0177 loss_train: 0.2348 acc_train: 0.9199 loss_val: 0.9511 acc_val: 0.7554 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0601s v_time: 0.0308s
# Epoch: 0178 loss_train: 0.1867 acc_train: 0.9366 loss_val: 1.0304 acc_val: 0.7521 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0760s v_time: 0.0335s
# Epoch: 0179 loss_train: 0.2387 acc_train: 0.9366 loss_val: 0.9282 acc_val: 0.7604 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0617s v_time: 0.0262s
# Epoch: 0180 loss_train: 0.2400 acc_train: 0.9215 loss_val: 0.9849 acc_val: 0.7621 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0732s v_time: 0.0267s
# Epoch: 0181 loss_train: 0.1960 acc_train: 0.9416 loss_val: 0.9414 acc_val: 0.7387 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0602s v_time: 0.0307s
# Epoch: 0182 loss_train: 0.1855 acc_train: 0.9432 loss_val: 1.0036 acc_val: 0.7546 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0769s v_time: 0.0269s
# Epoch: 0183 loss_train: 0.2153 acc_train: 0.9332 loss_val: 0.9675 acc_val: 0.7412 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0601s v_time: 0.0305s
# Epoch: 0184 loss_train: 0.2130 acc_train: 0.9366 loss_val: 0.9821 acc_val: 0.7471 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0767s v_time: 0.0265s
# Epoch: 0185 loss_train: 0.2459 acc_train: 0.9282 loss_val: 0.9740 acc_val: 0.7629 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0601s v_time: 0.0306s
# Epoch: 0186 loss_train: 0.2245 acc_train: 0.9265 loss_val: 0.9954 acc_val: 0.7571 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0658s v_time: 0.0252s
# Epoch: 0187 loss_train: 0.1984 acc_train: 0.9366 loss_val: 1.0238 acc_val: 0.7596 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0649s v_time: 0.0255s
# Epoch: 0188 loss_train: 0.2405 acc_train: 0.9316 loss_val: 1.0230 acc_val: 0.7554 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0589s v_time: 0.0293s
# Epoch: 0189 loss_train: 0.2491 acc_train: 0.9349 loss_val: 0.9661 acc_val: 0.7529 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0766s v_time: 0.0266s
# Epoch: 0190 loss_train: 0.3315 acc_train: 0.9299 loss_val: 1.0259 acc_val: 0.7387 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0601s v_time: 0.0304s
# Epoch: 0191 loss_train: 0.2205 acc_train: 0.9265 loss_val: 0.8896 acc_val: 0.7629 cur_lr: 0.02000 s_time: 0.0034s t_time: 0.0766s v_time: 0.0267s
# Epoch: 0192 loss_train: 0.2085 acc_train: 0.9416 loss_val: 0.9022 acc_val: 0.7471 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0599s v_time: 0.0306s
# Epoch: 0193 loss_train: 0.2541 acc_train: 0.9299 loss_val: 0.8794 acc_val: 0.7479 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0742s v_time: 0.0258s
# Epoch: 0194 loss_train: 0.2265 acc_train: 0.9349 loss_val: 0.9124 acc_val: 0.7554 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0602s v_time: 0.0327s
# Epoch: 0195 loss_train: 0.2124 acc_train: 0.9349 loss_val: 0.9270 acc_val: 0.7596 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0770s v_time: 0.0268s
# Epoch: 0196 loss_train: 0.2194 acc_train: 0.9349 loss_val: 0.8463 acc_val: 0.7663 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0599s v_time: 0.0303s
# Epoch: 0197 loss_train: 0.2081 acc_train: 0.9299 loss_val: 0.9042 acc_val: 0.7596 cur_lr: 0.02000 s_time: 0.0034s t_time: 0.0759s v_time: 0.0335s
# Epoch: 0198 loss_train: 0.2433 acc_train: 0.9299 loss_val: 0.9717 acc_val: 0.7521 cur_lr: 0.02000 s_time: 0.0032s t_time: 0.0764s v_time: 0.0260s
# Epoch: 0199 loss_train: 0.2503 acc_train: 0.9299 loss_val: 0.9619 acc_val: 0.7471 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0599s v_time: 0.0306s
# Epoch: 0200 loss_train: 0.2264 acc_train: 0.9215 loss_val: 1.0246 acc_val: 0.7429 cur_lr: 0.02000 s_time: 0.0035s t_time: 0.0740s v_time: 0.0260s
# Epoch: 0201 loss_train: 0.1722 acc_train: 0.9499 loss_val: 0.8963 acc_val: 0.7521 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0631s v_time: 0.0327s
# Epoch: 0202 loss_train: 0.2569 acc_train: 0.9265 loss_val: 0.8432 acc_val: 0.7646 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0652s v_time: 0.0253s
# Epoch: 0203 loss_train: 0.2087 acc_train: 0.9499 loss_val: 0.9266 acc_val: 0.7462 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0677s v_time: 0.0257s
# Epoch: 0204 loss_train: 0.2137 acc_train: 0.9349 loss_val: 0.7981 acc_val: 0.7755 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0601s v_time: 0.0303s
# Epoch: 0205 loss_train: 0.2483 acc_train: 0.9215 loss_val: 0.8906 acc_val: 0.7646 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0766s v_time: 0.0265s
# Epoch: 0206 loss_train: 0.2749 acc_train: 0.9132 loss_val: 0.9330 acc_val: 0.7479 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0602s v_time: 0.0307s
# Epoch: 0207 loss_train: 0.2070 acc_train: 0.9366 loss_val: 0.9485 acc_val: 0.7487 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0766s v_time: 0.0270s
# Epoch: 0208 loss_train: 0.1829 acc_train: 0.9382 loss_val: 1.0059 acc_val: 0.7362 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0602s v_time: 0.0309s
# Epoch: 0209 loss_train: 0.1904 acc_train: 0.9432 loss_val: 0.9615 acc_val: 0.7454 cur_lr: 0.02000 s_time: 0.0032s t_time: 0.0765s v_time: 0.0337s
# Epoch: 0210 loss_train: 0.2676 acc_train: 0.9382 loss_val: 0.9604 acc_val: 0.7446 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0789s v_time: 0.0260s
# Epoch: 0211 loss_train: 0.2404 acc_train: 0.9299 loss_val: 0.9423 acc_val: 0.7604 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0601s v_time: 0.0305s
# Epoch: 0212 loss_train: 0.2384 acc_train: 0.9265 loss_val: 0.9636 acc_val: 0.7529 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0762s v_time: 0.0259s
# Epoch: 0213 loss_train: 0.2148 acc_train: 0.9332 loss_val: 0.9333 acc_val: 0.7604 cur_lr: 0.02000 s_time: 0.0032s t_time: 0.0606s v_time: 0.0307s
# Epoch: 0214 loss_train: 0.2366 acc_train: 0.9215 loss_val: 0.8811 acc_val: 0.7663 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0762s v_time: 0.0287s
# Epoch: 0215 loss_train: 0.2061 acc_train: 0.9432 loss_val: 0.8530 acc_val: 0.7796 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0601s v_time: 0.0297s
# Epoch: 0216 loss_train: 0.1749 acc_train: 0.9482 loss_val: 0.8254 acc_val: 0.7830 cur_lr: 0.02000 s_time: 0.0032s t_time: 0.0777s v_time: 0.0268s
# Epoch: 0217 loss_train: 0.1850 acc_train: 0.9399 loss_val: 0.9922 acc_val: 0.7471 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0597s v_time: 0.0307s
# Epoch: 0218 loss_train: 0.2347 acc_train: 0.9316 loss_val: 0.9547 acc_val: 0.7479 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0765s v_time: 0.0267s
# Epoch: 0219 loss_train: 0.2585 acc_train: 0.9316 loss_val: 0.9209 acc_val: 0.7462 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0598s v_time: 0.0305s
# Epoch: 0220 loss_train: 0.2367 acc_train: 0.9299 loss_val: 0.9224 acc_val: 0.7521 cur_lr: 0.02000 s_time: 0.0034s t_time: 0.0768s v_time: 0.0265s
# Epoch: 0221 loss_train: 0.2111 acc_train: 0.9449 loss_val: 0.9169 acc_val: 0.7621 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0602s v_time: 0.0315s
# Epoch: 0222 loss_train: 0.2046 acc_train: 0.9399 loss_val: 0.8811 acc_val: 0.7654 cur_lr: 0.02000 s_time: 0.0032s t_time: 0.0607s v_time: 0.0262s
# Epoch: 0223 loss_train: 0.2148 acc_train: 0.9366 loss_val: 0.8536 acc_val: 0.7688 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0734s v_time: 0.0267s
# Epoch: 0224 loss_train: 0.2504 acc_train: 0.9349 loss_val: 0.8776 acc_val: 0.7613 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0602s v_time: 0.0307s
# Epoch: 0225 loss_train: 0.2011 acc_train: 0.9232 loss_val: 0.9119 acc_val: 0.7654 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0776s v_time: 0.0260s
# Epoch: 0226 loss_train: 0.2113 acc_train: 0.9449 loss_val: 0.8759 acc_val: 0.7571 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0603s v_time: 0.0308s
# Epoch: 0227 loss_train: 0.2584 acc_train: 0.9232 loss_val: 0.9640 acc_val: 0.7596 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0764s v_time: 0.0268s
# Epoch: 0228 loss_train: 0.3133 acc_train: 0.9132 loss_val: 0.8973 acc_val: 0.7563 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0599s v_time: 0.0308s
# Epoch: 0229 loss_train: 0.2314 acc_train: 0.9316 loss_val: 0.8806 acc_val: 0.7588 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0656s v_time: 0.0256s
# Epoch: 0230 loss_train: 0.2102 acc_train: 0.9215 loss_val: 0.8857 acc_val: 0.7571 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0646s v_time: 0.0258s
# Epoch: 0231 loss_train: 0.2660 acc_train: 0.9316 loss_val: 0.9023 acc_val: 0.7613 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0599s v_time: 0.0311s
# Epoch: 0232 loss_train: 0.2219 acc_train: 0.9349 loss_val: 0.9493 acc_val: 0.7646 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0765s v_time: 0.0265s
# Epoch: 0233 loss_train: 0.2660 acc_train: 0.9215 loss_val: 0.9442 acc_val: 0.7521 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0600s v_time: 0.0307s
# Epoch: 0234 loss_train: 0.2633 acc_train: 0.9182 loss_val: 0.9307 acc_val: 0.7437 cur_lr: 0.02000 s_time: 0.0032s t_time: 0.0753s v_time: 0.0268s
# Epoch: 0235 loss_train: 0.2825 acc_train: 0.9182 loss_val: 0.8701 acc_val: 0.7504 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0600s v_time: 0.0306s
# Epoch: 0236 loss_train: 0.2118 acc_train: 0.9316 loss_val: 0.8891 acc_val: 0.7571 cur_lr: 0.02000 s_time: 0.0034s t_time: 0.0718s v_time: 0.0260s
# Epoch: 0237 loss_train: 0.2552 acc_train: 0.9215 loss_val: 0.8781 acc_val: 0.7588 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0645s v_time: 0.0267s
# Epoch: 0238 loss_train: 0.2397 acc_train: 0.9282 loss_val: 0.8998 acc_val: 0.7554 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0600s v_time: 0.0306s
# Epoch: 0239 loss_train: 0.2667 acc_train: 0.9249 loss_val: 0.8721 acc_val: 0.7529 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0774s v_time: 0.0267s
# Epoch: 0240 loss_train: 0.3062 acc_train: 0.9316 loss_val: 0.8971 acc_val: 0.7604 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0601s v_time: 0.0308s
# Epoch: 0241 loss_train: 0.2167 acc_train: 0.9265 loss_val: 0.9304 acc_val: 0.7588 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0764s v_time: 0.0271s
# Epoch: 0242 loss_train: 0.2455 acc_train: 0.9299 loss_val: 0.8966 acc_val: 0.7638 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0606s v_time: 0.0314s
# Epoch: 0243 loss_train: 0.2021 acc_train: 0.9399 loss_val: 0.9450 acc_val: 0.7412 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0751s v_time: 0.0259s
# Epoch: 0244 loss_train: 0.1826 acc_train: 0.9399 loss_val: 0.9334 acc_val: 0.7513 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0603s v_time: 0.0311s
# Epoch: 0245 loss_train: 0.2358 acc_train: 0.9282 loss_val: 0.9388 acc_val: 0.7629 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0767s v_time: 0.0266s
# Epoch: 0246 loss_train: 0.2256 acc_train: 0.9316 loss_val: 0.9118 acc_val: 0.7621 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0598s v_time: 0.0306s
# Epoch: 0247 loss_train: 0.1975 acc_train: 0.9282 loss_val: 0.9658 acc_val: 0.7621 cur_lr: 0.02000 s_time: 0.0034s t_time: 0.0764s v_time: 0.0266s
# Epoch: 0248 loss_train: 0.1847 acc_train: 0.9482 loss_val: 1.0241 acc_val: 0.7588 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0599s v_time: 0.0306s
# Epoch: 0249 loss_train: 0.2143 acc_train: 0.9299 loss_val: 1.0922 acc_val: 0.7513 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0758s v_time: 0.0336s
# Epoch: 0250 loss_train: 0.2228 acc_train: 0.9399 loss_val: 0.9368 acc_val: 0.7780 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0755s v_time: 0.0258s
# Epoch: 0251 loss_train: 0.2948 acc_train: 0.9215 loss_val: 1.0000 acc_val: 0.7604 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0598s v_time: 0.0304s
# Epoch: 0252 loss_train: 0.2111 acc_train: 0.9349 loss_val: 0.9560 acc_val: 0.7646 cur_lr: 0.02000 s_time: 0.0034s t_time: 0.0765s v_time: 0.0328s
# Epoch: 0253 loss_train: 0.2156 acc_train: 0.9399 loss_val: 0.8406 acc_val: 0.7730 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0764s v_time: 0.0258s
# Epoch: 0254 loss_train: 0.2522 acc_train: 0.9382 loss_val: 0.9466 acc_val: 0.7546 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0601s v_time: 0.0304s
# Epoch: 0255 loss_train: 0.2254 acc_train: 0.9399 loss_val: 1.0148 acc_val: 0.7429 cur_lr: 0.02000 s_time: 0.0035s t_time: 0.0764s v_time: 0.0328s
# Epoch: 0256 loss_train: 0.2450 acc_train: 0.9316 loss_val: 0.9169 acc_val: 0.7579 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0766s v_time: 0.0265s
# Epoch: 0257 loss_train: 0.2873 acc_train: 0.9249 loss_val: 0.9201 acc_val: 0.7563 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0601s v_time: 0.0306s
# Epoch: 0258 loss_train: 0.2735 acc_train: 0.9282 loss_val: 0.9163 acc_val: 0.7579 cur_lr: 0.02000 s_time: 0.0035s t_time: 0.0765s v_time: 0.0259s
# Epoch: 0259 loss_train: 0.2580 acc_train: 0.9316 loss_val: 0.8289 acc_val: 0.7596 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0600s v_time: 0.0305s
# Epoch: 0260 loss_train: 0.2178 acc_train: 0.9366 loss_val: 0.8797 acc_val: 0.7571 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0772s v_time: 0.0265s
# Epoch: 0261 loss_train: 0.2271 acc_train: 0.9382 loss_val: 0.9149 acc_val: 0.7613 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0600s v_time: 0.0307s
# Epoch: 0262 loss_train: 0.2441 acc_train: 0.9199 loss_val: 0.8674 acc_val: 0.7554 cur_lr: 0.02000 s_time: 0.0032s t_time: 0.0763s v_time: 0.0331s
# Epoch: 0263 loss_train: 0.2151 acc_train: 0.9265 loss_val: 0.8442 acc_val: 0.7705 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0775s v_time: 0.0264s
# Epoch: 0264 loss_train: 0.2219 acc_train: 0.9416 loss_val: 0.8957 acc_val: 0.7696 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0602s v_time: 0.0305s
# Epoch: 0265 loss_train: 0.2164 acc_train: 0.9282 loss_val: 0.8578 acc_val: 0.7596 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0770s v_time: 0.0266s
# Epoch: 0266 loss_train: 0.2421 acc_train: 0.9332 loss_val: 0.8533 acc_val: 0.7846 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0600s v_time: 0.0308s
# Epoch: 0267 loss_train: 0.2051 acc_train: 0.9349 loss_val: 0.8225 acc_val: 0.7638 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0766s v_time: 0.0270s
# Epoch: 0268 loss_train: 0.2091 acc_train: 0.9316 loss_val: 0.8876 acc_val: 0.7604 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0597s v_time: 0.0305s
# Epoch: 0269 loss_train: 0.1958 acc_train: 0.9432 loss_val: 0.9822 acc_val: 0.7387 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0765s v_time: 0.0268s
# Epoch: 0270 loss_train: 0.2019 acc_train: 0.9349 loss_val: 0.8775 acc_val: 0.7705 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0598s v_time: 0.0305s
# Epoch: 0271 loss_train: 0.2217 acc_train: 0.9316 loss_val: 0.9113 acc_val: 0.7513 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0751s v_time: 0.0257s
# Epoch: 0272 loss_train: 0.2487 acc_train: 0.9316 loss_val: 0.8342 acc_val: 0.7613 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0585s v_time: 0.0289s
# Epoch: 0273 loss_train: 0.2668 acc_train: 0.9249 loss_val: 0.8893 acc_val: 0.7563 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0655s v_time: 0.0257s
# Epoch: 0274 loss_train: 0.2612 acc_train: 0.9249 loss_val: 0.9222 acc_val: 0.7579 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0666s v_time: 0.0265s
# Epoch: 0275 loss_train: 0.2284 acc_train: 0.9215 loss_val: 0.9015 acc_val: 0.7613 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0598s v_time: 0.0305s
# Epoch: 0276 loss_train: 0.2859 acc_train: 0.9232 loss_val: 0.8754 acc_val: 0.7462 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0755s v_time: 0.0257s
# Epoch: 0277 loss_train: 0.2390 acc_train: 0.9332 loss_val: 0.8507 acc_val: 0.7613 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0600s v_time: 0.0304s
# Epoch: 0278 loss_train: 0.1889 acc_train: 0.9416 loss_val: 0.8853 acc_val: 0.7679 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0760s v_time: 0.0333s
# Epoch: 0279 loss_train: 0.2299 acc_train: 0.9316 loss_val: 1.0199 acc_val: 0.7312 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0588s v_time: 0.0251s
# Epoch: 0280 loss_train: 0.1939 acc_train: 0.9382 loss_val: 0.9229 acc_val: 0.7462 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0679s v_time: 0.0257s
# Epoch: 0281 loss_train: 0.2511 acc_train: 0.9349 loss_val: 0.8479 acc_val: 0.7671 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0638s v_time: 0.0266s
# Epoch: 0282 loss_train: 0.1627 acc_train: 0.9549 loss_val: 0.8610 acc_val: 0.7738 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0600s v_time: 0.0306s
# Epoch: 0283 loss_train: 0.2250 acc_train: 0.9432 loss_val: 0.8598 acc_val: 0.7679 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0760s v_time: 0.0332s
# Epoch: 0284 loss_train: 0.1891 acc_train: 0.9482 loss_val: 0.8758 acc_val: 0.7763 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0764s v_time: 0.0330s
# Epoch: 0285 loss_train: 0.2059 acc_train: 0.9249 loss_val: 0.9288 acc_val: 0.7805 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0764s v_time: 0.0265s
# Epoch: 0286 loss_train: 0.2341 acc_train: 0.9232 loss_val: 0.8526 acc_val: 0.7679 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0601s v_time: 0.0307s
# Epoch: 0287 loss_train: 0.2762 acc_train: 0.9132 loss_val: 0.8845 acc_val: 0.7646 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0729s v_time: 0.0253s
# Epoch: 0288 loss_train: 0.2071 acc_train: 0.9332 loss_val: 0.8941 acc_val: 0.7471 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0586s v_time: 0.0322s
# Epoch: 0289 loss_train: 0.2758 acc_train: 0.9265 loss_val: 0.8685 acc_val: 0.7713 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0759s v_time: 0.0333s
# Epoch: 0290 loss_train: 0.2182 acc_train: 0.9265 loss_val: 0.9012 acc_val: 0.7554 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0776s v_time: 0.0257s
# Epoch: 0291 loss_train: 0.2198 acc_train: 0.9399 loss_val: 0.8761 acc_val: 0.7621 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0599s v_time: 0.0305s
# Epoch: 0292 loss_train: 0.1956 acc_train: 0.9482 loss_val: 0.9142 acc_val: 0.7421 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0766s v_time: 0.0266s
# Epoch: 0293 loss_train: 0.2347 acc_train: 0.9199 loss_val: 0.9269 acc_val: 0.7487 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0601s v_time: 0.0311s
# Epoch: 0294 loss_train: 0.2297 acc_train: 0.9232 loss_val: 0.8876 acc_val: 0.7654 cur_lr: 0.02000 s_time: 0.0032s t_time: 0.0705s v_time: 0.0259s
# Epoch: 0295 loss_train: 0.2813 acc_train: 0.9215 loss_val: 0.9317 acc_val: 0.7604 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0645s v_time: 0.0256s
# Epoch: 0296 loss_train: 0.2524 acc_train: 0.9232 loss_val: 0.9187 acc_val: 0.7763 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0602s v_time: 0.0304s
# Epoch: 0297 loss_train: 0.2343 acc_train: 0.9332 loss_val: 0.9062 acc_val: 0.7513 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0764s v_time: 0.0332s
# Epoch: 0298 loss_train: 0.2583 acc_train: 0.9316 loss_val: 0.8897 acc_val: 0.7738 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0767s v_time: 0.0261s
# Epoch: 0299 loss_train: 0.1805 acc_train: 0.9382 loss_val: 0.9736 acc_val: 0.7479 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0599s v_time: 0.0307s
# Epoch: 0300 loss_train: 0.2433 acc_train: 0.9265 loss_val: 0.9095 acc_val: 0.7646 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0673s v_time: 0.0261s
# Epoch: 0301 loss_train: 0.2147 acc_train: 0.9382 loss_val: 0.8897 acc_val: 0.7571 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0667s v_time: 0.0268s
# Epoch: 0302 loss_train: 0.2108 acc_train: 0.9382 loss_val: 0.9695 acc_val: 0.7487 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0598s v_time: 0.0311s
# Epoch: 0303 loss_train: 0.2303 acc_train: 0.9366 loss_val: 0.9171 acc_val: 0.7563 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0774s v_time: 0.0335s
# Epoch: 0304 loss_train: 0.2629 acc_train: 0.9232 loss_val: 0.8717 acc_val: 0.7713 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0758s v_time: 0.0265s
# Epoch: 0305 loss_train: 0.1593 acc_train: 0.9466 loss_val: 0.8841 acc_val: 0.7788 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0600s v_time: 0.0305s
# Epoch: 0306 loss_train: 0.2098 acc_train: 0.9449 loss_val: 0.8665 acc_val: 0.7913 cur_lr: 0.02000 s_time: 0.0035s t_time: 0.0766s v_time: 0.0331s
# Epoch: 0307 loss_train: 0.2353 acc_train: 0.9265 loss_val: 0.9487 acc_val: 0.7705 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0691s v_time: 0.0257s
# Epoch: 0308 loss_train: 0.2227 acc_train: 0.9366 loss_val: 0.8921 acc_val: 0.7713 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0670s v_time: 0.0265s
# Epoch: 0309 loss_train: 0.2183 acc_train: 0.9265 loss_val: 0.8564 acc_val: 0.7888 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0601s v_time: 0.0311s
# Epoch: 0310 loss_train: 0.2375 acc_train: 0.9165 loss_val: 0.9184 acc_val: 0.7654 cur_lr: 0.02000 s_time: 0.0032s t_time: 0.0774s v_time: 0.0268s
# Epoch: 0311 loss_train: 0.2039 acc_train: 0.9382 loss_val: 0.8576 acc_val: 0.7888 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0600s v_time: 0.0308s
# Epoch: 0312 loss_train: 0.2332 acc_train: 0.9299 loss_val: 0.8337 acc_val: 0.7780 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0766s v_time: 0.0265s
# Epoch: 0313 loss_train: 0.2647 acc_train: 0.9065 loss_val: 0.9159 acc_val: 0.7746 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0596s v_time: 0.0305s
# Epoch: 0314 loss_train: 0.2117 acc_train: 0.9199 loss_val: 0.9490 acc_val: 0.7613 cur_lr: 0.02000 s_time: 0.0034s t_time: 0.0728s v_time: 0.0257s
# Epoch: 0315 loss_train: 0.2592 acc_train: 0.9349 loss_val: 0.9436 acc_val: 0.7613 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0636s v_time: 0.0257s
# Epoch: 0316 loss_train: 0.2571 acc_train: 0.9265 loss_val: 0.9347 acc_val: 0.7588 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0599s v_time: 0.0303s
# Epoch: 0317 loss_train: 0.2725 acc_train: 0.9316 loss_val: 0.8643 acc_val: 0.7679 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0750s v_time: 0.0334s
# Epoch: 0318 loss_train: 0.2722 acc_train: 0.9249 loss_val: 0.9498 acc_val: 0.7663 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0766s v_time: 0.0268s
# Epoch: 0319 loss_train: 0.2290 acc_train: 0.9316 loss_val: 0.9635 acc_val: 0.7462 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0600s v_time: 0.0305s
# Epoch: 0320 loss_train: 0.2095 acc_train: 0.9399 loss_val: 0.9641 acc_val: 0.7496 cur_lr: 0.02000 s_time: 0.0034s t_time: 0.0763s v_time: 0.0270s
# Epoch: 0321 loss_train: 0.2179 acc_train: 0.9316 loss_val: 0.9542 acc_val: 0.7396 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0598s v_time: 0.0307s
# Epoch: 0322 loss_train: 0.2456 acc_train: 0.9182 loss_val: 0.9261 acc_val: 0.7429 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0770s v_time: 0.0261s
# Epoch: 0323 loss_train: 0.1959 acc_train: 0.9416 loss_val: 1.0222 acc_val: 0.7412 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0607s v_time: 0.0306s
# Epoch: 0324 loss_train: 0.2557 acc_train: 0.9082 loss_val: 0.9102 acc_val: 0.7654 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0760s v_time: 0.0328s
# Epoch: 0325 loss_train: 0.2585 acc_train: 0.9182 loss_val: 0.8992 acc_val: 0.7571 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0752s v_time: 0.0338s
# Epoch: 0326 loss_train: 0.2206 acc_train: 0.9366 loss_val: 0.9622 acc_val: 0.7504 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0769s v_time: 0.0257s
# Epoch: 0327 loss_train: 0.2829 acc_train: 0.9249 loss_val: 0.9296 acc_val: 0.7479 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0600s v_time: 0.0303s
# Epoch: 0328 loss_train: 0.2061 acc_train: 0.9432 loss_val: 0.9614 acc_val: 0.7579 cur_lr: 0.02000 s_time: 0.0036s t_time: 0.0719s v_time: 0.0259s
# ...
# Epoch: 0393 loss_train: 0.2440 acc_train: 0.9299 loss_val: 0.9220 acc_val: 0.7588 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0600s v_time: 0.0303s
# Epoch: 0394 loss_train: 0.2304 acc_train: 0.9316 loss_val: 0.9416 acc_val: 0.7604 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0765s v_time: 0.0266s
# Epoch: 0395 loss_train: 0.2428 acc_train: 0.9316 loss_val: 0.9515 acc_val: 0.7479 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0599s v_time: 0.0306s
# Epoch: 0396 loss_train: 0.2360 acc_train: 0.9332 loss_val: 0.9110 acc_val: 0.7696 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0759s v_time: 0.0258s
# Epoch: 0397 loss_train: 0.2628 acc_train: 0.9215 loss_val: 0.8708 acc_val: 0.7629 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0599s v_time: 0.0305s
# Epoch: 0398 loss_train: 0.2479 acc_train: 0.9265 loss_val: 0.9160 acc_val: 0.7613 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0765s v_time: 0.0262s
# Epoch: 0399 loss_train: 0.2215 acc_train: 0.9199 loss_val: 0.8978 acc_val: 0.7521 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0607s v_time: 0.0314s
# Epoch: 0400 loss_train: 0.2392 acc_train: 0.9215 loss_val: 0.9142 acc_val: 0.7521 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0775s v_time: 0.0265s
# Epoch: 0401 loss_train: 0.2435 acc_train: 0.9282 loss_val: 0.9177 acc_val: 0.7588 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0604s v_time: 0.0312s
# Epoch: 0402 loss_train: 0.2184 acc_train: 0.9349 loss_val: 0.8495 acc_val: 0.7621 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0771s v_time: 0.0266s
# Epoch: 0403 loss_train: 0.1988 acc_train: 0.9432 loss_val: 0.8976 acc_val: 0.7579 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0598s v_time: 0.0306s
# Epoch: 0404 loss_train: 0.2424 acc_train: 0.9349 loss_val: 0.8704 acc_val: 0.7654 cur_lr: 0.02000 s_time: 0.0034s t_time: 0.0763s v_time: 0.0330s
# Epoch: 0405 loss_train: 0.2086 acc_train: 0.9316 loss_val: 0.9066 acc_val: 0.7696 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0751s v_time: 0.0268s
# Epoch: 0406 loss_train: 0.2193 acc_train: 0.9416 loss_val: 0.8959 acc_val: 0.7696 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0599s v_time: 0.0305s
# Epoch: 0407 loss_train: 0.2270 acc_train: 0.9332 loss_val: 0.9172 acc_val: 0.7638 cur_lr: 0.02000 s_time: 0.0035s t_time: 0.0724s v_time: 0.0258s
# Epoch: 0408 loss_train: 0.1843 acc_train: 0.9366 loss_val: 0.9468 acc_val: 0.7663 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0638s v_time: 0.0259s
# Epoch: 0409 loss_train: 0.2844 acc_train: 0.9149 loss_val: 1.0150 acc_val: 0.7521 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0597s v_time: 0.0305s
# Epoch: 0410 loss_train: 0.2652 acc_train: 0.9149 loss_val: 0.9245 acc_val: 0.7713 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0765s v_time: 0.0329s
# Epoch: 0411 loss_train: 0.1995 acc_train: 0.9299 loss_val: 0.9342 acc_val: 0.7654 cur_lr: 0.02000 s_time: 0.0032s t_time: 0.0766s v_time: 0.0266s
# Epoch: 0412 loss_train: 0.2021 acc_train: 0.9316 loss_val: 0.9279 acc_val: 0.7654 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0599s v_time: 0.0383s
# Epoch: 0413 loss_train: 0.2737 acc_train: 0.9299 loss_val: 0.9466 acc_val: 0.7579 cur_lr: 0.02000 s_time: 0.0034s t_time: 0.0621s v_time: 0.0256s
# Epoch: 0414 loss_train: 0.2827 acc_train: 0.9282 loss_val: 0.9274 acc_val: 0.7487 cur_lr: 0.02000 s_time: 0.0032s t_time: 0.0710s v_time: 0.0313s
# Epoch: 0415 loss_train: 0.1998 acc_train: 0.9482 loss_val: 0.8591 acc_val: 0.7705 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0717s v_time: 0.0311s
# Epoch: 0416 loss_train: 0.2150 acc_train: 0.9382 loss_val: 0.9362 acc_val: 0.7538 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0708s v_time: 0.0319s
# Epoch: 0417 loss_train: 0.2446 acc_train: 0.9416 loss_val: 0.9338 acc_val: 0.7588 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0713s v_time: 0.0314s
# Epoch: 0418 loss_train: 0.2013 acc_train: 0.9232 loss_val: 0.8862 acc_val: 0.7696 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0710s v_time: 0.0313s
# Epoch: 0419 loss_train: 0.2341 acc_train: 0.9299 loss_val: 0.8689 acc_val: 0.7671 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0712s v_time: 0.0278s
# Epoch: 0420 loss_train: 0.2323 acc_train: 0.9215 loss_val: 0.8799 acc_val: 0.7679 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0600s v_time: 0.0284s
# Epoch: 0421 loss_train: 0.2032 acc_train: 0.9382 loss_val: 0.9425 acc_val: 0.7538 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0714s v_time: 0.0317s
# Epoch: 0422 loss_train: 0.1988 acc_train: 0.9416 loss_val: 0.9085 acc_val: 0.7638 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0715s v_time: 0.0308s
# Epoch: 0423 loss_train: 0.2642 acc_train: 0.9149 loss_val: 0.9043 acc_val: 0.7763 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0707s v_time: 0.0313s
# Epoch: 0424 loss_train: 0.2285 acc_train: 0.9349 loss_val: 0.8879 acc_val: 0.7654 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0708s v_time: 0.0312s
# Epoch: 0425 loss_train: 0.2380 acc_train: 0.9215 loss_val: 0.8813 acc_val: 0.7688 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0711s v_time: 0.0316s
# Epoch: 0426 loss_train: 0.2109 acc_train: 0.9449 loss_val: 0.8297 acc_val: 0.7654 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0711s v_time: 0.0260s
# Epoch: 0427 loss_train: 0.2529 acc_train: 0.9249 loss_val: 0.9179 acc_val: 0.7479 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0589s v_time: 0.0289s
# Epoch: 0428 loss_train: 0.1980 acc_train: 0.9349 loss_val: 0.8334 acc_val: 0.7679 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0712s v_time: 0.0310s
# Epoch: 0429 loss_train: 0.1928 acc_train: 0.9449 loss_val: 0.8587 acc_val: 0.7688 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0713s v_time: 0.0316s
# Epoch: 0430 loss_train: 0.2174 acc_train: 0.9349 loss_val: 0.8629 acc_val: 0.7679 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0708s v_time: 0.0306s
# Epoch: 0431 loss_train: 0.2456 acc_train: 0.9249 loss_val: 0.8892 acc_val: 0.7588 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0708s v_time: 0.0321s
# Epoch: 0432 loss_train: 0.1963 acc_train: 0.9449 loss_val: 0.8794 acc_val: 0.7713 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0708s v_time: 0.0315s
# Epoch: 0433 loss_train: 0.2421 acc_train: 0.9332 loss_val: 0.8398 acc_val: 0.7755 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0716s v_time: 0.0277s
# Epoch: 0434 loss_train: 0.2219 acc_train: 0.9316 loss_val: 0.8999 acc_val: 0.7554 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0589s v_time: 0.0281s
# Epoch: 0435 loss_train: 0.2500 acc_train: 0.9182 loss_val: 0.9099 acc_val: 0.7621 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0711s v_time: 0.0309s
# Epoch: 0436 loss_train: 0.1954 acc_train: 0.9432 loss_val: 0.8498 acc_val: 0.7621 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0715s v_time: 0.0318s
# Epoch: 0437 loss_train: 0.2292 acc_train: 0.9299 loss_val: 0.8859 acc_val: 0.7696 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0706s v_time: 0.0314s
# Epoch: 0438 loss_train: 0.1943 acc_train: 0.9349 loss_val: 0.9442 acc_val: 0.7646 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0712s v_time: 0.0312s
# Epoch: 0439 loss_train: 0.2280 acc_train: 0.9399 loss_val: 0.9292 acc_val: 0.7563 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0713s v_time: 0.0310s
# Epoch: 0440 loss_train: 0.2147 acc_train: 0.9316 loss_val: 0.9105 acc_val: 0.7613 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0731s v_time: 0.0259s
# Epoch: 0441 loss_train: 0.2054 acc_train: 0.9265 loss_val: 0.9229 acc_val: 0.7571 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0589s v_time: 0.0294s
# Epoch: 0442 loss_train: 0.2122 acc_train: 0.9382 loss_val: 0.9071 acc_val: 0.7563 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0714s v_time: 0.0307s
# Epoch: 0443 loss_train: 0.2108 acc_train: 0.9349 loss_val: 0.9840 acc_val: 0.7421 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0714s v_time: 0.0308s
# Epoch: 0444 loss_train: 0.2296 acc_train: 0.9215 loss_val: 0.8762 acc_val: 0.7688 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0590s v_time: 0.0254s
# Epoch: 0445 loss_train: 0.2158 acc_train: 0.9399 loss_val: 0.9310 acc_val: 0.7579 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0695s v_time: 0.0310s
# Epoch: 0446 loss_train: 0.1934 acc_train: 0.9432 loss_val: 0.8588 acc_val: 0.7705 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0717s v_time: 0.0308s
# Epoch: 0447 loss_train: 0.2714 acc_train: 0.9149 loss_val: 0.8811 acc_val: 0.7546 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0705s v_time: 0.0277s
# Epoch: 0448 loss_train: 0.2318 acc_train: 0.9449 loss_val: 0.8586 acc_val: 0.7696 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0590s v_time: 0.0274s
# Epoch: 0449 loss_train: 0.2322 acc_train: 0.9282 loss_val: 0.8849 acc_val: 0.7646 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0721s v_time: 0.0306s
# Epoch: 0450 loss_train: 0.2414 acc_train: 0.9282 loss_val: 0.9179 acc_val: 0.7563 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0710s v_time: 0.0316s
# Epoch: 0451 loss_train: 0.1993 acc_train: 0.9366 loss_val: 0.9052 acc_val: 0.7563 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0708s v_time: 0.0310s
# Epoch: 0452 loss_train: 0.2958 acc_train: 0.9165 loss_val: 0.9128 acc_val: 0.7563 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0710s v_time: 0.0309s
# Epoch: 0453 loss_train: 0.2189 acc_train: 0.9416 loss_val: 0.8722 acc_val: 0.7688 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0707s v_time: 0.0311s
# Epoch: 0454 loss_train: 0.1925 acc_train: 0.9349 loss_val: 0.9191 acc_val: 0.7613 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0711s v_time: 0.0259s
# Epoch: 0455 loss_train: 0.1934 acc_train: 0.9349 loss_val: 1.0009 acc_val: 0.7504 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0588s v_time: 0.0291s
# Epoch: 0456 loss_train: 0.1784 acc_train: 0.9399 loss_val: 0.9406 acc_val: 0.7613 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0712s v_time: 0.0308s
# Epoch: 0457 loss_train: 0.2502 acc_train: 0.9265 loss_val: 0.9641 acc_val: 0.7579 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0714s v_time: 0.0321s
# Epoch: 0458 loss_train: 0.2305 acc_train: 0.9215 loss_val: 0.9481 acc_val: 0.7671 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0717s v_time: 0.0316s
# Epoch: 0459 loss_train: 0.2569 acc_train: 0.9332 loss_val: 0.9502 acc_val: 0.7638 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0718s v_time: 0.0314s
# Epoch: 0460 loss_train: 0.1762 acc_train: 0.9466 loss_val: 0.9291 acc_val: 0.7604 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0719s v_time: 0.0314s
# Epoch: 0461 loss_train: 0.2565 acc_train: 0.9316 loss_val: 0.9932 acc_val: 0.7538 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0699s v_time: 0.0257s
# Epoch: 0462 loss_train: 0.2394 acc_train: 0.9282 loss_val: 0.9909 acc_val: 0.7521 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0588s v_time: 0.0302s
# Epoch: 0463 loss_train: 0.2403 acc_train: 0.9299 loss_val: 0.9571 acc_val: 0.7730 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0713s v_time: 0.0307s
# Epoch: 0464 loss_train: 0.2261 acc_train: 0.9349 loss_val: 1.0024 acc_val: 0.7638 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0707s v_time: 0.0309s
# Epoch: 0465 loss_train: 0.2710 acc_train: 0.9265 loss_val: 0.9923 acc_val: 0.7563 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0707s v_time: 0.0311s
# Epoch: 0466 loss_train: 0.1761 acc_train: 0.9482 loss_val: 0.9483 acc_val: 0.7654 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0705s v_time: 0.0308s
# Epoch: 0467 loss_train: 0.2180 acc_train: 0.9316 loss_val: 0.9533 acc_val: 0.7471 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0706s v_time: 0.0311s
# Epoch: 0468 loss_train: 0.2537 acc_train: 0.9265 loss_val: 1.0079 acc_val: 0.7538 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0689s v_time: 0.0257s
# Epoch: 0469 loss_train: 0.2016 acc_train: 0.9399 loss_val: 0.9585 acc_val: 0.7646 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0594s v_time: 0.0313s
# Epoch: 0470 loss_train: 0.1984 acc_train: 0.9449 loss_val: 0.9240 acc_val: 0.7638 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0715s v_time: 0.0308s
# Epoch: 0471 loss_train: 0.2378 acc_train: 0.9366 loss_val: 0.9460 acc_val: 0.7604 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0711s v_time: 0.0312s
# Epoch: 0472 loss_train: 0.1749 acc_train: 0.9482 loss_val: 1.0058 acc_val: 0.7454 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0709s v_time: 0.0322s
# Epoch: 0473 loss_train: 0.2222 acc_train: 0.9332 loss_val: 0.9162 acc_val: 0.7513 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0709s v_time: 0.0313s
# Epoch: 0474 loss_train: 0.2192 acc_train: 0.9399 loss_val: 1.0408 acc_val: 0.7446 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0709s v_time: 0.0312s
# Epoch: 0475 loss_train: 0.2858 acc_train: 0.9232 loss_val: 0.9462 acc_val: 0.7496 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0693s v_time: 0.0256s
# Epoch: 0476 loss_train: 0.2099 acc_train: 0.9366 loss_val: 0.9065 acc_val: 0.7563 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0600s v_time: 0.0308s
# Epoch: 0477 loss_train: 0.2952 acc_train: 0.9232 loss_val: 0.9674 acc_val: 0.7462 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0718s v_time: 0.0317s
# Epoch: 0478 loss_train: 0.1991 acc_train: 0.9399 loss_val: 0.9600 acc_val: 0.7454 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0711s v_time: 0.0308s
# Epoch: 0479 loss_train: 0.2100 acc_train: 0.9366 loss_val: 0.9155 acc_val: 0.7487 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0712s v_time: 0.0317s
# Epoch: 0480 loss_train: 0.1995 acc_train: 0.9382 loss_val: 0.9889 acc_val: 0.7437 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0710s v_time: 0.0308s
# Epoch: 0481 loss_train: 0.2475 acc_train: 0.9265 loss_val: 0.9362 acc_val: 0.7646 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0709s v_time: 0.0311s
# Epoch: 0482 loss_train: 0.2826 acc_train: 0.9098 loss_val: 0.9088 acc_val: 0.7713 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0694s v_time: 0.0256s
# Epoch: 0483 loss_train: 0.2217 acc_train: 0.9265 loss_val: 0.9753 acc_val: 0.7437 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0603s v_time: 0.0306s
# Epoch: 0484 loss_train: 0.2365 acc_train: 0.9265 loss_val: 0.9700 acc_val: 0.7379 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0717s v_time: 0.0314s
# Epoch: 0485 loss_train: 0.1706 acc_train: 0.9432 loss_val: 0.9599 acc_val: 0.7538 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0705s v_time: 0.0309s
# Epoch: 0486 loss_train: 0.2253 acc_train: 0.9316 loss_val: 0.9337 acc_val: 0.7454 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0708s v_time: 0.0311s
# Epoch: 0487 loss_train: 0.2021 acc_train: 0.9265 loss_val: 0.9010 acc_val: 0.7538 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0705s v_time: 0.0323s
# Epoch: 0488 loss_train: 0.2242 acc_train: 0.9332 loss_val: 0.8839 acc_val: 0.7638 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0704s v_time: 0.0314s
# Epoch: 0489 loss_train: 0.1926 acc_train: 0.9382 loss_val: 0.9160 acc_val: 0.7688 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0688s v_time: 0.0255s
# Epoch: 0490 loss_train: 0.1930 acc_train: 0.9432 loss_val: 0.9487 acc_val: 0.7596 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0606s v_time: 0.0308s
# Epoch: 0491 loss_train: 0.1851 acc_train: 0.9399 loss_val: 0.9048 acc_val: 0.7654 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0714s v_time: 0.0316s
# Epoch: 0492 loss_train: 0.2223 acc_train: 0.9282 loss_val: 0.9288 acc_val: 0.7730 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0709s v_time: 0.0307s
# Epoch: 0493 loss_train: 0.1769 acc_train: 0.9399 loss_val: 0.9554 acc_val: 0.7696 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0704s v_time: 0.0314s
# Epoch: 0494 loss_train: 0.1933 acc_train: 0.9366 loss_val: 1.0280 acc_val: 0.7538 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0708s v_time: 0.0319s
# Epoch: 0495 loss_train: 0.2201 acc_train: 0.9232 loss_val: 0.9085 acc_val: 0.7771 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0713s v_time: 0.0314s
# Epoch: 0496 loss_train: 0.2229 acc_train: 0.9215 loss_val: 0.9504 acc_val: 0.7696 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0664s v_time: 0.0259s
# Epoch: 0497 loss_train: 0.2084 acc_train: 0.9282 loss_val: 0.9799 acc_val: 0.7588 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0647s v_time: 0.0315s
# Epoch: 0498 loss_train: 0.2077 acc_train: 0.9249 loss_val: 0.9698 acc_val: 0.7604 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0719s v_time: 0.0313s
# Epoch: 0499 loss_train: 0.2097 acc_train: 0.9366 loss_val: 0.9269 acc_val: 0.7663 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0717s v_time: 0.0309s
# Epoch: 0500 loss_train: 0.1530 acc_train: 0.9466 loss_val: 0.9552 acc_val: 0.7679 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0705s v_time: 0.0313s
# Optimization Finished!
# Total time elapsed: 49.8889s
# Test set results: loss= 0.4578 auc= 0.9784 accuracy= 0.8564
# accuracy=0.85643
# 0.152977	0.955245	0.457769	0.946578	0.767947	0.856427
# Cora_ML
# Mean Epoch Times: 0.002951341152191162

# %%
# define the training function.
def train(epoch, train_adj, train_fea, idx_train, val_adj=None, val_fea=None):
    if val_adj is None:
        val_adj = train_adj
        val_fea = train_fea

    t = time.time()
    model.train()
    optimizer.zero_grad()
    output = model(train_fea, train_adj)
    # special for reddit
    if sampler.learning_type == "inductive":
        loss_train = F.nll_loss(output, labels[idx_train])
        acc_train = accuracy(output, labels[idx_train])
    else:
        loss_train = F.nll_loss(output[idx_train], labels[idx_train])
        acc_train = accuracy(output[idx_train], labels[idx_train])

    loss_train.backward()
    optimizer.step()
    train_t = time.time() - t
    val_t = time.time()
    # We can not apply the fastmode for the reddit dataset.
    # if sampler.learning_type == "inductive" or not args.fastmode:

    if early_stopping > 0 and sampler.dataset != "reddit":
        loss_val = F.nll_loss(output[idx_val], labels[idx_val]).item()
        early_stopping(loss_val, model)

    if not fastmode:
        #    # Evaluate validation set performance separately,
        #    # deactivates dropout during validation run.
        model.eval()
        output = model(val_fea, val_adj)
        loss_val = F.nll_loss(output[idx_val], labels[idx_val]).item()
        acc_val = accuracy(output[idx_val], labels[idx_val]).item()
        if sampler.dataset == "reddit":
            early_stopping(loss_val, model)
    else:
        loss_val = 0
        acc_val = 0

    if lradjust:
        scheduler.step()

    val_t = time.time() - val_t
    return (loss_train.item(), acc_train.item(), loss_val, acc_val, get_lr(optimizer), train_t, val_t)


def test(test_adj, test_fea):
    model.eval()
    output = model(test_fea, test_adj)
    loss_test = F.nll_loss(output[idx_test], labels[idx_test])
    acc_test = accuracy(output[idx_test], labels[idx_test])
    auc_test = roc_auc_compute_fn(output[idx_test], labels[idx_test])
    if debug:
        print("Test set results:",
              "loss= {:.4f}".format(loss_test.item()),
              "auc= {:.4f}".format(auc_test),
              "accuracy= {:.4f}".format(acc_test.item()))
        print("accuracy=%.5f" % (acc_test.item()))
    return (loss_test.item(), acc_test.item())


# Train model
t_total = time.time()
loss_train = np.zeros((epochs,))
acc_train = np.zeros((epochs,))
loss_val = np.zeros((epochs,))
acc_val = np.zeros((epochs,))

sampling_t = 0

EpochTimes = []

for epoch in range(epochs):
    input_idx_train = idx_train
    sampling_t = time.time()
    # no sampling
    # randomedge sampling if args.sampling_percent >= 1.0, it behaves the same as stub_sampler.
    (train_adj, train_fea) = sampler.randomedge_sampler(percent=sampling_percent, normalization=normalization,
                                                        cuda=cuda)
    if mixmode:
        train_adj = train_adj.cuda()

    sampling_t = time.time() - sampling_t
    
    EpochTimes.append(sampling_t)
    
    # The validation set is controlled by idx_val
    # if sampler.learning_type == "transductive":
    if is_train:
        outputs = train(epoch, train_adj, train_fea, input_idx_train)
    else:
        (val_adj, val_fea) = sampler.get_test_set(normalization=normalization, cuda=cuda)
        if mixmode:
            val_adj = val_adj.cuda()
        outputs = train(epoch, train_adj, train_fea, input_idx_train, val_adj, val_fea)

    if debug and epoch % 1 == 0:
        print('Epoch: {:04d}'.format(epoch + 1),
              'loss_train: {:.4f}'.format(outputs[0]),
              'acc_train: {:.4f}'.format(outputs[1]),
              'loss_val: {:.4f}'.format(outputs[2]),
              'acc_val: {:.4f}'.format(outputs[3]),
              'cur_lr: {:.5f}'.format(outputs[4]),
              's_time: {:.4f}s'.format(sampling_t),
              't_time: {:.4f}s'.format(outputs[5]),
              'v_time: {:.4f}s'.format(outputs[6]))
    
    loss_train[epoch], acc_train[epoch], loss_val[epoch], acc_val[epoch] = outputs[0], outputs[1], outputs[2], outputs[
        3]

    if early_stopping > 0 and early_stopping.early_stop:
        print("Early stopping.")
        model.load_state_dict(early_stopping.load_checkpoint())
        break

if early_stopping > 0:
    model.load_state_dict(early_stopping.load_checkpoint())

if debug:
    print("Optimization Finished!")
    print("Total time elapsed: {:.4f}s".format(time.time() - t_total))
# Out:
# Epoch: 0001 loss_train: 2.0129 acc_train: 0.1429 loss_val: 1.8114 acc_val: 0.2700 cur_lr: 0.02000 s_time: 0.0047s t_time: 0.0423s v_time: 0.0127s
# Epoch: 0002 loss_train: 1.7480 acc_train: 0.3214 loss_val: 1.6105 acc_val: 0.4840 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0307s v_time: 0.0124s
# Epoch: 0003 loss_train: 1.4470 acc_train: 0.5214 loss_val: 1.4628 acc_val: 0.5160 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0309s v_time: 0.0124s
# Epoch: 0004 loss_train: 1.0124 acc_train: 0.7286 loss_val: 1.2433 acc_val: 0.5760 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0305s v_time: 0.0124s
# Epoch: 0005 loss_train: 0.7457 acc_train: 0.7714 loss_val: 1.0301 acc_val: 0.6660 cur_lr: 0.02000 s_time: 0.0023s t_time: 0.0312s v_time: 0.0122s
# Epoch: 0006 loss_train: 0.4334 acc_train: 0.8929 loss_val: 0.9686 acc_val: 0.6900 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0296s v_time: 0.0122s
# Epoch: 0007 loss_train: 0.3529 acc_train: 0.8643 loss_val: 1.3010 acc_val: 0.6460 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0301s v_time: 0.0125s
# Epoch: 0008 loss_train: 0.4009 acc_train: 0.8571 loss_val: 1.3621 acc_val: 0.6560 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0303s v_time: 0.0127s
# Epoch: 0009 loss_train: 0.3249 acc_train: 0.9143 loss_val: 1.7737 acc_val: 0.6180 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0298s v_time: 0.0123s
# Epoch: 0010 loss_train: 0.4523 acc_train: 0.9071 loss_val: 1.6398 acc_val: 0.6620 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0301s v_time: 0.0124s
# Epoch: 0011 loss_train: 0.1889 acc_train: 0.9357 loss_val: 1.7177 acc_val: 0.6600 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0302s v_time: 0.0122s
# Epoch: 0012 loss_train: 0.4246 acc_train: 0.9071 loss_val: 1.7504 acc_val: 0.6240 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0301s v_time: 0.0123s
# Epoch: 0013 loss_train: 0.4481 acc_train: 0.9429 loss_val: 1.6842 acc_val: 0.6500 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0303s v_time: 0.0124s
# Epoch: 0014 loss_train: 0.4087 acc_train: 0.9214 loss_val: 1.8822 acc_val: 0.6280 cur_lr: 0.02000 s_time: 0.0064s t_time: 0.0316s v_time: 0.0124s
# Epoch: 0015 loss_train: 0.3134 acc_train: 0.9357 loss_val: 1.6620 acc_val: 0.6540 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0305s v_time: 0.0123s
# Epoch: 0016 loss_train: 0.1759 acc_train: 0.9500 loss_val: 1.7293 acc_val: 0.6740 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0310s v_time: 0.0123s
# Epoch: 0017 loss_train: 0.1979 acc_train: 0.9643 loss_val: 1.8150 acc_val: 0.6440 cur_lr: 0.02000 s_time: 0.0023s t_time: 0.0293s v_time: 0.0123s
# Epoch: 0018 loss_train: 0.1835 acc_train: 0.9571 loss_val: 1.8926 acc_val: 0.6280 cur_lr: 0.02000 s_time: 0.0023s t_time: 0.0287s v_time: 0.0124s
# Epoch: 0019 loss_train: 0.2457 acc_train: 0.9643 loss_val: 1.7167 acc_val: 0.6400 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0300s v_time: 0.0123s
# Epoch: 0020 loss_train: 0.2461 acc_train: 0.9357 loss_val: 1.9306 acc_val: 0.6000 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0303s v_time: 0.0123s
# Epoch: 0021 loss_train: 0.0975 acc_train: 0.9786 loss_val: 1.9815 acc_val: 0.5660 cur_lr: 0.02000 s_time: 0.0034s t_time: 0.0303s v_time: 0.0123s
# Epoch: 0022 loss_train: 0.1841 acc_train: 0.9714 loss_val: 1.9902 acc_val: 0.5920 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0300s v_time: 0.0123s
# Epoch: 0023 loss_train: 0.3385 acc_train: 0.9500 loss_val: 1.9644 acc_val: 0.5920 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0306s v_time: 0.0123s
# Epoch: 0024 loss_train: 0.1964 acc_train: 0.9500 loss_val: 1.7859 acc_val: 0.6200 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0302s v_time: 0.0122s
# Epoch: 0025 loss_train: 0.1104 acc_train: 0.9643 loss_val: 1.8011 acc_val: 0.6100 cur_lr: 0.02000 s_time: 0.0023s t_time: 0.0295s v_time: 0.0121s
# Epoch: 0026 loss_train: 0.1755 acc_train: 0.9500 loss_val: 1.8913 acc_val: 0.6020 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0289s v_time: 0.0127s
# Epoch: 0027 loss_train: 0.1429 acc_train: 0.9357 loss_val: 1.6066 acc_val: 0.6220 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0298s v_time: 0.0123s
# Epoch: 0028 loss_train: 0.2156 acc_train: 0.9357 loss_val: 1.4639 acc_val: 0.6480 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0301s v_time: 0.0123s
# Epoch: 0029 loss_train: 0.1737 acc_train: 0.9500 loss_val: 1.5884 acc_val: 0.6300 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0301s v_time: 0.0122s
# Epoch: 0030 loss_train: 0.1911 acc_train: 0.9286 loss_val: 1.4424 acc_val: 0.6280 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0301s v_time: 0.0124s
# Epoch: 0031 loss_train: 0.1346 acc_train: 0.9643 loss_val: 1.5253 acc_val: 0.6460 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0306s v_time: 0.0125s
# Epoch: 0032 loss_train: 0.1353 acc_train: 0.9357 loss_val: 1.6353 acc_val: 0.6120 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0299s v_time: 0.0124s
# Epoch: 0033 loss_train: 0.1752 acc_train: 0.9500 loss_val: 1.6532 acc_val: 0.6020 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0298s v_time: 0.0124s
# Epoch: 0034 loss_train: 0.2469 acc_train: 0.9357 loss_val: 1.4716 acc_val: 0.6100 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0299s v_time: 0.0123s
# Epoch: 0035 loss_train: 0.0658 acc_train: 0.9857 loss_val: 1.5561 acc_val: 0.6220 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0300s v_time: 0.0123s
# Epoch: 0036 loss_train: 0.1117 acc_train: 0.9714 loss_val: 1.5406 acc_val: 0.6440 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0305s v_time: 0.0129s
# Epoch: 0037 loss_train: 0.2617 acc_train: 0.9429 loss_val: 1.6787 acc_val: 0.5860 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0301s v_time: 0.0122s
# Epoch: 0038 loss_train: 0.1207 acc_train: 0.9643 loss_val: 1.5065 acc_val: 0.6100 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0294s v_time: 0.0122s
# Epoch: 0039 loss_train: 0.1379 acc_train: 0.9571 loss_val: 1.4850 acc_val: 0.6440 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0302s v_time: 0.0123s
# Epoch: 0040 loss_train: 0.1242 acc_train: 0.9500 loss_val: 1.4380 acc_val: 0.6300 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0299s v_time: 0.0122s
# Epoch: 0041 loss_train: 0.1450 acc_train: 0.9571 loss_val: 1.5496 acc_val: 0.6380 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0298s v_time: 0.0122s
# Epoch: 0042 loss_train: 0.1469 acc_train: 0.9500 loss_val: 1.5235 acc_val: 0.6500 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0295s v_time: 0.0124s
# Epoch: 0043 loss_train: 0.0965 acc_train: 0.9643 loss_val: 1.4147 acc_val: 0.6420 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0299s v_time: 0.0123s
# Epoch: 0044 loss_train: 0.2160 acc_train: 0.9571 loss_val: 1.3059 acc_val: 0.6400 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0300s v_time: 0.0125s
# Epoch: 0045 loss_train: 0.1391 acc_train: 0.9571 loss_val: 1.3880 acc_val: 0.6620 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0299s v_time: 0.0123s
# Epoch: 0046 loss_train: 0.1999 acc_train: 0.9643 loss_val: 1.4853 acc_val: 0.6260 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0302s v_time: 0.0123s
# Epoch: 0047 loss_train: 0.1620 acc_train: 0.9643 loss_val: 1.6434 acc_val: 0.6060 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0302s v_time: 0.0123s
# Epoch: 0048 loss_train: 0.0941 acc_train: 0.9786 loss_val: 1.6366 acc_val: 0.6100 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0299s v_time: 0.0123s
# Epoch: 0049 loss_train: 0.0777 acc_train: 0.9714 loss_val: 1.6128 acc_val: 0.5980 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0300s v_time: 0.0124s
# Epoch: 0050 loss_train: 0.0965 acc_train: 0.9714 loss_val: 1.6194 acc_val: 0.6080 cur_lr: 0.02000 s_time: 0.0023s t_time: 0.0296s v_time: 0.0123s
# Epoch: 0051 loss_train: 0.2020 acc_train: 0.9786 loss_val: 1.7725 acc_val: 0.6060 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0320s v_time: 0.0127s
# Epoch: 0052 loss_train: 0.2112 acc_train: 0.9500 loss_val: 1.7865 acc_val: 0.5860 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0301s v_time: 0.0128s
# Epoch: 0053 loss_train: 0.0833 acc_train: 0.9643 loss_val: 1.5069 acc_val: 0.6280 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0294s v_time: 0.0121s
# Epoch: 0054 loss_train: 0.0988 acc_train: 0.9714 loss_val: 1.5223 acc_val: 0.6460 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0291s v_time: 0.0122s
# Epoch: 0055 loss_train: 0.1023 acc_train: 0.9786 loss_val: 1.4587 acc_val: 0.6240 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0302s v_time: 0.0123s
# Epoch: 0056 loss_train: 0.2034 acc_train: 0.9643 loss_val: 1.5099 acc_val: 0.6460 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0307s v_time: 0.0122s
# Epoch: 0057 loss_train: 0.0669 acc_train: 0.9857 loss_val: 1.6145 acc_val: 0.6380 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0295s v_time: 0.0122s
# Epoch: 0058 loss_train: 0.2086 acc_train: 0.9357 loss_val: 1.6617 acc_val: 0.6320 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0301s v_time: 0.0125s
# Epoch: 0059 loss_train: 0.2505 acc_train: 0.9429 loss_val: 1.6370 acc_val: 0.6060 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0301s v_time: 0.0123s
# Epoch: 0060 loss_train: 0.1418 acc_train: 0.9714 loss_val: 1.5398 acc_val: 0.6340 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0298s v_time: 0.0123s
# Epoch: 0061 loss_train: 0.1054 acc_train: 0.9571 loss_val: 1.4632 acc_val: 0.6600 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0301s v_time: 0.0123s
# Epoch: 0062 loss_train: 0.1258 acc_train: 0.9786 loss_val: 1.6023 acc_val: 0.6300 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0299s v_time: 0.0123s
# Epoch: 0063 loss_train: 0.1756 acc_train: 0.9571 loss_val: 1.4835 acc_val: 0.6460 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0299s v_time: 0.0123s
# Epoch: 0064 loss_train: 0.0541 acc_train: 0.9714 loss_val: 1.4232 acc_val: 0.6480 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0298s v_time: 0.0123s
# Epoch: 0065 loss_train: 0.0513 acc_train: 0.9857 loss_val: 1.4709 acc_val: 0.6360 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0303s v_time: 0.0125s
# Epoch: 0066 loss_train: 0.0718 acc_train: 0.9786 loss_val: 1.5145 acc_val: 0.6320 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0306s v_time: 0.0123s
# Epoch: 0067 loss_train: 0.1137 acc_train: 0.9714 loss_val: 1.5460 acc_val: 0.6240 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0295s v_time: 0.0124s
# Epoch: 0068 loss_train: 0.1201 acc_train: 0.9714 loss_val: 1.7225 acc_val: 0.6100 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0299s v_time: 0.0124s
# Epoch: 0069 loss_train: 0.0975 acc_train: 0.9714 loss_val: 1.9093 acc_val: 0.5920 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0293s v_time: 0.0122s
# Epoch: 0070 loss_train: 0.0963 acc_train: 0.9714 loss_val: 1.7171 acc_val: 0.6320 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0291s v_time: 0.0122s
# Epoch: 0071 loss_train: 0.1178 acc_train: 0.9786 loss_val: 1.7686 acc_val: 0.6060 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0306s v_time: 0.0123s
# Epoch: 0072 loss_train: 0.1164 acc_train: 0.9643 loss_val: 1.6834 acc_val: 0.6200 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0300s v_time: 0.0122s
# Epoch: 0073 loss_train: 0.1539 acc_train: 0.9714 loss_val: 1.9680 acc_val: 0.5900 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0294s v_time: 0.0121s
# Epoch: 0074 loss_train: 0.0765 acc_train: 0.9714 loss_val: 1.6161 acc_val: 0.6460 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0302s v_time: 0.0123s
# Epoch: 0075 loss_train: 0.1004 acc_train: 0.9714 loss_val: 1.8095 acc_val: 0.6120 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0297s v_time: 0.0123s
# Epoch: 0076 loss_train: 0.0673 acc_train: 0.9786 loss_val: 1.9106 acc_val: 0.6140 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0304s v_time: 0.0123s
# Epoch: 0077 loss_train: 0.0521 acc_train: 0.9786 loss_val: 1.7142 acc_val: 0.6060 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0300s v_time: 0.0125s
# Epoch: 0078 loss_train: 0.1353 acc_train: 0.9714 loss_val: 1.5455 acc_val: 0.6380 cur_lr: 0.02000 s_time: 0.0023s t_time: 0.0299s v_time: 0.0122s
# Epoch: 0079 loss_train: 0.1925 acc_train: 0.9714 loss_val: 1.6306 acc_val: 0.6300 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0299s v_time: 0.0125s
# Epoch: 0080 loss_train: 0.1975 acc_train: 0.9786 loss_val: 1.7045 acc_val: 0.6460 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0301s v_time: 0.0123s
# Epoch: 0081 loss_train: 0.1504 acc_train: 0.9500 loss_val: 1.4346 acc_val: 0.6640 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0306s v_time: 0.0123s
# Epoch: 0082 loss_train: 0.1605 acc_train: 0.9571 loss_val: 1.6067 acc_val: 0.6400 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0301s v_time: 0.0122s
# Epoch: 0083 loss_train: 0.0795 acc_train: 0.9714 loss_val: 1.6202 acc_val: 0.6440 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0300s v_time: 0.0123s
# Epoch: 0084 loss_train: 0.0844 acc_train: 0.9571 loss_val: 1.3807 acc_val: 0.6660 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0307s v_time: 0.0124s
# Epoch: 0085 loss_train: 0.0995 acc_train: 0.9786 loss_val: 1.5380 acc_val: 0.6600 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0294s v_time: 0.0122s
# Epoch: 0086 loss_train: 0.0513 acc_train: 0.9857 loss_val: 1.4361 acc_val: 0.6480 cur_lr: 0.02000 s_time: 0.0022s t_time: 0.0302s v_time: 0.0122s
# Epoch: 0087 loss_train: 0.0832 acc_train: 0.9714 loss_val: 1.4142 acc_val: 0.6720 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0297s v_time: 0.0125s
# Epoch: 0088 loss_train: 0.0522 acc_train: 0.9857 loss_val: 1.4660 acc_val: 0.6560 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0297s v_time: 0.0122s
# Epoch: 0089 loss_train: 0.1194 acc_train: 0.9643 loss_val: 1.3939 acc_val: 0.6660 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0297s v_time: 0.0122s
# Epoch: 0090 loss_train: 0.1100 acc_train: 0.9714 loss_val: 1.5219 acc_val: 0.6640 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0303s v_time: 0.0123s
# Epoch: 0091 loss_train: 0.1543 acc_train: 0.9429 loss_val: 1.4734 acc_val: 0.6240 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0299s v_time: 0.0122s
# Epoch: 0092 loss_train: 0.0993 acc_train: 0.9643 loss_val: 1.4661 acc_val: 0.6360 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0304s v_time: 0.0125s
# Epoch: 0093 loss_train: 0.0970 acc_train: 0.9643 loss_val: 1.6313 acc_val: 0.6140 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0304s v_time: 0.0123s
# Epoch: 0094 loss_train: 0.1066 acc_train: 0.9714 loss_val: 1.6831 acc_val: 0.6220 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0298s v_time: 0.0123s
# Epoch: 0095 loss_train: 0.0871 acc_train: 0.9786 loss_val: 1.6591 acc_val: 0.6260 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0303s v_time: 0.0125s
# Epoch: 0096 loss_train: 0.0400 acc_train: 0.9929 loss_val: 1.8065 acc_val: 0.5880 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0302s v_time: 0.0123s
# Epoch: 0097 loss_train: 0.3257 acc_train: 0.9357 loss_val: 1.8090 acc_val: 0.6120 cur_lr: 0.02000 s_time: 0.0023s t_time: 0.0301s v_time: 0.0124s
# Epoch: 0098 loss_train: 0.1167 acc_train: 0.9714 loss_val: 1.6318 acc_val: 0.6160 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0298s v_time: 0.0131s
# Epoch: 0099 loss_train: 0.1100 acc_train: 0.9571 loss_val: 1.6628 acc_val: 0.6420 cur_lr: 0.02000 s_time: 0.0023s t_time: 0.0290s v_time: 0.0123s
# Epoch: 0100 loss_train: 0.1492 acc_train: 0.9714 loss_val: 1.5187 acc_val: 0.6440 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0306s v_time: 0.0123s
# Epoch: 0101 loss_train: 0.1002 acc_train: 0.9714 loss_val: 1.6347 acc_val: 0.6420 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0299s v_time: 0.0122s
# Epoch: 0102 loss_train: 0.2040 acc_train: 0.9571 loss_val: 1.4805 acc_val: 0.6320 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0296s v_time: 0.0125s
# Epoch: 0103 loss_train: 0.0713 acc_train: 0.9929 loss_val: 1.6914 acc_val: 0.6160 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0299s v_time: 0.0125s
# Epoch: 0104 loss_train: 0.2041 acc_train: 0.9429 loss_val: 1.6263 acc_val: 0.6200 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0294s v_time: 0.0122s
# Epoch: 0105 loss_train: 0.2088 acc_train: 0.9286 loss_val: 1.7041 acc_val: 0.5960 cur_lr: 0.02000 s_time: 0.0022s t_time: 0.0297s v_time: 0.0122s
# Epoch: 0106 loss_train: 0.0911 acc_train: 0.9571 loss_val: 1.6925 acc_val: 0.5960 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0308s v_time: 0.0123s
# Epoch: 0107 loss_train: 0.0638 acc_train: 0.9786 loss_val: 1.7427 acc_val: 0.6100 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0301s v_time: 0.0123s
# Epoch: 0108 loss_train: 0.1096 acc_train: 0.9643 loss_val: 1.6507 acc_val: 0.6180 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0303s v_time: 0.0125s
# Epoch: 0109 loss_train: 0.1069 acc_train: 0.9786 loss_val: 1.7480 acc_val: 0.6080 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0343s v_time: 0.0124s
# Epoch: 0110 loss_train: 0.1381 acc_train: 0.9643 loss_val: 1.5992 acc_val: 0.6280 cur_lr: 0.02000 s_time: 0.0033s t_time: 0.0302s v_time: 0.0125s
# Epoch: 0111 loss_train: 0.0880 acc_train: 0.9786 loss_val: 1.8231 acc_val: 0.6140 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0311s v_time: 0.0123s
# Epoch: 0112 loss_train: 0.1359 acc_train: 0.9500 loss_val: 1.6403 acc_val: 0.6260 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0297s v_time: 0.0123s
# Epoch: 0113 loss_train: 0.1609 acc_train: 0.9643 loss_val: 1.7284 acc_val: 0.6200 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0304s v_time: 0.0125s
# Epoch: 0114 loss_train: 0.1143 acc_train: 0.9714 loss_val: 1.6347 acc_val: 0.6280 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0299s v_time: 0.0123s
# Epoch: 0115 loss_train: 0.0706 acc_train: 0.9786 loss_val: 1.7085 acc_val: 0.6320 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0300s v_time: 0.0124s
# Epoch: 0116 loss_train: 0.0706 acc_train: 0.9714 loss_val: 1.6723 acc_val: 0.6300 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0307s v_time: 0.0122s
# Epoch: 0117 loss_train: 0.0539 acc_train: 0.9857 loss_val: 1.7186 acc_val: 0.6340 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0294s v_time: 0.0122s
# Epoch: 0118 loss_train: 0.0951 acc_train: 0.9714 loss_val: 1.7018 acc_val: 0.6260 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0298s v_time: 0.0124s
# Epoch: 0119 loss_train: 0.0773 acc_train: 0.9714 loss_val: 1.7244 acc_val: 0.6280 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0306s v_time: 0.0122s
# Epoch: 0120 loss_train: 0.0514 acc_train: 0.9857 loss_val: 1.8603 acc_val: 0.6160 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0293s v_time: 0.0122s
# Epoch: 0121 loss_train: 0.0641 acc_train: 0.9714 loss_val: 1.6240 acc_val: 0.6360 cur_lr: 0.02000 s_time: 0.0022s t_time: 0.0292s v_time: 0.0124s
# Epoch: 0122 loss_train: 0.0914 acc_train: 0.9643 loss_val: 1.7486 acc_val: 0.6220 cur_lr: 0.02000 s_time: 0.0023s t_time: 0.0285s v_time: 0.0123s
# Epoch: 0123 loss_train: 0.1229 acc_train: 0.9714 loss_val: 1.8751 acc_val: 0.6400 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0300s v_time: 0.0123s
# Epoch: 0124 loss_train: 0.1074 acc_train: 0.9714 loss_val: 1.7278 acc_val: 0.6440 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0302s v_time: 0.0125s
# Epoch: 0125 loss_train: 0.0839 acc_train: 0.9714 loss_val: 1.6931 acc_val: 0.6420 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0292s v_time: 0.0122s
# Epoch: 0126 loss_train: 0.0625 acc_train: 0.9786 loss_val: 1.5749 acc_val: 0.6600 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0304s v_time: 0.0124s
# Epoch: 0127 loss_train: 0.0503 acc_train: 0.9714 loss_val: 1.7366 acc_val: 0.6260 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0300s v_time: 0.0123s
# Epoch: 0128 loss_train: 0.0672 acc_train: 0.9786 loss_val: 1.4247 acc_val: 0.6840 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0300s v_time: 0.0123s
# Epoch: 0129 loss_train: 0.1395 acc_train: 0.9643 loss_val: 1.7889 acc_val: 0.6560 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0302s v_time: 0.0125s
# Epoch: 0130 loss_train: 0.0804 acc_train: 0.9857 loss_val: 1.4692 acc_val: 0.6780 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0296s v_time: 0.0122s
# Epoch: 0131 loss_train: 0.0427 acc_train: 0.9857 loss_val: 1.6609 acc_val: 0.6700 cur_lr: 0.02000 s_time: 0.0023s t_time: 0.0298s v_time: 0.0124s
# Epoch: 0132 loss_train: 0.0712 acc_train: 0.9643 loss_val: 1.8533 acc_val: 0.6480 cur_lr: 0.02000 s_time: 0.0025s t_time: 0.0277s v_time: 0.0121s
# Epoch: 0133 loss_train: 0.0406 acc_train: 0.9857 loss_val: 1.8640 acc_val: 0.6400 cur_lr: 0.02000 s_time: 0.0026s t_time: 0.0296s v_time: 0.0122s
# Epoch: 0134 loss_train: 0.0280 acc_train: 0.9857 loss_val: 1.7081 acc_val: 0.6400 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0300s v_time: 0.0125s
# Epoch: 0135 loss_train: 0.0762 acc_train: 0.9643 loss_val: 1.8387 acc_val: 0.6620 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0301s v_time: 0.0122s
# Epoch: 0136 loss_train: 0.0877 acc_train: 0.9714 loss_val: 1.8722 acc_val: 0.6660 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0297s v_time: 0.0122s
# Epoch: 0137 loss_train: 0.0370 acc_train: 0.9929 loss_val: 1.8559 acc_val: 0.6360 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0301s v_time: 0.0125s
# Epoch: 0138 loss_train: 0.2004 acc_train: 0.9643 loss_val: 1.8445 acc_val: 0.6560 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0293s v_time: 0.0122s
# Epoch: 0139 loss_train: 0.0711 acc_train: 0.9857 loss_val: 1.6813 acc_val: 0.6620 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0297s v_time: 0.0125s
# Epoch: 0140 loss_train: 0.0335 acc_train: 0.9857 loss_val: 1.7208 acc_val: 0.6660 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0296s v_time: 0.0122s
# Epoch: 0141 loss_train: 0.0495 acc_train: 0.9857 loss_val: 1.8812 acc_val: 0.6460 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0304s v_time: 0.0123s
# Epoch: 0142 loss_train: 0.2088 acc_train: 0.9643 loss_val: 1.7690 acc_val: 0.6560 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0300s v_time: 0.0123s
# Epoch: 0143 loss_train: 0.0777 acc_train: 0.9643 loss_val: 1.6598 acc_val: 0.6460 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0296s v_time: 0.0122s
# Epoch: 0144 loss_train: 0.0384 acc_train: 0.9857 loss_val: 1.8266 acc_val: 0.6460 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0296s v_time: 0.0124s
# Epoch: 0145 loss_train: 0.1195 acc_train: 0.9500 loss_val: 1.7797 acc_val: 0.6500 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0300s v_time: 0.0123s
# Epoch: 0146 loss_train: 0.0870 acc_train: 0.9786 loss_val: 1.7980 acc_val: 0.6380 cur_lr: 0.02000 s_time: 0.0023s t_time: 0.0306s v_time: 0.0124s
# Epoch: 0147 loss_train: 0.0982 acc_train: 0.9643 loss_val: 1.8420 acc_val: 0.6100 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0292s v_time: 0.0122s
# Epoch: 0148 loss_train: 0.0566 acc_train: 0.9857 loss_val: 1.7762 acc_val: 0.6360 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0304s v_time: 0.0123s
# Epoch: 0149 loss_train: 0.1390 acc_train: 0.9643 loss_val: 1.7922 acc_val: 0.6220 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0295s v_time: 0.0122s
# Epoch: 0150 loss_train: 0.0957 acc_train: 0.9714 loss_val: 1.9153 acc_val: 0.5860 cur_lr: 0.02000 s_time: 0.0026s t_time: 0.0303s v_time: 0.0123s
# Epoch: 0151 loss_train: 0.1377 acc_train: 0.9571 loss_val: 1.8882 acc_val: 0.6140 cur_lr: 0.02000 s_time: 0.0023s t_time: 0.0313s v_time: 0.0124s
# Epoch: 0152 loss_train: 0.1332 acc_train: 0.9500 loss_val: 1.8792 acc_val: 0.6120 cur_lr: 0.02000 s_time: 0.0022s t_time: 0.0299s v_time: 0.0121s
# Epoch: 0153 loss_train: 0.1122 acc_train: 0.9643 loss_val: 1.8685 acc_val: 0.6000 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0292s v_time: 0.0124s
# Epoch: 0154 loss_train: 0.1033 acc_train: 0.9571 loss_val: 1.5417 acc_val: 0.6380 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0298s v_time: 0.0125s
# Epoch: 0155 loss_train: 0.1183 acc_train: 0.9714 loss_val: 1.6916 acc_val: 0.6320 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0299s v_time: 0.0122s
# Epoch: 0156 loss_train: 0.1284 acc_train: 0.9643 loss_val: 1.6164 acc_val: 0.6560 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0301s v_time: 0.0122s
# Epoch: 0157 loss_train: 0.1355 acc_train: 0.9571 loss_val: 1.6973 acc_val: 0.6420 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0297s v_time: 0.0123s
# Epoch: 0158 loss_train: 0.2333 acc_train: 0.9429 loss_val: 1.5053 acc_val: 0.6660 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0296s v_time: 0.0123s
# Epoch: 0159 loss_train: 0.1194 acc_train: 0.9571 loss_val: 1.6317 acc_val: 0.6340 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0300s v_time: 0.0125s
# Epoch: 0160 loss_train: 0.0851 acc_train: 0.9643 loss_val: 1.6247 acc_val: 0.6520 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0296s v_time: 0.0122s
# Epoch: 0161 loss_train: 0.0799 acc_train: 0.9714 loss_val: 1.5042 acc_val: 0.6680 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0304s v_time: 0.0125s
# Epoch: 0162 loss_train: 0.1111 acc_train: 0.9643 loss_val: 1.5245 acc_val: 0.6500 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0298s v_time: 0.0123s
# Epoch: 0163 loss_train: 0.1555 acc_train: 0.9786 loss_val: 1.5404 acc_val: 0.6380 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0299s v_time: 0.0126s
# Epoch: 0164 loss_train: 0.1535 acc_train: 0.9643 loss_val: 1.6529 acc_val: 0.6020 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0299s v_time: 0.0122s
# Epoch: 0165 loss_train: 0.0955 acc_train: 0.9500 loss_val: 1.5888 acc_val: 0.6260 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0292s v_time: 0.0122s
# Epoch: 0166 loss_train: 0.0778 acc_train: 0.9786 loss_val: 1.8240 acc_val: 0.6260 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0302s v_time: 0.0125s
# Epoch: 0167 loss_train: 0.2454 acc_train: 0.9500 loss_val: 1.8671 acc_val: 0.6120 cur_lr: 0.02000 s_time: 0.0022s t_time: 0.0304s v_time: 0.0123s
# Epoch: 0168 loss_train: 0.0745 acc_train: 0.9786 loss_val: 1.7137 acc_val: 0.6400 cur_lr: 0.02000 s_time: 0.0023s t_time: 0.0290s v_time: 0.0123s
# Epoch: 0169 loss_train: 0.1816 acc_train: 0.9429 loss_val: 1.7581 acc_val: 0.6180 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0300s v_time: 0.0123s
# Epoch: 0170 loss_train: 0.0696 acc_train: 0.9929 loss_val: 1.9122 acc_val: 0.6360 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0297s v_time: 0.0125s
# Epoch: 0171 loss_train: 0.0742 acc_train: 0.9786 loss_val: 2.0292 acc_val: 0.6440 cur_lr: 0.02000 s_time: 0.0023s t_time: 0.0306s v_time: 0.0123s
# Epoch: 0172 loss_train: 0.0793 acc_train: 0.9643 loss_val: 1.5106 acc_val: 0.6380 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0301s v_time: 0.0123s
# Epoch: 0173 loss_train: 0.1364 acc_train: 0.9571 loss_val: 1.8215 acc_val: 0.6380 cur_lr: 0.02000 s_time: 0.0023s t_time: 0.0309s v_time: 0.0123s
# Epoch: 0174 loss_train: 0.1545 acc_train: 0.9500 loss_val: 1.8847 acc_val: 0.6360 cur_lr: 0.02000 s_time: 0.0023s t_time: 0.0300s v_time: 0.0123s
# Epoch: 0175 loss_train: 0.1243 acc_train: 0.9643 loss_val: 1.5309 acc_val: 0.6540 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0301s v_time: 0.0123s
# Epoch: 0176 loss_train: 0.1877 acc_train: 0.9500 loss_val: 1.6128 acc_val: 0.6080 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0300s v_time: 0.0123s
# Epoch: 0177 loss_train: 0.1822 acc_train: 0.9429 loss_val: 1.7408 acc_val: 0.6260 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0303s v_time: 0.0125s
# Epoch: 0178 loss_train: 0.1495 acc_train: 0.9571 loss_val: 1.8602 acc_val: 0.6060 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0296s v_time: 0.0123s
# Epoch: 0179 loss_train: 0.1312 acc_train: 0.9714 loss_val: 1.6937 acc_val: 0.6260 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0295s v_time: 0.0127s
# Epoch: 0180 loss_train: 0.1037 acc_train: 0.9643 loss_val: 1.7327 acc_val: 0.6260 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0298s v_time: 0.0122s
# Epoch: 0181 loss_train: 0.1893 acc_train: 0.9643 loss_val: 1.6148 acc_val: 0.6440 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0298s v_time: 0.0121s
# Epoch: 0182 loss_train: 0.0971 acc_train: 0.9714 loss_val: 1.6007 acc_val: 0.6480 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0299s v_time: 0.0124s
# Epoch: 0183 loss_train: 0.0526 acc_train: 0.9857 loss_val: 1.6883 acc_val: 0.6460 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0305s v_time: 0.0122s
# Epoch: 0184 loss_train: 0.1321 acc_train: 0.9500 loss_val: 1.6562 acc_val: 0.6140 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0297s v_time: 0.0122s
# Epoch: 0185 loss_train: 0.1618 acc_train: 0.9714 loss_val: 1.5570 acc_val: 0.6200 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0297s v_time: 0.0125s
# Epoch: 0186 loss_train: 0.1589 acc_train: 0.9429 loss_val: 1.6387 acc_val: 0.6480 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0304s v_time: 0.0123s
# Epoch: 0187 loss_train: 0.1114 acc_train: 0.9643 loss_val: 1.7595 acc_val: 0.6020 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0301s v_time: 0.0123s
# Epoch: 0188 loss_train: 0.1968 acc_train: 0.9571 loss_val: 1.7676 acc_val: 0.6160 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0294s v_time: 0.0122s
# Epoch: 0189 loss_train: 0.0796 acc_train: 0.9714 loss_val: 1.7838 acc_val: 0.5760 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0301s v_time: 0.0123s
# Epoch: 0190 loss_train: 0.1966 acc_train: 0.9500 loss_val: 1.8663 acc_val: 0.6180 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0300s v_time: 0.0123s
# Epoch: 0191 loss_train: 0.1389 acc_train: 0.9571 loss_val: 1.7891 acc_val: 0.5940 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0309s v_time: 0.0125s
# Epoch: 0192 loss_train: 0.1129 acc_train: 0.9500 loss_val: 1.8096 acc_val: 0.6220 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0299s v_time: 0.0123s
# Epoch: 0193 loss_train: 0.0966 acc_train: 0.9786 loss_val: 1.7462 acc_val: 0.6360 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0298s v_time: 0.0125s
# Epoch: 0194 loss_train: 0.0698 acc_train: 0.9857 loss_val: 1.6813 acc_val: 0.6420 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0299s v_time: 0.0123s
# Epoch: 0195 loss_train: 0.1826 acc_train: 0.9643 loss_val: 1.6446 acc_val: 0.6360 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0295s v_time: 0.0128s
# Epoch: 0196 loss_train: 0.0708 acc_train: 0.9786 loss_val: 1.6625 acc_val: 0.6540 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0301s v_time: 0.0123s
# Epoch: 0197 loss_train: 0.1223 acc_train: 0.9500 loss_val: 1.6418 acc_val: 0.6520 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0298s v_time: 0.0122s
# Epoch: 0198 loss_train: 0.2033 acc_train: 0.9643 loss_val: 1.6991 acc_val: 0.6420 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0303s v_time: 0.0123s
# Epoch: 0199 loss_train: 0.2516 acc_train: 0.9143 loss_val: 1.7899 acc_val: 0.6080 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0301s v_time: 0.0122s
# Epoch: 0200 loss_train: 0.0638 acc_train: 0.9857 loss_val: 1.6890 acc_val: 0.6360 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0294s v_time: 0.0122s
# Epoch: 0201 loss_train: 0.1464 acc_train: 0.9643 loss_val: 2.0452 acc_val: 0.6100 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0301s v_time: 0.0124s
# Epoch: 0202 loss_train: 0.0858 acc_train: 0.9571 loss_val: 1.9412 acc_val: 0.6080 cur_lr: 0.02000 s_time: 0.0023s t_time: 0.0299s v_time: 0.0122s
# Epoch: 0203 loss_train: 0.0725 acc_train: 0.9786 loss_val: 1.8885 acc_val: 0.6340 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0301s v_time: 0.0122s
# Epoch: 0204 loss_train: 0.1225 acc_train: 0.9571 loss_val: 1.8879 acc_val: 0.5920 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0298s v_time: 0.0122s
# Epoch: 0205 loss_train: 0.2872 acc_train: 0.9429 loss_val: 1.9387 acc_val: 0.5920 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0299s v_time: 0.0127s
# Epoch: 0206 loss_train: 0.1539 acc_train: 0.9571 loss_val: 1.9492 acc_val: 0.6000 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0303s v_time: 0.0123s
# Epoch: 0207 loss_train: 0.0847 acc_train: 0.9786 loss_val: 1.9919 acc_val: 0.6000 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0297s v_time: 0.0123s
# Epoch: 0208 loss_train: 0.1463 acc_train: 0.9643 loss_val: 2.0760 acc_val: 0.6040 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0298s v_time: 0.0122s
# Epoch: 0209 loss_train: 0.2025 acc_train: 0.9286 loss_val: 1.9853 acc_val: 0.6040 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0300s v_time: 0.0123s
# Epoch: 0210 loss_train: 0.1227 acc_train: 0.9714 loss_val: 2.0773 acc_val: 0.6080 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0303s v_time: 0.0125s
# Epoch: 0211 loss_train: 0.2321 acc_train: 0.9214 loss_val: 1.6757 acc_val: 0.6660 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0305s v_time: 0.0129s
# Epoch: 0212 loss_train: 0.0480 acc_train: 0.9857 loss_val: 1.7079 acc_val: 0.6720 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0297s v_time: 0.0122s
# Epoch: 0213 loss_train: 0.0999 acc_train: 0.9643 loss_val: 1.7361 acc_val: 0.6700 cur_lr: 0.02000 s_time: 0.0022s t_time: 0.0296s v_time: 0.0122s
# Epoch: 0214 loss_train: 0.1752 acc_train: 0.9500 loss_val: 1.5511 acc_val: 0.6800 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0308s v_time: 0.0122s
# Epoch: 0215 loss_train: 0.2244 acc_train: 0.9500 loss_val: 1.8614 acc_val: 0.6500 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0292s v_time: 0.0122s
# Epoch: 0216 loss_train: 0.1058 acc_train: 0.9571 loss_val: 1.8253 acc_val: 0.6560 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0300s v_time: 0.0125s
# Epoch: 0217 loss_train: 0.0926 acc_train: 0.9786 loss_val: 1.7467 acc_val: 0.6380 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0295s v_time: 0.0123s
# Epoch: 0218 loss_train: 0.2219 acc_train: 0.9500 loss_val: 1.8906 acc_val: 0.6180 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0302s v_time: 0.0123s
# Epoch: 0219 loss_train: 0.0959 acc_train: 0.9643 loss_val: 1.9503 acc_val: 0.6340 cur_lr: 0.02000 s_time: 0.0025s t_time: 0.0302s v_time: 0.0122s
# Epoch: 0220 loss_train: 0.2443 acc_train: 0.9643 loss_val: 1.8902 acc_val: 0.6140 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0297s v_time: 0.0123s
# Epoch: 0221 loss_train: 0.2879 acc_train: 0.9500 loss_val: 1.8460 acc_val: 0.6460 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0303s v_time: 0.0122s
# Epoch: 0222 loss_train: 0.0873 acc_train: 0.9714 loss_val: 1.9346 acc_val: 0.6380 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0300s v_time: 0.0123s
# Epoch: 0223 loss_train: 0.0908 acc_train: 0.9786 loss_val: 1.7455 acc_val: 0.6200 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0303s v_time: 0.0125s
# Epoch: 0224 loss_train: 0.3116 acc_train: 0.9357 loss_val: 1.7597 acc_val: 0.6380 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0297s v_time: 0.0122s
# Epoch: 0225 loss_train: 0.2108 acc_train: 0.9571 loss_val: 1.8451 acc_val: 0.6180 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0299s v_time: 0.0124s
# Epoch: 0226 loss_train: 0.1372 acc_train: 0.9643 loss_val: 1.8910 acc_val: 0.6620 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0301s v_time: 0.0122s
# Epoch: 0227 loss_train: 0.1108 acc_train: 0.9429 loss_val: 1.8759 acc_val: 0.6380 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0300s v_time: 0.0128s
# Epoch: 0228 loss_train: 0.1158 acc_train: 0.9571 loss_val: 1.6907 acc_val: 0.6420 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0294s v_time: 0.0121s
# Epoch: 0229 loss_train: 0.3435 acc_train: 0.9357 loss_val: 1.9142 acc_val: 0.6420 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0296s v_time: 0.0122s
# Epoch: 0230 loss_train: 0.0994 acc_train: 0.9500 loss_val: 1.7988 acc_val: 0.6340 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0300s v_time: 0.0122s
# Epoch: 0231 loss_train: 0.0746 acc_train: 0.9571 loss_val: 1.8969 acc_val: 0.6320 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0306s v_time: 0.0122s
# Epoch: 0232 loss_train: 0.0975 acc_train: 0.9714 loss_val: 1.7589 acc_val: 0.6540 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0295s v_time: 0.0122s
# Epoch: 0233 loss_train: 0.1241 acc_train: 0.9571 loss_val: 1.5617 acc_val: 0.6680 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0301s v_time: 0.0125s
# Epoch: 0234 loss_train: 0.1113 acc_train: 0.9500 loss_val: 1.5938 acc_val: 0.6620 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0296s v_time: 0.0123s
# Epoch: 0235 loss_train: 0.1998 acc_train: 0.9643 loss_val: 1.7567 acc_val: 0.6740 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0301s v_time: 0.0124s
# Epoch: 0236 loss_train: 0.1393 acc_train: 0.9571 loss_val: 1.4834 acc_val: 0.6700 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0302s v_time: 0.0123s
# Epoch: 0237 loss_train: 0.1189 acc_train: 0.9786 loss_val: 1.7252 acc_val: 0.6360 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0301s v_time: 0.0123s
# Epoch: 0238 loss_train: 0.1132 acc_train: 0.9500 loss_val: 1.8826 acc_val: 0.6300 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0301s v_time: 0.0123s
# Epoch: 0239 loss_train: 0.1243 acc_train: 0.9571 loss_val: 1.7748 acc_val: 0.6040 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0301s v_time: 0.0123s
# Epoch: 0240 loss_train: 0.1536 acc_train: 0.9500 loss_val: 1.7816 acc_val: 0.6060 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0301s v_time: 0.0125s
# Epoch: 0241 loss_train: 0.1433 acc_train: 0.9429 loss_val: 1.6921 acc_val: 0.6000 cur_lr: 0.02000 s_time: 0.0023s t_time: 0.0304s v_time: 0.0123s
# Epoch: 0242 loss_train: 0.1794 acc_train: 0.9429 loss_val: 1.8565 acc_val: 0.6240 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0300s v_time: 0.0124s
# Epoch: 0243 loss_train: 0.0886 acc_train: 0.9571 loss_val: 1.9466 acc_val: 0.5920 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0302s v_time: 0.0128s
# Epoch: 0244 loss_train: 0.0900 acc_train: 0.9643 loss_val: 1.7335 acc_val: 0.5980 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0296s v_time: 0.0122s
# Epoch: 0245 loss_train: 0.1386 acc_train: 0.9643 loss_val: 1.9130 acc_val: 0.6200 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0295s v_time: 0.0121s
# Epoch: 0246 loss_train: 0.1093 acc_train: 0.9714 loss_val: 1.7421 acc_val: 0.6040 cur_lr: 0.02000 s_time: 0.0026s t_time: 0.0306s v_time: 0.0122s
# Epoch: 0247 loss_train: 0.2099 acc_train: 0.9643 loss_val: 1.7562 acc_val: 0.6160 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0301s v_time: 0.0123s
# Epoch: 0248 loss_train: 0.0958 acc_train: 0.9500 loss_val: 1.7139 acc_val: 0.6340 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0300s v_time: 0.0125s
# Epoch: 0249 loss_train: 0.2344 acc_train: 0.9500 loss_val: 1.6536 acc_val: 0.6280 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0296s v_time: 0.0122s
# Epoch: 0250 loss_train: 0.0782 acc_train: 0.9714 loss_val: 1.6892 acc_val: 0.6260 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0300s v_time: 0.0125s
# Epoch: 0251 loss_train: 0.1249 acc_train: 0.9571 loss_val: 1.6911 acc_val: 0.6220 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0308s v_time: 0.0123s
# Epoch: 0252 loss_train: 0.0790 acc_train: 0.9643 loss_val: 1.6186 acc_val: 0.6580 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0301s v_time: 0.0123s
# Epoch: 0253 loss_train: 0.0867 acc_train: 0.9929 loss_val: 1.7273 acc_val: 0.6300 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0300s v_time: 0.0125s
# Epoch: 0254 loss_train: 0.0667 acc_train: 0.9857 loss_val: 1.9009 acc_val: 0.6020 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0299s v_time: 0.0123s
# Epoch: 0255 loss_train: 0.2055 acc_train: 0.9786 loss_val: 1.7116 acc_val: 0.6340 cur_lr: 0.02000 s_time: 0.0023s t_time: 0.0301s v_time: 0.0124s
# Epoch: 0256 loss_train: 0.0702 acc_train: 0.9643 loss_val: 1.7451 acc_val: 0.6280 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0301s v_time: 0.0123s
# Epoch: 0257 loss_train: 0.2281 acc_train: 0.9643 loss_val: 1.7256 acc_val: 0.6260 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0299s v_time: 0.0123s
# Epoch: 0258 loss_train: 0.1064 acc_train: 0.9714 loss_val: 1.7134 acc_val: 0.6280 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0343s v_time: 0.0128s
# Epoch: 0259 loss_train: 0.0495 acc_train: 0.9786 loss_val: 1.7168 acc_val: 0.6160 cur_lr: 0.02000 s_time: 0.0033s t_time: 0.0310s v_time: 0.0122s
# Epoch: 0260 loss_train: 0.1156 acc_train: 0.9571 loss_val: 1.7475 acc_val: 0.6340 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0295s v_time: 0.0121s
# Epoch: 0261 loss_train: 0.0463 acc_train: 0.9857 loss_val: 1.7122 acc_val: 0.6180 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0304s v_time: 0.0124s
# Epoch: 0262 loss_train: 0.0492 acc_train: 0.9857 loss_val: 1.6059 acc_val: 0.6360 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0305s v_time: 0.0122s
# Epoch: 0263 loss_train: 0.0845 acc_train: 0.9643 loss_val: 1.6605 acc_val: 0.6500 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0297s v_time: 0.0122s
# Epoch: 0264 loss_train: 0.0926 acc_train: 0.9786 loss_val: 1.7476 acc_val: 0.6380 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0291s v_time: 0.0125s
# Epoch: 0265 loss_train: 0.0801 acc_train: 0.9714 loss_val: 1.5904 acc_val: 0.6580 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0294s v_time: 0.0122s
# Epoch: 0266 loss_train: 0.1008 acc_train: 0.9643 loss_val: 1.5756 acc_val: 0.6460 cur_lr: 0.02000 s_time: 0.0023s t_time: 0.0306s v_time: 0.0123s
# Epoch: 0267 loss_train: 0.2967 acc_train: 0.9643 loss_val: 1.5858 acc_val: 0.6500 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0301s v_time: 0.0123s
# Epoch: 0268 loss_train: 0.2076 acc_train: 0.9571 loss_val: 1.4841 acc_val: 0.6640 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0298s v_time: 0.0123s
# Epoch: 0269 loss_train: 0.1668 acc_train: 0.9714 loss_val: 1.5091 acc_val: 0.6520 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0297s v_time: 0.0124s
# Epoch: 0270 loss_train: 0.1538 acc_train: 0.9571 loss_val: 1.5730 acc_val: 0.6400 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0296s v_time: 0.0123s
# Epoch: 0271 loss_train: 0.1607 acc_train: 0.9786 loss_val: 1.8098 acc_val: 0.6200 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0304s v_time: 0.0122s
# Epoch: 0272 loss_train: 0.1364 acc_train: 0.9571 loss_val: 1.4864 acc_val: 0.6620 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0295s v_time: 0.0122s
# Epoch: 0273 loss_train: 0.0960 acc_train: 0.9714 loss_val: 1.6019 acc_val: 0.6340 cur_lr: 0.02000 s_time: 0.0023s t_time: 0.0298s v_time: 0.0122s
# Epoch: 0274 loss_train: 0.1504 acc_train: 0.9714 loss_val: 1.5415 acc_val: 0.6520 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0301s v_time: 0.0122s
# Epoch: 0275 loss_train: 0.0550 acc_train: 0.9929 loss_val: 1.7078 acc_val: 0.6280 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0308s v_time: 0.0122s
# Epoch: 0276 loss_train: 0.1696 acc_train: 0.9643 loss_val: 1.5459 acc_val: 0.6200 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0298s v_time: 0.0121s
# Epoch: 0277 loss_train: 0.1308 acc_train: 0.9714 loss_val: 1.6810 acc_val: 0.6280 cur_lr: 0.02000 s_time: 0.0022s t_time: 0.0300s v_time: 0.0124s
# Epoch: 0278 loss_train: 0.1357 acc_train: 0.9714 loss_val: 1.6305 acc_val: 0.6420 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0291s v_time: 0.0126s
# Epoch: 0279 loss_train: 0.0559 acc_train: 0.9857 loss_val: 1.5973 acc_val: 0.6540 cur_lr: 0.02000 s_time: 0.0022s t_time: 0.0300s v_time: 0.0122s
# Epoch: 0280 loss_train: 0.0764 acc_train: 0.9786 loss_val: 1.8226 acc_val: 0.6180 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0297s v_time: 0.0122s
# Epoch: 0281 loss_train: 0.2366 acc_train: 0.9500 loss_val: 1.7734 acc_val: 0.6320 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0305s v_time: 0.0123s
# Epoch: 0282 loss_train: 0.1268 acc_train: 0.9643 loss_val: 1.5878 acc_val: 0.6280 cur_lr: 0.02000 s_time: 0.0022s t_time: 0.0302s v_time: 0.0123s
# Epoch: 0283 loss_train: 0.1074 acc_train: 0.9714 loss_val: 1.9588 acc_val: 0.5800 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0294s v_time: 0.0125s
# Epoch: 0284 loss_train: 0.2121 acc_train: 0.9500 loss_val: 1.5607 acc_val: 0.6340 cur_lr: 0.02000 s_time: 0.0026s t_time: 0.0298s v_time: 0.0122s
# Epoch: 0285 loss_train: 0.1143 acc_train: 0.9714 loss_val: 1.7235 acc_val: 0.6080 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0298s v_time: 0.0125s
# Epoch: 0286 loss_train: 0.1373 acc_train: 0.9571 loss_val: 1.4797 acc_val: 0.6200 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0305s v_time: 0.0123s
# Epoch: 0287 loss_train: 0.1294 acc_train: 0.9571 loss_val: 1.6492 acc_val: 0.6260 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0297s v_time: 0.0122s
# Epoch: 0288 loss_train: 0.1501 acc_train: 0.9286 loss_val: 1.7855 acc_val: 0.6020 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0301s v_time: 0.0123s
# Epoch: 0289 loss_train: 0.1417 acc_train: 0.9643 loss_val: 1.8870 acc_val: 0.5960 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0299s v_time: 0.0123s
# Epoch: 0290 loss_train: 0.2119 acc_train: 0.9214 loss_val: 1.7385 acc_val: 0.6140 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0295s v_time: 0.0124s
# Epoch: 0291 loss_train: 0.1628 acc_train: 0.9571 loss_val: 1.8500 acc_val: 0.6000 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0305s v_time: 0.0122s
# Epoch: 0292 loss_train: 0.0936 acc_train: 0.9786 loss_val: 1.6823 acc_val: 0.6060 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0293s v_time: 0.0122s
# Epoch: 0293 loss_train: 0.0720 acc_train: 0.9786 loss_val: 1.5663 acc_val: 0.6360 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0293s v_time: 0.0124s
# Epoch: 0294 loss_train: 0.0784 acc_train: 0.9643 loss_val: 1.5623 acc_val: 0.6520 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0301s v_time: 0.0122s
# Epoch: 0295 loss_train: 0.0656 acc_train: 0.9714 loss_val: 1.6468 acc_val: 0.6200 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0297s v_time: 0.0122s
# Epoch: 0296 loss_train: 0.1579 acc_train: 0.9643 loss_val: 1.8188 acc_val: 0.6120 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0298s v_time: 0.0124s
# Epoch: 0297 loss_train: 0.0524 acc_train: 0.9857 loss_val: 1.7860 acc_val: 0.6160 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0302s v_time: 0.0123s
# Epoch: 0298 loss_train: 0.0678 acc_train: 0.9857 loss_val: 1.6448 acc_val: 0.6400 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0301s v_time: 0.0123s
# Epoch: 0299 loss_train: 0.0927 acc_train: 0.9714 loss_val: 1.7161 acc_val: 0.6240 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0297s v_time: 0.0124s
# Epoch: 0300 loss_train: 0.0543 acc_train: 0.9714 loss_val: 1.8059 acc_val: 0.6520 cur_lr: 0.02000 s_time: 0.0023s t_time: 0.0299s v_time: 0.0122s
# Epoch: 0301 loss_train: 0.1800 acc_train: 0.9357 loss_val: 1.8191 acc_val: 0.6420 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0299s v_time: 0.0124s
# Epoch: 0302 loss_train: 0.2141 acc_train: 0.9571 loss_val: 1.7033 acc_val: 0.6400 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0299s v_time: 0.0123s
# Epoch: 0303 loss_train: 0.1077 acc_train: 0.9714 loss_val: 1.8803 acc_val: 0.6240 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0301s v_time: 0.0123s
# Epoch: 0304 loss_train: 0.1587 acc_train: 0.9500 loss_val: 1.8197 acc_val: 0.6460 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0302s v_time: 0.0125s
# Epoch: 0305 loss_train: 0.0621 acc_train: 0.9786 loss_val: 1.8620 acc_val: 0.6080 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0301s v_time: 0.0123s
# Epoch: 0306 loss_train: 0.1243 acc_train: 0.9786 loss_val: 1.7798 acc_val: 0.6480 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0298s v_time: 0.0123s
# Epoch: 0307 loss_train: 0.0276 acc_train: 1.0000 loss_val: 1.8087 acc_val: 0.6300 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0301s v_time: 0.0122s
# Epoch: 0308 loss_train: 0.0465 acc_train: 0.9929 loss_val: 1.7738 acc_val: 0.6480 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0294s v_time: 0.0121s
# Epoch: 0309 loss_train: 0.1351 acc_train: 0.9643 loss_val: 1.8880 acc_val: 0.6220 cur_lr: 0.02000 s_time: 0.0022s t_time: 0.0299s v_time: 0.0124s
# Epoch: 0310 loss_train: 0.0679 acc_train: 0.9786 loss_val: 1.7816 acc_val: 0.6300 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0304s v_time: 0.0122s
# Epoch: 0311 loss_train: 0.0807 acc_train: 0.9571 loss_val: 1.7808 acc_val: 0.6240 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0302s v_time: 0.0122s
# Epoch: 0312 loss_train: 0.0659 acc_train: 0.9857 loss_val: 1.8255 acc_val: 0.6500 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0293s v_time: 0.0123s
# Epoch: 0313 loss_train: 0.0702 acc_train: 0.9571 loss_val: 1.8465 acc_val: 0.6340 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0297s v_time: 0.0123s
# Epoch: 0314 loss_train: 0.0574 acc_train: 0.9714 loss_val: 1.8906 acc_val: 0.6380 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0305s v_time: 0.0125s
# Epoch: 0315 loss_train: 0.1301 acc_train: 0.9571 loss_val: 2.0147 acc_val: 0.6380 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0297s v_time: 0.0123s
# Epoch: 0316 loss_train: 0.1545 acc_train: 0.9571 loss_val: 2.0193 acc_val: 0.6380 cur_lr: 0.02000 s_time: 0.0022s t_time: 0.0305s v_time: 0.0124s
# Epoch: 0317 loss_train: 0.1237 acc_train: 0.9500 loss_val: 1.7659 acc_val: 0.6520 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0300s v_time: 0.0123s
# Epoch: 0318 loss_train: 0.0941 acc_train: 0.9857 loss_val: 1.9916 acc_val: 0.6420 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0300s v_time: 0.0123s
# Epoch: 0319 loss_train: 0.0894 acc_train: 0.9857 loss_val: 1.7985 acc_val: 0.6460 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0301s v_time: 0.0124s
# Epoch: 0320 loss_train: 0.0564 acc_train: 0.9786 loss_val: 1.8971 acc_val: 0.6100 cur_lr: 0.02000 s_time: 0.0022s t_time: 0.0289s v_time: 0.0122s
# Epoch: 0321 loss_train: 0.0985 acc_train: 0.9786 loss_val: 1.8021 acc_val: 0.6180 cur_lr: 0.02000 s_time: 0.0022s t_time: 0.0292s v_time: 0.0123s
# Epoch: 0322 loss_train: 0.1008 acc_train: 0.9643 loss_val: 1.8537 acc_val: 0.6300 cur_lr: 0.02000 s_time: 0.0031s t_time: 0.0297s v_time: 0.0129s
# Epoch: 0323 loss_train: 0.1635 acc_train: 0.9571 loss_val: 2.0494 acc_val: 0.6100 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0299s v_time: 0.0122s
# Epoch: 0324 loss_train: 0.1541 acc_train: 0.9714 loss_val: 1.8507 acc_val: 0.6380 cur_lr: 0.02000 s_time: 0.0026s t_time: 0.0297s v_time: 0.0122s
# Epoch: 0325 loss_train: 0.0427 acc_train: 0.9857 loss_val: 1.9889 acc_val: 0.6280 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0306s v_time: 0.0122s
# Epoch: 0326 loss_train: 0.1033 acc_train: 0.9571 loss_val: 2.0665 acc_val: 0.6200 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0299s v_time: 0.0122s
# Epoch: 0327 loss_train: 0.0719 acc_train: 0.9857 loss_val: 1.9057 acc_val: 0.6120 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0295s v_time: 0.0125s
# Epoch: 0328 loss_train: 0.1557 acc_train: 0.9429 loss_val: 1.6598 acc_val: 0.6660 cur_lr: 0.02000 s_time: 0.0025s t_time: 0.0300s v_time: 0.0123s
# ...
# Epoch: 0392 loss_train: 0.1159 acc_train: 0.9571 loss_val: 1.8050 acc_val: 0.6120 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0300s v_time: 0.0123s
# Epoch: 0393 loss_train: 0.1691 acc_train: 0.9786 loss_val: 1.9160 acc_val: 0.5860 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0299s v_time: 0.0124s
# Epoch: 0394 loss_train: 0.1492 acc_train: 0.9643 loss_val: 2.1132 acc_val: 0.5660 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0303s v_time: 0.0125s
# Epoch: 0395 loss_train: 0.1577 acc_train: 0.9786 loss_val: 1.9306 acc_val: 0.5880 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0300s v_time: 0.0123s
# Epoch: 0396 loss_train: 0.1673 acc_train: 0.9714 loss_val: 1.8708 acc_val: 0.5960 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0301s v_time: 0.0123s
# Epoch: 0397 loss_train: 0.1672 acc_train: 0.9357 loss_val: 1.8497 acc_val: 0.6340 cur_lr: 0.02000 s_time: 0.0022s t_time: 0.0296s v_time: 0.0123s
# Epoch: 0398 loss_train: 0.1027 acc_train: 0.9643 loss_val: 1.8448 acc_val: 0.6100 cur_lr: 0.02000 s_time: 0.0023s t_time: 0.0290s v_time: 0.0125s
# Epoch: 0399 loss_train: 0.2528 acc_train: 0.9500 loss_val: 2.0045 acc_val: 0.5960 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0301s v_time: 0.0123s
# Epoch: 0400 loss_train: 0.1233 acc_train: 0.9857 loss_val: 1.8992 acc_val: 0.6100 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0300s v_time: 0.0124s
# Epoch: 0401 loss_train: 0.0940 acc_train: 0.9500 loss_val: 1.8028 acc_val: 0.6100 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0303s v_time: 0.0123s
# Epoch: 0402 loss_train: 0.0859 acc_train: 0.9714 loss_val: 1.8923 acc_val: 0.6100 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0299s v_time: 0.0122s
# Epoch: 0403 loss_train: 0.0918 acc_train: 0.9714 loss_val: 1.8217 acc_val: 0.6000 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0297s v_time: 0.0122s
# Epoch: 0404 loss_train: 0.2387 acc_train: 0.9429 loss_val: 1.8108 acc_val: 0.6100 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0301s v_time: 0.0125s
# Epoch: 0405 loss_train: 0.1059 acc_train: 0.9643 loss_val: 2.0657 acc_val: 0.5940 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0304s v_time: 0.0123s
# Epoch: 0406 loss_train: 0.1042 acc_train: 0.9786 loss_val: 1.9507 acc_val: 0.5740 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0301s v_time: 0.0122s
# Epoch: 0407 loss_train: 0.1327 acc_train: 0.9571 loss_val: 2.2392 acc_val: 0.5760 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0297s v_time: 0.0123s
# Epoch: 0408 loss_train: 0.1882 acc_train: 0.9429 loss_val: 2.1313 acc_val: 0.5800 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0296s v_time: 0.0122s
# Epoch: 0409 loss_train: 0.1093 acc_train: 0.9571 loss_val: 2.0928 acc_val: 0.5800 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0304s v_time: 0.0125s
# Epoch: 0410 loss_train: 0.2562 acc_train: 0.9214 loss_val: 1.8006 acc_val: 0.6020 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0299s v_time: 0.0123s
# Epoch: 0411 loss_train: 0.0646 acc_train: 0.9857 loss_val: 1.9225 acc_val: 0.6220 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0304s v_time: 0.0125s
# Epoch: 0412 loss_train: 0.1286 acc_train: 0.9571 loss_val: 1.8784 acc_val: 0.6220 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0297s v_time: 0.0123s
# Epoch: 0413 loss_train: 0.0601 acc_train: 0.9929 loss_val: 1.9383 acc_val: 0.6140 cur_lr: 0.02000 s_time: 0.0023s t_time: 0.0299s v_time: 0.0123s
# Epoch: 0414 loss_train: 0.0923 acc_train: 0.9643 loss_val: 2.0708 acc_val: 0.6060 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0298s v_time: 0.0123s
# Epoch: 0415 loss_train: 0.0474 acc_train: 1.0000 loss_val: 1.7800 acc_val: 0.6240 cur_lr: 0.02000 s_time: 0.0022s t_time: 0.0291s v_time: 0.0122s
# Epoch: 0416 loss_train: 0.1448 acc_train: 0.9429 loss_val: 1.8467 acc_val: 0.6160 cur_lr: 0.02000 s_time: 0.0022s t_time: 0.0285s v_time: 0.0125s
# Epoch: 0417 loss_train: 0.0963 acc_train: 0.9643 loss_val: 1.8103 acc_val: 0.6420 cur_lr: 0.02000 s_time: 0.0026s t_time: 0.0300s v_time: 0.0129s
# Epoch: 0418 loss_train: 0.0903 acc_train: 0.9643 loss_val: 1.8734 acc_val: 0.6260 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0300s v_time: 0.0123s
# Epoch: 0419 loss_train: 0.1125 acc_train: 0.9500 loss_val: 1.9616 acc_val: 0.6080 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0298s v_time: 0.0122s
# Epoch: 0420 loss_train: 0.1179 acc_train: 0.9571 loss_val: 1.6522 acc_val: 0.6820 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0299s v_time: 0.0123s
# Epoch: 0421 loss_train: 0.0880 acc_train: 0.9857 loss_val: 1.9211 acc_val: 0.6340 cur_lr: 0.02000 s_time: 0.0023s t_time: 0.0308s v_time: 0.0122s
# Epoch: 0422 loss_train: 0.1480 acc_train: 0.9500 loss_val: 1.7611 acc_val: 0.6400 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0295s v_time: 0.0122s
# Epoch: 0423 loss_train: 0.1326 acc_train: 0.9571 loss_val: 1.7000 acc_val: 0.6300 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0300s v_time: 0.0124s
# Epoch: 0424 loss_train: 0.2900 acc_train: 0.9429 loss_val: 1.9461 acc_val: 0.5920 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0298s v_time: 0.0122s
# Epoch: 0425 loss_train: 0.1055 acc_train: 0.9714 loss_val: 1.9756 acc_val: 0.5920 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0294s v_time: 0.0123s
# Epoch: 0426 loss_train: 0.2268 acc_train: 0.9357 loss_val: 1.8902 acc_val: 0.6100 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0303s v_time: 0.0122s
# Epoch: 0427 loss_train: 0.1829 acc_train: 0.9500 loss_val: 1.9704 acc_val: 0.5880 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0300s v_time: 0.0122s
# Epoch: 0428 loss_train: 0.0664 acc_train: 0.9786 loss_val: 2.1772 acc_val: 0.5760 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0298s v_time: 0.0124s
# Epoch: 0429 loss_train: 0.1910 acc_train: 0.9571 loss_val: 2.1525 acc_val: 0.5720 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0299s v_time: 0.0122s
# Epoch: 0430 loss_train: 0.1462 acc_train: 0.9571 loss_val: 2.0975 acc_val: 0.5900 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0295s v_time: 0.0123s
# Epoch: 0431 loss_train: 0.1552 acc_train: 0.9500 loss_val: 2.0641 acc_val: 0.5720 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0305s v_time: 0.0123s
# Epoch: 0432 loss_train: 0.1597 acc_train: 0.9571 loss_val: 2.0516 acc_val: 0.5840 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0301s v_time: 0.0123s
# Epoch: 0433 loss_train: 0.1510 acc_train: 0.9500 loss_val: 1.7649 acc_val: 0.6320 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0297s v_time: 0.0128s
# Epoch: 0434 loss_train: 0.1556 acc_train: 0.9571 loss_val: 1.8072 acc_val: 0.6520 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0296s v_time: 0.0122s
# Epoch: 0435 loss_train: 0.3760 acc_train: 0.9357 loss_val: 1.8762 acc_val: 0.6260 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0295s v_time: 0.0122s
# Epoch: 0436 loss_train: 0.1013 acc_train: 0.9643 loss_val: 1.6836 acc_val: 0.6440 cur_lr: 0.02000 s_time: 0.0022s t_time: 0.0311s v_time: 0.0123s
# Epoch: 0437 loss_train: 0.1202 acc_train: 0.9571 loss_val: 1.5585 acc_val: 0.6520 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0311s v_time: 0.0123s
# Epoch: 0438 loss_train: 0.0934 acc_train: 0.9643 loss_val: 1.5061 acc_val: 0.6420 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0293s v_time: 0.0122s
# Epoch: 0439 loss_train: 0.1329 acc_train: 0.9571 loss_val: 1.5812 acc_val: 0.6460 cur_lr: 0.02000 s_time: 0.0026s t_time: 0.0301s v_time: 0.0125s
# Epoch: 0440 loss_train: 0.1791 acc_train: 0.9500 loss_val: 1.7412 acc_val: 0.6340 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0298s v_time: 0.0123s
# Epoch: 0441 loss_train: 0.2061 acc_train: 0.9500 loss_val: 1.6917 acc_val: 0.6280 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0304s v_time: 0.0123s
# Epoch: 0442 loss_train: 0.1781 acc_train: 0.9714 loss_val: 1.8085 acc_val: 0.6280 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0297s v_time: 0.0123s
# Epoch: 0443 loss_train: 0.0853 acc_train: 0.9786 loss_val: 1.6840 acc_val: 0.6120 cur_lr: 0.02000 s_time: 0.0023s t_time: 0.0291s v_time: 0.0122s
# Epoch: 0444 loss_train: 0.1374 acc_train: 0.9643 loss_val: 1.7387 acc_val: 0.6560 cur_lr: 0.02000 s_time: 0.0022s t_time: 0.0277s v_time: 0.0122s
# Epoch: 0445 loss_train: 0.1621 acc_train: 0.9286 loss_val: 1.5862 acc_val: 0.6600 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0296s v_time: 0.0123s
# Epoch: 0446 loss_train: 0.0619 acc_train: 0.9857 loss_val: 1.8744 acc_val: 0.6260 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0304s v_time: 0.0123s
# Epoch: 0447 loss_train: 0.0764 acc_train: 0.9714 loss_val: 1.7569 acc_val: 0.6440 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0302s v_time: 0.0124s
# Epoch: 0448 loss_train: 0.1085 acc_train: 0.9643 loss_val: 2.0034 acc_val: 0.6140 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0300s v_time: 0.0122s
# Epoch: 0449 loss_train: 0.1095 acc_train: 0.9714 loss_val: 1.8998 acc_val: 0.6100 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0305s v_time: 0.0125s
# Epoch: 0450 loss_train: 0.1549 acc_train: 0.9500 loss_val: 1.7938 acc_val: 0.6060 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0295s v_time: 0.0122s
# Epoch: 0451 loss_train: 0.1965 acc_train: 0.9643 loss_val: 1.9550 acc_val: 0.5860 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0301s v_time: 0.0122s
# Epoch: 0452 loss_train: 0.1046 acc_train: 0.9714 loss_val: 1.9723 acc_val: 0.6040 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0300s v_time: 0.0123s
# Epoch: 0453 loss_train: 0.0551 acc_train: 0.9929 loss_val: 1.9715 acc_val: 0.5920 cur_lr: 0.02000 s_time: 0.0025s t_time: 0.0291s v_time: 0.0123s
# Epoch: 0454 loss_train: 0.0855 acc_train: 0.9643 loss_val: 1.8238 acc_val: 0.6220 cur_lr: 0.02000 s_time: 0.0022s t_time: 0.0286s v_time: 0.0128s
# Epoch: 0455 loss_train: 0.0985 acc_train: 0.9643 loss_val: 1.8433 acc_val: 0.6060 cur_lr: 0.02000 s_time: 0.0022s t_time: 0.0283s v_time: 0.0122s
# Epoch: 0456 loss_train: 0.2130 acc_train: 0.9357 loss_val: 1.8010 acc_val: 0.6420 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0303s v_time: 0.0125s
# Epoch: 0457 loss_train: 0.0895 acc_train: 0.9643 loss_val: 1.8299 acc_val: 0.6440 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0296s v_time: 0.0123s
# Epoch: 0458 loss_train: 0.1534 acc_train: 0.9714 loss_val: 1.7527 acc_val: 0.6260 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0297s v_time: 0.0123s
# Epoch: 0459 loss_train: 0.2021 acc_train: 0.9571 loss_val: 1.9928 acc_val: 0.6020 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0297s v_time: 0.0127s
# Epoch: 0460 loss_train: 0.2575 acc_train: 0.9500 loss_val: 1.8199 acc_val: 0.6240 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0298s v_time: 0.0123s
# Epoch: 0461 loss_train: 0.1984 acc_train: 0.9643 loss_val: 1.7268 acc_val: 0.6620 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0304s v_time: 0.0126s
# Epoch: 0462 loss_train: 0.1569 acc_train: 0.9500 loss_val: 1.6897 acc_val: 0.6440 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0301s v_time: 0.0123s
# Epoch: 0463 loss_train: 0.1046 acc_train: 0.9643 loss_val: 1.5940 acc_val: 0.6540 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0298s v_time: 0.0123s
# Epoch: 0464 loss_train: 0.1412 acc_train: 0.9357 loss_val: 1.7267 acc_val: 0.6340 cur_lr: 0.02000 s_time: 0.0023s t_time: 0.0306s v_time: 0.0123s
# Epoch: 0465 loss_train: 0.1820 acc_train: 0.9643 loss_val: 2.0183 acc_val: 0.6060 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0296s v_time: 0.0125s
# Epoch: 0466 loss_train: 0.0881 acc_train: 0.9714 loss_val: 1.9736 acc_val: 0.6360 cur_lr: 0.02000 s_time: 0.0026s t_time: 0.0304s v_time: 0.0123s
# Epoch: 0467 loss_train: 0.0750 acc_train: 0.9786 loss_val: 1.8954 acc_val: 0.6040 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0292s v_time: 0.0122s
# Epoch: 0468 loss_train: 0.1136 acc_train: 0.9786 loss_val: 1.9048 acc_val: 0.6220 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0297s v_time: 0.0126s
# Epoch: 0469 loss_train: 0.1629 acc_train: 0.9500 loss_val: 1.8871 acc_val: 0.6200 cur_lr: 0.02000 s_time: 0.0029s t_time: 0.0300s v_time: 0.0123s
# Epoch: 0470 loss_train: 0.0937 acc_train: 0.9571 loss_val: 2.1824 acc_val: 0.5740 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0300s v_time: 0.0123s
# Epoch: 0471 loss_train: 0.1157 acc_train: 0.9500 loss_val: 1.8787 acc_val: 0.6100 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0310s v_time: 0.0123s
# Epoch: 0472 loss_train: 0.1618 acc_train: 0.9571 loss_val: 1.8496 acc_val: 0.6100 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0298s v_time: 0.0122s
# Epoch: 0473 loss_train: 0.1929 acc_train: 0.9643 loss_val: 2.1217 acc_val: 0.5700 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0302s v_time: 0.0125s
# Epoch: 0474 loss_train: 0.1142 acc_train: 0.9643 loss_val: 2.1971 acc_val: 0.6000 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0296s v_time: 0.0123s
# Epoch: 0475 loss_train: 0.1838 acc_train: 0.9429 loss_val: 2.0088 acc_val: 0.5700 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0294s v_time: 0.0124s
# Epoch: 0476 loss_train: 0.1984 acc_train: 0.9643 loss_val: 2.0186 acc_val: 0.5840 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0306s v_time: 0.0123s
# Epoch: 0477 loss_train: 0.1347 acc_train: 0.9571 loss_val: 2.0179 acc_val: 0.5580 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0299s v_time: 0.0123s
# Epoch: 0478 loss_train: 0.2281 acc_train: 0.9714 loss_val: 1.9697 acc_val: 0.5860 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0296s v_time: 0.0122s
# Epoch: 0479 loss_train: 0.1308 acc_train: 0.9429 loss_val: 1.8687 acc_val: 0.6140 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0299s v_time: 0.0122s
# Epoch: 0480 loss_train: 0.1004 acc_train: 0.9786 loss_val: 1.7890 acc_val: 0.6040 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0300s v_time: 0.0124s
# Epoch: 0481 loss_train: 0.1213 acc_train: 0.9643 loss_val: 1.8237 acc_val: 0.6160 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0311s v_time: 0.0123s
# Epoch: 0482 loss_train: 0.1166 acc_train: 0.9643 loss_val: 1.7005 acc_val: 0.6440 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0296s v_time: 0.0122s
# Epoch: 0483 loss_train: 0.1435 acc_train: 0.9714 loss_val: 1.8715 acc_val: 0.6240 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0293s v_time: 0.0123s
# Epoch: 0484 loss_train: 0.0781 acc_train: 0.9857 loss_val: 1.7693 acc_val: 0.6320 cur_lr: 0.02000 s_time: 0.0030s t_time: 0.0294s v_time: 0.0126s
# Epoch: 0485 loss_train: 0.1046 acc_train: 0.9714 loss_val: 1.7423 acc_val: 0.6260 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0293s v_time: 0.0122s
# Epoch: 0486 loss_train: 0.1300 acc_train: 0.9500 loss_val: 1.6956 acc_val: 0.6280 cur_lr: 0.02000 s_time: 0.0026s t_time: 0.0299s v_time: 0.0121s
# Epoch: 0487 loss_train: 0.0399 acc_train: 0.9857 loss_val: 1.8112 acc_val: 0.6380 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0305s v_time: 0.0123s
# Epoch: 0488 loss_train: 0.1432 acc_train: 0.9643 loss_val: 1.8915 acc_val: 0.6100 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0295s v_time: 0.0122s
# Epoch: 0489 loss_train: 0.0966 acc_train: 0.9643 loss_val: 1.8580 acc_val: 0.6200 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0298s v_time: 0.0125s
# Epoch: 0490 loss_train: 0.1273 acc_train: 0.9500 loss_val: 1.8344 acc_val: 0.6540 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0299s v_time: 0.0123s
# Epoch: 0491 loss_train: 0.1096 acc_train: 0.9643 loss_val: 1.8662 acc_val: 0.6340 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0304s v_time: 0.0123s
# Epoch: 0492 loss_train: 0.0739 acc_train: 0.9786 loss_val: 1.8190 acc_val: 0.6360 cur_lr: 0.02000 s_time: 0.0025s t_time: 0.0302s v_time: 0.0122s
# Epoch: 0493 loss_train: 0.1531 acc_train: 0.9571 loss_val: 1.8138 acc_val: 0.6340 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0294s v_time: 0.0122s
# Epoch: 0494 loss_train: 0.0582 acc_train: 0.9929 loss_val: 1.7573 acc_val: 0.6400 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0304s v_time: 0.0122s
# Epoch: 0495 loss_train: 0.1173 acc_train: 0.9571 loss_val: 1.8637 acc_val: 0.6440 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0297s v_time: 0.0123s
# Epoch: 0496 loss_train: 0.1309 acc_train: 0.9571 loss_val: 1.7970 acc_val: 0.6320 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0309s v_time: 0.0162s
# Epoch: 0497 loss_train: 0.1864 acc_train: 0.9571 loss_val: 1.9511 acc_val: 0.6260 cur_lr: 0.02000 s_time: 0.0032s t_time: 0.0311s v_time: 0.0122s
# Epoch: 0498 loss_train: 0.1294 acc_train: 0.9786 loss_val: 1.7876 acc_val: 0.6380 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0298s v_time: 0.0122s
# Epoch: 0499 loss_train: 0.1073 acc_train: 0.9714 loss_val: 1.7104 acc_val: 0.6340 cur_lr: 0.02000 s_time: 0.0027s t_time: 0.0302s v_time: 0.0125s
# Epoch: 0500 loss_train: 0.4472 acc_train: 0.9500 loss_val: 1.8225 acc_val: 0.6400 cur_lr: 0.02000 s_time: 0.0028s t_time: 0.0300s v_time: 0.0122s
# Optimization Finished!
# Total time elapsed: 22.5886s

# %% [markdown]
# Mean and Standard Deviation

# %%
# Testing
(test_adj, test_fea) = sampler.get_test_set(normalization=normalization, cuda=cuda)
if mixmode:
    test_adj = test_adj.cuda()
(loss_test, acc_test) = test(test_adj, test_fea)
print("%.6f\t%.6f\t%.6f\t%.6f\t%.6f\t%.6f" % (
loss_train[-1], loss_val[-1], loss_test, acc_train[-1], acc_val[-1], acc_test))
print(dataset)
print("Mean Epoch Times:", np.mean(EpochTimes))
# Out:
# Test set results: loss= 1.3717 auc= 0.9678 accuracy= 0.6541
# accuracy=0.65408
# 0.745350	1.883498	1.371742	0.788277	0.558419	0.654079
# Cora
# Mean Epoch Times: 0.0186201303655451

# %%
a= [0.644734,0.654079,0.654079]
mean_a = np.mean(a)
std_dev_a = np.std(a)
print(mean_a, std_dev_a)
# Out:
# 0.650964 0.0044052752467921615
