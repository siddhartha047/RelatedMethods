# %%
import os
import sys
import math
import copy 
import torch 
import random
DEBUG = False
import numpy as np
import torch_sparse
import pandas as pd 
import pickle as pkl
from tqdm import tqdm
from time import time
import networkx as nx
from dgl import DGLGraph
from scipy import linalg
from pathlib import Path
from torch import Tensor
import scipy.sparse as sp
from random import randint
from dgl import transforms
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
from scipy import sparse, stats
from scipy.sparse import csgraph
from scipy.sparse import csr_matrix
from dgl import from_networkx, DGLGraph
from torch_geometric.utils import scatter
from dgl.data import citation_graph as citegrh
from torch_geometric.typing import SparseTensor
from torch_geometric.utils import to_undirected
from torch_geometric.utils import remove_self_loops
from sklearn.metrics.pairwise import cosine_similarity
# from ipynb.fs.full.Dataset import get_data_from_dataset
# from ipynb.fs.full.Dataset import get_data_from_dataset,train_val_test_mask
from ogb.nodeproppred import Evaluator, PygNodePropPredDataset
from typing import Callable, List, NamedTuple, Optional, Tuple, Union
from torch_geometric.utils import add_self_loops,add_remaining_self_loops
# from ipynb.fs.full.SpectralSparsifier import EffectiveResistance, LocalEffectiveResistance, get_sparse_adj_matrix

# %%
import numpy as np
import torch
import pickle as pkl
import sys
import networkx as nx
import numpy as np
import scipy.sparse as sp

import argparse
import time
from time import localtime
import torch
import torch.nn.functional as F
from dgl import DGLGraph
from dgl.data import register_data_args, load_data
import random
from torch.backends import cudnn
import networkx as nx
import numpy as np
import torch
import torch.nn as nn
import dgl.function as fn
from dgl.nn.pytorch import edge_softmax
import numpy as np
import torch.nn.functional as F

import torch
import torch.nn as nn
import dgl.function as fn
from dgl.nn.pytorch import edge_softmax
import numpy as np
import torch.nn.functional as F

# %%
import DeviceDir

DIR, RESULTS_DIR = DeviceDir.get_directory()
device, NUM_PROCESSORS = DeviceDir.get_device()

# %%
from ipynb.fs.full.SGSLoadDataset import LOAD_DATASET

DATASET_NAME = "SmallCora"
data, dataset  = LOAD_DATASET(DIR, DATASET_NAME)
num_classes = max(data.y).item()+1
# Out:
# SmallCora N: 2708 E: 10556 F: 1433 C: 7 d: 3.90 lr: 0.05 i: False s: False u: True

# %%
sig = nn.Sigmoid()
hardtanh = nn.Hardtanh(0,1)
gamma = -0.1
zeta = 1.1
beta = 0.66
eps = 1e-20
const1 = beta*np.log(-gamma/zeta + eps)

def l0_train(logAlpha, min, max):
    U = torch.rand(logAlpha.size()).type_as(logAlpha) + eps
    s = sig((torch.log(U / (1 - U)) + logAlpha) / beta)
    s_bar = s * (zeta - gamma) + gamma
    mask = F.hardtanh(s_bar, min, max)
    return mask

def l0_test(logAlpha, min, max):
    s = sig(logAlpha/beta)
    s_bar = s * (zeta - gamma) + gamma
    mask = F.hardtanh(s_bar, min, max)
    return mask

def get_loss2(logAlpha):
    return sig(logAlpha - const1)


class GraphAttention(nn.Module):
    def __init__(self,
                 g,
                 in_dim,
                 out_dim,
                 num_heads,
                 feat_drop,
                 attn_drop,
                 alpha,
                 bias_l0,
                 residual=False,l0=0, min=0):
        super(GraphAttention, self).__init__()
        self.g = g
        self.num_heads = num_heads
        self.fc = nn.Linear(in_dim, num_heads * out_dim, bias=False)
        if feat_drop:
            self.feat_drop = nn.Dropout(feat_drop)
        else:
            self.feat_drop = lambda x : x
        if attn_drop:
            self.attn_drop = nn.Dropout(attn_drop)
        else:
            self.attn_drop = lambda x : x
        self.attn_l = nn.Parameter(torch.Tensor(size=(1, 1, out_dim)))
        self.attn_r = nn.Parameter(torch.Tensor(size=(1, 1, out_dim)))
        self.bias_l0 = nn.Parameter(torch.FloatTensor([bias_l0]))

        nn.init.xavier_normal_(self.fc.weight.data, gain=1.414)
        nn.init.xavier_normal_(self.attn_l.data, gain=1.414)
        nn.init.xavier_normal_(self.attn_r.data, gain=1.414)
        self.leaky_relu = nn.LeakyReLU(alpha)
        self.softmax = edge_softmax
        self.residual = residual
        self.num = 0
        self.l0 = l0
        self.loss = 0
        self.dis = []
        self.min=min
        if residual:
            if in_dim != out_dim:
                self.res_fc = nn.Linear(in_dim, num_heads * out_dim, bias=False)
                nn.init.xavier_normal_(self.res_fc.weight.data, gain=1.414)
            else:
                self.res_fc = None

    def forward(self, inputs, edges="__ALL__", skip=0):
        self.loss = 0
        # prepare
        h = self.feat_drop(inputs)  # NxD
        ft = self.fc(h).reshape((h.shape[0], self.num_heads, -1))  # NxHxD'
        a1 = (ft * self.attn_l).sum(dim=-1).unsqueeze(-1) # N x H x 1
        a2 = (ft * self.attn_r).sum(dim=-1).unsqueeze(-1) # N x H x 1
      
        self.g.ndata.update({'ft' : ft, 'a1' : a1, 'a2' : a2})

        if skip == 0:
            # 1. compute edge attention
            self.g.apply_edges(self.edge_attention, edges)

            # 2. compute softmax
            if self.l0 == 1:
                ind = self.g.nodes()
                self.g.apply_edges(self.loop, edges=(ind, ind))

            self.edge_softmax()

            if self.l0 == 1:
                self.g.apply_edges(self.norm)

        # 2. compute the aggregated node features scaled by the dropped,
            edges = self.g.edata['a'].squeeze().nonzero().squeeze()


        self.g.edata['a_drop'] = self.attn_drop(self.g.edata['a'])
        self.num = (self.g.edata['a'] > 0).sum()
        self.g.update_all(fn.u_mul_e('ft', 'a_drop', 'ft'), fn.sum('ft', 'ft'))
        ret = self.g.ndata['ft']

        # 4. residual
        if self.residual:
            if self.res_fc is not None:
                resval = self.res_fc(h).reshape((h.shape[0], self.num_heads, -1))  # NxHxD'
            else:
                resval = torch.unsqueeze(h, 1)  # Nx1xD'
            ret = resval + ret
        return ret, edges

    def edge_attention(self, edges):
        # an edge UDF to compute unnormalized attention values from src and dst
        if self.l0 == 0:
            m = self.leaky_relu(edges.src['a1'] + edges.dst['a2'])
        else:
            tmp = edges.src['a1'] + edges.dst['a2']
            logits = tmp + self.bias_l0

            if self.training:
                m = l0_train(logits, 0, 1)
            else:
                m = l0_test(logits, 0, 1)
            self.loss = get_loss2(logits[:,0,:]).sum()
        return {'a': m}

    def norm(self, edges):
        # normalize attention
        a = edges.data['a'] / edges.dst['z']
        return {'a' : a}

    def loop(self, edges):
        # set attention to itself as 1
        return {'a': torch.pow(edges.data['a'], 0)}

    def normalize(self, logits):
        self._logits_name = "_logits"
        self._normalizer_name = "_norm"
        self.g.edata[self._logits_name] = logits
        self.g.update_all(fn.copy_edge(self._logits_name, self._logits_name),
                         fn.sum(self._logits_name, self._normalizer_name))
        return self.g.edata.pop(self._logits_name), self.g.ndata.pop(self._normalizer_name)

    def edge_softmax(self):

        if self.l0 == 0:
            scores = self.softmax(self.g, self.g.edata.pop('a'))
        else:
            scores, normalizer = self.normalize(self.g.edata.pop('a'))
            self.g.ndata['z'] = normalizer[:,0,:].unsqueeze(1)

        self.g.edata['a'] = scores[:,0,:].unsqueeze(1)

class GAT(nn.Module):
    def __init__(self,
                 g,
                 num_layers,
                 in_dim,
                 num_hidden,
                 num_classes,
                 heads,
                 activation,
                 feat_drop,
                 attn_drop,
                 alpha,
                 bias_l0,
                 residual, l0=0):
        super(GAT, self).__init__()
        self.g = g
        self.num_layers = num_layers
        self.gat_layers = nn.ModuleList()
        self.activation = activation
        # input projection (no residual)
        self.gat_layers.append(GraphAttention(
            g, in_dim, num_hidden, heads[0], feat_drop, attn_drop, alpha,bias_l0, False, l0=l0, min=0))
        # hidden layers
        for l in range(1, num_layers):
            # due to multi-head, the in_dim = num_hidden * num_heads
            self.gat_layers.append(GraphAttention(
                g, num_hidden * heads[l-1], num_hidden, heads[l],
                feat_drop, attn_drop, alpha,bias_l0, residual, l0=l0, min=0))
        # output projection
        self.gat_layers.append(GraphAttention(
            g, num_hidden * heads[-2], num_classes, heads[-1],
            feat_drop, attn_drop, alpha,bias_l0, residual, l0=l0))


    def forward(self, inputs):

        h = inputs
        edges = "__ALL__"
        h, edges = self.gat_layers[0](h, edges)
        h = self.activation(h.flatten(1))
        for l in range(1, self.num_layers):
            h, _= self.gat_layers[l](h, edges, skip=1)
            h = self.activation(h.flatten(1))

        # output projection
        logits,_ = self.gat_layers[-1](h, edges, skip=1)
        logits = logits.mean(1)
        return logits

# %% [markdown]
# utils .py

# %%
class EarlyStopping:
    def __init__(self, patience=10):
        self.patience = patience
        self.counter = 0
        self.best_score = None
        self.early_stop = False

    def step(self, acc, model):
        score = acc
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(model)
        elif score < self.best_score:
            self.counter += 1
            # print('EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(model)
            self.counter = 0
        return self.early_stop

    def save_checkpoint(self, model):
        '''Saves model when validation loss decrease.'''
        torch.save(model.state_dict(), 'es_checkpoint.pt')

# %% [markdown]
# GAT . py

# %%
from sklearn.metrics import f1_score

def accuracy(logits, labels):
#     _, indices = torch.max(logits, dim=1)
#     correct = torch.sum(indices == labels)
#     return correct.item() * 1.0 / len(labels)
    preds = logits.argmax(dim=1)
    f1 = f1_score(labels.cpu(), preds.cpu(), average='micro')
    return f1
    

def evaluate(model, features, labels, mask,loss_fcn):
    model.eval()
    with torch.no_grad():
        logits = model(features)
        logits = logits[mask]
        labels = labels[mask]
        loss_data = loss_fcn(logits, labels)
        return accuracy(logits, labels), loss_data

def set_seeds(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if gpu >= 0:
        torch.cuda.manual_seed(seed)
        cudnn.benchmark = False
        cudnn.deterministic = True

# %%
num_out_heads = 4
num_heads = 15
num_layers = 1
gpu = -1
l0 = 0
num_hidden = 128
residual = False 
idrop = 0.6
adrop = 0.6
lr = 0.005 
weight_decay = 5e-4
alpha = 0.2
early_stop = True 
fastmode = False 
seed = 123 
bias = 0 
loss_lo = 0 
syn_type = "scipy" 
self_loop = False 
sess ='default'
loss_l0  = 0
weight_decay = 0
l0 = 0

#data, dataset = get_data_from_dataset('cornell5')
epochs = 250

data = data.to(device)

#features = torch.FloatTensor(data.x)
features = data.x
#labels = torch.LongTensor(data.y)
labels = data.y
train_mask = data.train_mask
val_mask = data.val_mask
test_mask = data.test_mask
num_feats = features.shape[1]
n_classes = max(data.y).item()+1
n_edges = data.num_edges
current_time = time.strftime('%d_%H:%M:%S', localtime())
print("HELLO WORLD")

print("""----Data statistics------'
    #Edges %d
    #Classes %d
    #Train samples %d
    #Val samples %d
    #Test samples %d""" %
        (n_edges, n_classes,
        train_mask.sum().item(),
        val_mask.sum().item(),
        test_mask.sum().item()))

cuda = True

import dgl
from dgl.data.utils import generate_mask_tensor

g = dgl.graph((data.edge_index[0], data.edge_index[1]), num_nodes=data.x.size(0))

# Add node features
g.ndata['feat'] = data.x
g.ndata['label'] = data.y
# g.ndata['train_mask'] = generate_mask_tensor(data.train_mask.numpy())
# g.ndata['val_mask'] = generate_mask_tensor(data.val_mask.numpy())
# g.ndata['test_mask'] = generate_mask_tensor(data.test_mask.numpy())

g.ndata['train_mask'] = data.train_mask
g.ndata['val_mask'] = data.val_mask
g.ndata['test_mask'] = data.test_mask


n_edges = g.number_of_edges()
heads = ([num_heads] * num_layers) + [num_out_heads]

model = GAT(g,
            num_layers,
            num_feats,
            num_hidden,
            n_classes,
            heads,
            F.elu,
            idrop,
            adrop,
            alpha,
            bias,
            residual,
            l0).to(device)
print(model)

if early_stop:
    stopper = EarlyStopping(patience=150)
loss_fcn = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
dur = []
time_used = 0
# Out:
# HELLO WORLD
# ----Data statistics------'
#     #Edges 10556
#     #Classes 7
#     #Train samples 140
#     #Val samples 500
#     #Test samples 1000
# GAT(
#   (gat_layers): ModuleList(
#     (0): GraphAttention(
#       (fc): Linear(in_features=1433, out_features=240, bias=False)
#       (feat_drop): Dropout(p=0.6, inplace=False)
#       (attn_drop): Dropout(p=0.6, inplace=False)
#       (leaky_relu): LeakyReLU(negative_slope=0.2)
#     )
#     (1): GraphAttention(
#       (fc): Linear(in_features=240, out_features=28, bias=False)
#       (feat_drop): Dropout(p=0.6, inplace=False)
#       (attn_drop): Dropout(p=0.6, inplace=False)
#       (leaky_relu): LeakyReLU(negative_slope=0.2)
#     )
#   )
# )

# %%
model
# Out:
# GAT(
#   (gat_layers): ModuleList(
#     (0): GraphAttention(
#       (fc): Linear(in_features=1433, out_features=240, bias=False)
#       (feat_drop): Dropout(p=0.6, inplace=False)
#       (attn_drop): Dropout(p=0.6, inplace=False)
#       (leaky_relu): LeakyReLU(negative_slope=0.2)
#     )
#     (1): GraphAttention(
#       (fc): Linear(in_features=240, out_features=28, bias=False)
#       (feat_drop): Dropout(p=0.6, inplace=False)
#       (attn_drop): Dropout(p=0.6, inplace=False)
#       (leaky_relu): LeakyReLU(negative_slope=0.2)
#     )
#   )
# )

# %%
dur = []
best_test_f1 = 0

for epoch in range(epochs):
    
    model.train()
    t0 = time.time()

    # forward
    logits = model(features)
    loss = loss_fcn(logits[train_mask], labels[train_mask])

    loss_l0 = loss_l0*( model.gat_layers[0].loss)
    optimizer.zero_grad()
    (loss + loss_l0).backward()
    optimizer.step()
    dur.append(time.time() - t0)

    train_acc = accuracy(logits[train_mask], labels[train_mask])

    
    if fastmode:
        val_acc, loss = accuracy(logits[val_mask], labels[val_mask], loss_fcn)
    else:
        val_acc,_ = evaluate(model, features, labels, val_mask, loss_fcn)
        # if early_stop:
        #     if stopper.step(val_acc, model):   
        #         break        
    
    print("Epoch {:05d} | Time(s) {:.4f} | Loss {:.4f} | TrainAcc {:.4f} |"
            " ValAcc {:.4f} | ETputs(KTEPS) {:.2f}".format(epoch, np.mean(dur), loss.item(), train_acc,
                    val_acc, n_edges / np.mean(dur) / 1000))
print(dataset.name)


print("Time per epoch: ", np.mean(dur))
# Out:
# Epoch 00000 | Time(s) 0.0131 | Loss 0.6807 | TrainAcc 0.6786 | ValAcc 0.7700 | ETputs(KTEPS) 807.10
# Epoch 00001 | Time(s) 0.0117 | Loss 0.8048 | TrainAcc 0.6929 | ValAcc 0.7680 | ETputs(KTEPS) 900.67
# Epoch 00002 | Time(s) 0.0109 | Loss 0.6905 | TrainAcc 0.7143 | ValAcc 0.7680 | ETputs(KTEPS) 966.37
# Epoch 00003 | Time(s) 0.0104 | Loss 0.7753 | TrainAcc 0.6714 | ValAcc 0.7700 | ETputs(KTEPS) 1019.53
# Epoch 00004 | Time(s) 0.0099 | Loss 0.6317 | TrainAcc 0.7214 | ValAcc 0.7680 | ETputs(KTEPS) 1063.21
# Epoch 00005 | Time(s) 0.0096 | Loss 0.7576 | TrainAcc 0.6786 | ValAcc 0.7700 | ETputs(KTEPS) 1102.58
# Epoch 00006 | Time(s) 0.0093 | Loss 0.7576 | TrainAcc 0.6714 | ValAcc 0.7700 | ETputs(KTEPS) 1139.93
# Epoch 00007 | Time(s) 0.0090 | Loss 0.6932 | TrainAcc 0.7286 | ValAcc 0.7680 | ETputs(KTEPS) 1175.01
# Epoch 00008 | Time(s) 0.0087 | Loss 0.5536 | TrainAcc 0.7786 | ValAcc 0.7680 | ETputs(KTEPS) 1207.30
# Epoch 00009 | Time(s) 0.0085 | Loss 0.8084 | TrainAcc 0.6286 | ValAcc 0.7680 | ETputs(KTEPS) 1237.34
# Epoch 00010 | Time(s) 0.0083 | Loss 0.7529 | TrainAcc 0.6786 | ValAcc 0.7700 | ETputs(KTEPS) 1265.80
# Epoch 00011 | Time(s) 0.0082 | Loss 0.6710 | TrainAcc 0.7071 | ValAcc 0.7660 | ETputs(KTEPS) 1293.57
# Epoch 00012 | Time(s) 0.0080 | Loss 0.6809 | TrainAcc 0.7286 | ValAcc 0.7560 | ETputs(KTEPS) 1320.63
# Epoch 00013 | Time(s) 0.0078 | Loss 0.7394 | TrainAcc 0.7357 | ValAcc 0.7540 | ETputs(KTEPS) 1347.26
# Epoch 00014 | Time(s) 0.0077 | Loss 0.7847 | TrainAcc 0.6857 | ValAcc 0.7540 | ETputs(KTEPS) 1368.60
# Epoch 00015 | Time(s) 0.0076 | Loss 0.7666 | TrainAcc 0.6786 | ValAcc 0.7540 | ETputs(KTEPS) 1392.54
# Epoch 00016 | Time(s) 0.0074 | Loss 0.8743 | TrainAcc 0.6000 | ValAcc 0.7520 | ETputs(KTEPS) 1418.04
# Epoch 00017 | Time(s) 0.0073 | Loss 0.6525 | TrainAcc 0.7357 | ValAcc 0.7520 | ETputs(KTEPS) 1442.96
# Epoch 00018 | Time(s) 0.0072 | Loss 0.6485 | TrainAcc 0.7357 | ValAcc 0.7520 | ETputs(KTEPS) 1467.48
# Epoch 00019 | Time(s) 0.0071 | Loss 0.7456 | TrainAcc 0.7071 | ValAcc 0.7520 | ETputs(KTEPS) 1492.55
# Epoch 00020 | Time(s) 0.0070 | Loss 0.6008 | TrainAcc 0.7571 | ValAcc 0.7500 | ETputs(KTEPS) 1516.68
# Epoch 00021 | Time(s) 0.0069 | Loss 0.6286 | TrainAcc 0.7286 | ValAcc 0.7540 | ETputs(KTEPS) 1539.97
# Epoch 00022 | Time(s) 0.0068 | Loss 0.6861 | TrainAcc 0.7429 | ValAcc 0.7520 | ETputs(KTEPS) 1562.18
# Epoch 00023 | Time(s) 0.0067 | Loss 0.6800 | TrainAcc 0.7429 | ValAcc 0.7500 | ETputs(KTEPS) 1583.30
# Epoch 00024 | Time(s) 0.0066 | Loss 0.8126 | TrainAcc 0.6357 | ValAcc 0.7520 | ETputs(KTEPS) 1603.37
# Epoch 00025 | Time(s) 0.0065 | Loss 0.7282 | TrainAcc 0.7071 | ValAcc 0.7500 | ETputs(KTEPS) 1622.80
# Epoch 00026 | Time(s) 0.0064 | Loss 0.6839 | TrainAcc 0.7214 | ValAcc 0.7500 | ETputs(KTEPS) 1641.45
# Epoch 00027 | Time(s) 0.0064 | Loss 0.6719 | TrainAcc 0.7214 | ValAcc 0.7520 | ETputs(KTEPS) 1659.42
# Epoch 00028 | Time(s) 0.0063 | Loss 0.7615 | TrainAcc 0.6786 | ValAcc 0.7520 | ETputs(KTEPS) 1676.56
# Epoch 00029 | Time(s) 0.0062 | Loss 0.6930 | TrainAcc 0.7429 | ValAcc 0.7520 | ETputs(KTEPS) 1692.90
# Epoch 00030 | Time(s) 0.0062 | Loss 0.7796 | TrainAcc 0.7071 | ValAcc 0.7540 | ETputs(KTEPS) 1708.85
# Epoch 00031 | Time(s) 0.0061 | Loss 0.5821 | TrainAcc 0.7429 | ValAcc 0.7480 | ETputs(KTEPS) 1724.17
# Epoch 00032 | Time(s) 0.0061 | Loss 0.7418 | TrainAcc 0.7214 | ValAcc 0.7480 | ETputs(KTEPS) 1738.99
# Epoch 00033 | Time(s) 0.0060 | Loss 0.7065 | TrainAcc 0.6929 | ValAcc 0.7480 | ETputs(KTEPS) 1752.68
# Epoch 00034 | Time(s) 0.0060 | Loss 0.6123 | TrainAcc 0.7357 | ValAcc 0.7500 | ETputs(KTEPS) 1766.75
# Epoch 00035 | Time(s) 0.0060 | Loss 0.7017 | TrainAcc 0.7143 | ValAcc 0.7540 | ETputs(KTEPS) 1773.11
# Epoch 00036 | Time(s) 0.0059 | Loss 0.7650 | TrainAcc 0.7143 | ValAcc 0.7560 | ETputs(KTEPS) 1785.02
# Epoch 00037 | Time(s) 0.0059 | Loss 0.6277 | TrainAcc 0.7286 | ValAcc 0.7540 | ETputs(KTEPS) 1798.61
# Epoch 00038 | Time(s) 0.0058 | Loss 0.7092 | TrainAcc 0.6857 | ValAcc 0.7540 | ETputs(KTEPS) 1810.68
# Epoch 00039 | Time(s) 0.0058 | Loss 0.6492 | TrainAcc 0.7071 | ValAcc 0.7560 | ETputs(KTEPS) 1822.47
# Epoch 00040 | Time(s) 0.0058 | Loss 0.7448 | TrainAcc 0.6929 | ValAcc 0.7580 | ETputs(KTEPS) 1833.99
# Epoch 00041 | Time(s) 0.0057 | Loss 0.8515 | TrainAcc 0.6286 | ValAcc 0.7560 | ETputs(KTEPS) 1845.08
# Epoch 00042 | Time(s) 0.0057 | Loss 0.6662 | TrainAcc 0.7429 | ValAcc 0.7540 | ETputs(KTEPS) 1855.60
# Epoch 00043 | Time(s) 0.0057 | Loss 0.6815 | TrainAcc 0.7143 | ValAcc 0.7540 | ETputs(KTEPS) 1865.90
# Epoch 00044 | Time(s) 0.0056 | Loss 0.7172 | TrainAcc 0.7000 | ValAcc 0.7540 | ETputs(KTEPS) 1875.80
# Epoch 00045 | Time(s) 0.0056 | Loss 0.6893 | TrainAcc 0.7143 | ValAcc 0.7620 | ETputs(KTEPS) 1885.29
# Epoch 00046 | Time(s) 0.0056 | Loss 0.7858 | TrainAcc 0.6929 | ValAcc 0.7600 | ETputs(KTEPS) 1894.65
# Epoch 00047 | Time(s) 0.0055 | Loss 0.5998 | TrainAcc 0.7143 | ValAcc 0.7600 | ETputs(KTEPS) 1903.62
# Epoch 00048 | Time(s) 0.0055 | Loss 0.7697 | TrainAcc 0.6571 | ValAcc 0.7640 | ETputs(KTEPS) 1912.18
# Epoch 00049 | Time(s) 0.0055 | Loss 0.6621 | TrainAcc 0.7071 | ValAcc 0.7600 | ETputs(KTEPS) 1920.69
# Epoch 00050 | Time(s) 0.0055 | Loss 0.6446 | TrainAcc 0.7143 | ValAcc 0.7640 | ETputs(KTEPS) 1928.85
# Epoch 00051 | Time(s) 0.0055 | Loss 0.6947 | TrainAcc 0.6929 | ValAcc 0.7640 | ETputs(KTEPS) 1936.77
# Epoch 00052 | Time(s) 0.0054 | Loss 0.6665 | TrainAcc 0.7214 | ValAcc 0.7680 | ETputs(KTEPS) 1944.56
# Epoch 00053 | Time(s) 0.0054 | Loss 0.5919 | TrainAcc 0.7643 | ValAcc 0.7660 | ETputs(KTEPS) 1952.09
# Epoch 00054 | Time(s) 0.0054 | Loss 0.6773 | TrainAcc 0.7286 | ValAcc 0.7660 | ETputs(KTEPS) 1959.13
# Epoch 00055 | Time(s) 0.0054 | Loss 0.6378 | TrainAcc 0.7286 | ValAcc 0.7680 | ETputs(KTEPS) 1966.63
# Epoch 00056 | Time(s) 0.0053 | Loss 0.6774 | TrainAcc 0.7429 | ValAcc 0.7700 | ETputs(KTEPS) 1973.79
# Epoch 00057 | Time(s) 0.0053 | Loss 0.6944 | TrainAcc 0.6929 | ValAcc 0.7680 | ETputs(KTEPS) 1978.60
# Epoch 00058 | Time(s) 0.0053 | Loss 0.7313 | TrainAcc 0.6786 | ValAcc 0.7700 | ETputs(KTEPS) 1985.71
# Epoch 00059 | Time(s) 0.0053 | Loss 0.6702 | TrainAcc 0.7357 | ValAcc 0.7700 | ETputs(KTEPS) 1991.98
# Epoch 00060 | Time(s) 0.0053 | Loss 0.7216 | TrainAcc 0.6857 | ValAcc 0.7700 | ETputs(KTEPS) 1998.30
# Epoch 00061 | Time(s) 0.0053 | Loss 0.6909 | TrainAcc 0.6929 | ValAcc 0.7640 | ETputs(KTEPS) 2004.25
# Epoch 00062 | Time(s) 0.0053 | Loss 0.8177 | TrainAcc 0.7071 | ValAcc 0.7600 | ETputs(KTEPS) 2010.05
# Epoch 00063 | Time(s) 0.0052 | Loss 0.5448 | TrainAcc 0.7714 | ValAcc 0.7580 | ETputs(KTEPS) 2015.63
# Epoch 00064 | Time(s) 0.0052 | Loss 0.7193 | TrainAcc 0.7071 | ValAcc 0.7600 | ETputs(KTEPS) 2021.17
# Epoch 00065 | Time(s) 0.0052 | Loss 0.6896 | TrainAcc 0.7357 | ValAcc 0.7620 | ETputs(KTEPS) 2026.69
# Epoch 00066 | Time(s) 0.0052 | Loss 0.7369 | TrainAcc 0.7000 | ValAcc 0.7580 | ETputs(KTEPS) 2032.36
# Epoch 00067 | Time(s) 0.0052 | Loss 0.6662 | TrainAcc 0.7071 | ValAcc 0.7500 | ETputs(KTEPS) 2037.83
# Epoch 00068 | Time(s) 0.0052 | Loss 0.7621 | TrainAcc 0.7000 | ValAcc 0.7500 | ETputs(KTEPS) 2043.27
# Epoch 00069 | Time(s) 0.0052 | Loss 0.7995 | TrainAcc 0.7071 | ValAcc 0.7520 | ETputs(KTEPS) 2048.60
# Epoch 00070 | Time(s) 0.0051 | Loss 0.5627 | TrainAcc 0.7714 | ValAcc 0.7500 | ETputs(KTEPS) 2053.78
# Epoch 00071 | Time(s) 0.0051 | Loss 0.6364 | TrainAcc 0.7429 | ValAcc 0.7500 | ETputs(KTEPS) 2058.86
# Epoch 00072 | Time(s) 0.0051 | Loss 0.8600 | TrainAcc 0.6143 | ValAcc 0.7460 | ETputs(KTEPS) 2063.90
# Epoch 00073 | Time(s) 0.0051 | Loss 0.8003 | TrainAcc 0.6929 | ValAcc 0.7460 | ETputs(KTEPS) 2068.70
# Epoch 00074 | Time(s) 0.0051 | Loss 0.7840 | TrainAcc 0.6786 | ValAcc 0.7440 | ETputs(KTEPS) 2073.50
# Epoch 00075 | Time(s) 0.0051 | Loss 0.6445 | TrainAcc 0.7214 | ValAcc 0.7460 | ETputs(KTEPS) 2078.07
# Epoch 00076 | Time(s) 0.0051 | Loss 0.6263 | TrainAcc 0.7500 | ValAcc 0.7460 | ETputs(KTEPS) 2082.55
# Epoch 00077 | Time(s) 0.0051 | Loss 0.7634 | TrainAcc 0.6500 | ValAcc 0.7480 | ETputs(KTEPS) 2087.04
# Epoch 00078 | Time(s) 0.0051 | Loss 0.7931 | TrainAcc 0.6500 | ValAcc 0.7500 | ETputs(KTEPS) 2087.94
# Epoch 00079 | Time(s) 0.0050 | Loss 0.8038 | TrainAcc 0.6643 | ValAcc 0.7540 | ETputs(KTEPS) 2091.43
# Epoch 00080 | Time(s) 0.0050 | Loss 0.7772 | TrainAcc 0.6786 | ValAcc 0.7560 | ETputs(KTEPS) 2095.85
# Epoch 00081 | Time(s) 0.0050 | Loss 0.6810 | TrainAcc 0.7357 | ValAcc 0.7580 | ETputs(KTEPS) 2099.54
# Epoch 00082 | Time(s) 0.0050 | Loss 0.7662 | TrainAcc 0.6857 | ValAcc 0.7600 | ETputs(KTEPS) 2103.17
# Epoch 00083 | Time(s) 0.0050 | Loss 0.8024 | TrainAcc 0.6643 | ValAcc 0.7580 | ETputs(KTEPS) 2106.76
# Epoch 00084 | Time(s) 0.0050 | Loss 0.7990 | TrainAcc 0.6714 | ValAcc 0.7600 | ETputs(KTEPS) 2110.30
# Epoch 00085 | Time(s) 0.0050 | Loss 0.7656 | TrainAcc 0.6714 | ValAcc 0.7600 | ETputs(KTEPS) 2113.81
# Epoch 00086 | Time(s) 0.0050 | Loss 0.5694 | TrainAcc 0.7786 | ValAcc 0.7600 | ETputs(KTEPS) 2117.18
# Epoch 00087 | Time(s) 0.0050 | Loss 0.8255 | TrainAcc 0.6571 | ValAcc 0.7580 | ETputs(KTEPS) 2120.43
# Epoch 00088 | Time(s) 0.0050 | Loss 0.6421 | TrainAcc 0.7429 | ValAcc 0.7520 | ETputs(KTEPS) 2123.61
# Epoch 00089 | Time(s) 0.0050 | Loss 0.5842 | TrainAcc 0.7357 | ValAcc 0.7520 | ETputs(KTEPS) 2126.77
# Epoch 00090 | Time(s) 0.0050 | Loss 0.7384 | TrainAcc 0.6929 | ValAcc 0.7500 | ETputs(KTEPS) 2129.92
# Epoch 00091 | Time(s) 0.0049 | Loss 0.5923 | TrainAcc 0.7500 | ValAcc 0.7500 | ETputs(KTEPS) 2132.98
# Epoch 00092 | Time(s) 0.0049 | Loss 0.6910 | TrainAcc 0.7071 | ValAcc 0.7480 | ETputs(KTEPS) 2135.99
# Epoch 00093 | Time(s) 0.0049 | Loss 0.7788 | TrainAcc 0.6500 | ValAcc 0.7460 | ETputs(KTEPS) 2138.90
# Epoch 00094 | Time(s) 0.0049 | Loss 0.6218 | TrainAcc 0.7429 | ValAcc 0.7440 | ETputs(KTEPS) 2141.62
# Epoch 00095 | Time(s) 0.0049 | Loss 0.7855 | TrainAcc 0.6643 | ValAcc 0.7440 | ETputs(KTEPS) 2144.46
# Epoch 00096 | Time(s) 0.0049 | Loss 0.7744 | TrainAcc 0.6571 | ValAcc 0.7440 | ETputs(KTEPS) 2147.06
# Epoch 00097 | Time(s) 0.0049 | Loss 0.6803 | TrainAcc 0.7214 | ValAcc 0.7420 | ETputs(KTEPS) 2149.85
# Epoch 00098 | Time(s) 0.0049 | Loss 0.6686 | TrainAcc 0.7071 | ValAcc 0.7420 | ETputs(KTEPS) 2152.06
# Epoch 00099 | Time(s) 0.0049 | Loss 0.7637 | TrainAcc 0.6714 | ValAcc 0.7420 | ETputs(KTEPS) 2154.82
# Epoch 00100 | Time(s) 0.0049 | Loss 0.6939 | TrainAcc 0.7357 | ValAcc 0.7420 | ETputs(KTEPS) 2155.89
# Epoch 00101 | Time(s) 0.0049 | Loss 0.6576 | TrainAcc 0.6857 | ValAcc 0.7440 | ETputs(KTEPS) 2158.49
# Epoch 00102 | Time(s) 0.0049 | Loss 0.7522 | TrainAcc 0.6857 | ValAcc 0.7460 | ETputs(KTEPS) 2161.03
# Epoch 00103 | Time(s) 0.0049 | Loss 0.7397 | TrainAcc 0.7000 | ValAcc 0.7440 | ETputs(KTEPS) 2163.21
# Epoch 00104 | Time(s) 0.0049 | Loss 0.7523 | TrainAcc 0.6786 | ValAcc 0.7420 | ETputs(KTEPS) 2165.31
# Epoch 00105 | Time(s) 0.0049 | Loss 0.6737 | TrainAcc 0.7143 | ValAcc 0.7460 | ETputs(KTEPS) 2167.93
# Epoch 00106 | Time(s) 0.0049 | Loss 0.6959 | TrainAcc 0.7143 | ValAcc 0.7460 | ETputs(KTEPS) 2170.42
# Epoch 00107 | Time(s) 0.0049 | Loss 0.6475 | TrainAcc 0.7357 | ValAcc 0.7480 | ETputs(KTEPS) 2172.84
# Epoch 00108 | Time(s) 0.0049 | Loss 0.6024 | TrainAcc 0.7214 | ValAcc 0.7460 | ETputs(KTEPS) 2175.29
# Epoch 00109 | Time(s) 0.0048 | Loss 0.6636 | TrainAcc 0.7143 | ValAcc 0.7460 | ETputs(KTEPS) 2177.77
# Epoch 00110 | Time(s) 0.0048 | Loss 0.6697 | TrainAcc 0.7214 | ValAcc 0.7440 | ETputs(KTEPS) 2180.27
# Epoch 00111 | Time(s) 0.0048 | Loss 0.7019 | TrainAcc 0.6857 | ValAcc 0.7440 | ETputs(KTEPS) 2182.17
# Epoch 00112 | Time(s) 0.0048 | Loss 0.7876 | TrainAcc 0.6786 | ValAcc 0.7460 | ETputs(KTEPS) 2183.85
# Epoch 00113 | Time(s) 0.0048 | Loss 0.7781 | TrainAcc 0.6500 | ValAcc 0.7460 | ETputs(KTEPS) 2186.05
# Epoch 00114 | Time(s) 0.0048 | Loss 0.7122 | TrainAcc 0.6786 | ValAcc 0.7460 | ETputs(KTEPS) 2188.37
# Epoch 00115 | Time(s) 0.0048 | Loss 0.8296 | TrainAcc 0.6857 | ValAcc 0.7460 | ETputs(KTEPS) 2190.71
# Epoch 00116 | Time(s) 0.0048 | Loss 0.7940 | TrainAcc 0.7429 | ValAcc 0.7440 | ETputs(KTEPS) 2192.90
# Epoch 00117 | Time(s) 0.0048 | Loss 0.6923 | TrainAcc 0.6857 | ValAcc 0.7420 | ETputs(KTEPS) 2194.95
# Epoch 00118 | Time(s) 0.0048 | Loss 0.8607 | TrainAcc 0.7357 | ValAcc 0.7420 | ETputs(KTEPS) 2197.19
# Epoch 00119 | Time(s) 0.0048 | Loss 0.6805 | TrainAcc 0.7143 | ValAcc 0.7420 | ETputs(KTEPS) 2199.48
# Epoch 00120 | Time(s) 0.0048 | Loss 0.5755 | TrainAcc 0.7357 | ValAcc 0.7400 | ETputs(KTEPS) 2201.67
# Epoch 00121 | Time(s) 0.0048 | Loss 0.7545 | TrainAcc 0.6714 | ValAcc 0.7380 | ETputs(KTEPS) 2200.97
# Epoch 00122 | Time(s) 0.0048 | Loss 0.7833 | TrainAcc 0.6571 | ValAcc 0.7360 | ETputs(KTEPS) 2201.98
# Epoch 00123 | Time(s) 0.0048 | Loss 0.8019 | TrainAcc 0.7214 | ValAcc 0.7400 | ETputs(KTEPS) 2204.37
# Epoch 00124 | Time(s) 0.0048 | Loss 0.6876 | TrainAcc 0.7000 | ValAcc 0.7400 | ETputs(KTEPS) 2205.33
# Epoch 00125 | Time(s) 0.0048 | Loss 0.6738 | TrainAcc 0.7357 | ValAcc 0.7440 | ETputs(KTEPS) 2207.13
# Epoch 00126 | Time(s) 0.0048 | Loss 0.7499 | TrainAcc 0.6786 | ValAcc 0.7420 | ETputs(KTEPS) 2208.87
# Epoch 00127 | Time(s) 0.0048 | Loss 0.6680 | TrainAcc 0.7286 | ValAcc 0.7420 | ETputs(KTEPS) 2210.78
# Epoch 00128 | Time(s) 0.0048 | Loss 0.5798 | TrainAcc 0.7429 | ValAcc 0.7460 | ETputs(KTEPS) 2212.52
# Epoch 00129 | Time(s) 0.0048 | Loss 0.7748 | TrainAcc 0.6643 | ValAcc 0.7480 | ETputs(KTEPS) 2214.24
# Epoch 00130 | Time(s) 0.0048 | Loss 0.6100 | TrainAcc 0.7286 | ValAcc 0.7460 | ETputs(KTEPS) 2215.94
# Epoch 00131 | Time(s) 0.0048 | Loss 0.7952 | TrainAcc 0.6929 | ValAcc 0.7440 | ETputs(KTEPS) 2217.59
# Epoch 00132 | Time(s) 0.0048 | Loss 0.6569 | TrainAcc 0.7214 | ValAcc 0.7460 | ETputs(KTEPS) 2219.33
# Epoch 00133 | Time(s) 0.0048 | Loss 0.5423 | TrainAcc 0.7929 | ValAcc 0.7480 | ETputs(KTEPS) 2221.04
# Epoch 00134 | Time(s) 0.0047 | Loss 0.6263 | TrainAcc 0.7429 | ValAcc 0.7500 | ETputs(KTEPS) 2222.67
# Epoch 00135 | Time(s) 0.0047 | Loss 0.7195 | TrainAcc 0.6786 | ValAcc 0.7540 | ETputs(KTEPS) 2223.98
# Epoch 00136 | Time(s) 0.0047 | Loss 0.6910 | TrainAcc 0.7143 | ValAcc 0.7520 | ETputs(KTEPS) 2224.52
# Epoch 00137 | Time(s) 0.0047 | Loss 0.6588 | TrainAcc 0.7357 | ValAcc 0.7520 | ETputs(KTEPS) 2225.39
# Epoch 00138 | Time(s) 0.0047 | Loss 0.7943 | TrainAcc 0.6786 | ValAcc 0.7520 | ETputs(KTEPS) 2226.29
# Epoch 00139 | Time(s) 0.0047 | Loss 0.7537 | TrainAcc 0.6786 | ValAcc 0.7540 | ETputs(KTEPS) 2226.88
# Epoch 00140 | Time(s) 0.0047 | Loss 0.6214 | TrainAcc 0.7357 | ValAcc 0.7600 | ETputs(KTEPS) 2227.25
# Epoch 00141 | Time(s) 0.0047 | Loss 0.7252 | TrainAcc 0.6929 | ValAcc 0.7560 | ETputs(KTEPS) 2227.69
# Epoch 00142 | Time(s) 0.0047 | Loss 0.6724 | TrainAcc 0.7143 | ValAcc 0.7580 | ETputs(KTEPS) 2227.88
# Epoch 00143 | Time(s) 0.0047 | Loss 0.5459 | TrainAcc 0.7786 | ValAcc 0.7580 | ETputs(KTEPS) 2227.84
# Epoch 00144 | Time(s) 0.0047 | Loss 0.7434 | TrainAcc 0.6786 | ValAcc 0.7560 | ETputs(KTEPS) 2228.27
# Epoch 00145 | Time(s) 0.0047 | Loss 0.7945 | TrainAcc 0.6786 | ValAcc 0.7560 | ETputs(KTEPS) 2228.73
# Epoch 00146 | Time(s) 0.0047 | Loss 0.8002 | TrainAcc 0.6643 | ValAcc 0.7580 | ETputs(KTEPS) 2228.79
# Epoch 00147 | Time(s) 0.0047 | Loss 0.6058 | TrainAcc 0.7357 | ValAcc 0.7560 | ETputs(KTEPS) 2228.86
# Epoch 00148 | Time(s) 0.0047 | Loss 0.6030 | TrainAcc 0.7429 | ValAcc 0.7540 | ETputs(KTEPS) 2228.91
# Epoch 00149 | Time(s) 0.0047 | Loss 0.6443 | TrainAcc 0.7286 | ValAcc 0.7540 | ETputs(KTEPS) 2228.97
# Epoch 00150 | Time(s) 0.0047 | Loss 0.7024 | TrainAcc 0.7214 | ValAcc 0.7540 | ETputs(KTEPS) 2229.13
# Epoch 00151 | Time(s) 0.0047 | Loss 0.5917 | TrainAcc 0.7500 | ValAcc 0.7500 | ETputs(KTEPS) 2229.24
# Epoch 00152 | Time(s) 0.0047 | Loss 0.7764 | TrainAcc 0.6929 | ValAcc 0.7500 | ETputs(KTEPS) 2229.33
# Epoch 00153 | Time(s) 0.0047 | Loss 0.6226 | TrainAcc 0.7429 | ValAcc 0.7500 | ETputs(KTEPS) 2229.47
# Epoch 00154 | Time(s) 0.0047 | Loss 0.7369 | TrainAcc 0.7571 | ValAcc 0.7480 | ETputs(KTEPS) 2229.54
# Epoch 00155 | Time(s) 0.0047 | Loss 0.7676 | TrainAcc 0.6571 | ValAcc 0.7440 | ETputs(KTEPS) 2230.08
# Epoch 00156 | Time(s) 0.0047 | Loss 0.7312 | TrainAcc 0.7000 | ValAcc 0.7440 | ETputs(KTEPS) 2230.82
# Epoch 00157 | Time(s) 0.0047 | Loss 0.7723 | TrainAcc 0.6786 | ValAcc 0.7440 | ETputs(KTEPS) 2231.67
# Epoch 00158 | Time(s) 0.0047 | Loss 0.7668 | TrainAcc 0.6714 | ValAcc 0.7440 | ETputs(KTEPS) 2232.77
# Epoch 00159 | Time(s) 0.0047 | Loss 0.5536 | TrainAcc 0.7714 | ValAcc 0.7460 | ETputs(KTEPS) 2233.95
# Epoch 00160 | Time(s) 0.0047 | Loss 0.6622 | TrainAcc 0.7143 | ValAcc 0.7480 | ETputs(KTEPS) 2235.11
# Epoch 00161 | Time(s) 0.0047 | Loss 0.7271 | TrainAcc 0.7000 | ValAcc 0.7460 | ETputs(KTEPS) 2236.36
# Epoch 00162 | Time(s) 0.0047 | Loss 0.7655 | TrainAcc 0.6714 | ValAcc 0.7480 | ETputs(KTEPS) 2237.73
# Epoch 00163 | Time(s) 0.0047 | Loss 0.6927 | TrainAcc 0.7286 | ValAcc 0.7480 | ETputs(KTEPS) 2237.59
# Epoch 00164 | Time(s) 0.0047 | Loss 0.6800 | TrainAcc 0.7143 | ValAcc 0.7460 | ETputs(KTEPS) 2238.59
# Epoch 00165 | Time(s) 0.0047 | Loss 0.6350 | TrainAcc 0.7071 | ValAcc 0.7420 | ETputs(KTEPS) 2240.48
# Epoch 00166 | Time(s) 0.0047 | Loss 0.6302 | TrainAcc 0.7357 | ValAcc 0.7340 | ETputs(KTEPS) 2241.97
# Epoch 00167 | Time(s) 0.0047 | Loss 0.6765 | TrainAcc 0.6786 | ValAcc 0.7340 | ETputs(KTEPS) 2243.50
# Epoch 00168 | Time(s) 0.0047 | Loss 0.6764 | TrainAcc 0.7214 | ValAcc 0.7300 | ETputs(KTEPS) 2245.03
# Epoch 00169 | Time(s) 0.0047 | Loss 0.7211 | TrainAcc 0.6643 | ValAcc 0.7320 | ETputs(KTEPS) 2246.62
# Epoch 00170 | Time(s) 0.0047 | Loss 0.8489 | TrainAcc 0.6286 | ValAcc 0.7360 | ETputs(KTEPS) 2248.18
# Epoch 00171 | Time(s) 0.0047 | Loss 0.6181 | TrainAcc 0.7643 | ValAcc 0.7360 | ETputs(KTEPS) 2249.69
# Epoch 00172 | Time(s) 0.0047 | Loss 0.7478 | TrainAcc 0.6857 | ValAcc 0.7400 | ETputs(KTEPS) 2251.22
# Epoch 00173 | Time(s) 0.0047 | Loss 0.7338 | TrainAcc 0.7071 | ValAcc 0.7380 | ETputs(KTEPS) 2252.70
# Epoch 00174 | Time(s) 0.0047 | Loss 0.6588 | TrainAcc 0.7071 | ValAcc 0.7360 | ETputs(KTEPS) 2254.17
# Epoch 00175 | Time(s) 0.0047 | Loss 0.5816 | TrainAcc 0.7571 | ValAcc 0.7360 | ETputs(KTEPS) 2255.61
# Epoch 00176 | Time(s) 0.0047 | Loss 0.7922 | TrainAcc 0.7143 | ValAcc 0.7360 | ETputs(KTEPS) 2257.08
# Epoch 00177 | Time(s) 0.0047 | Loss 0.6557 | TrainAcc 0.7214 | ValAcc 0.7380 | ETputs(KTEPS) 2258.52
# Epoch 00178 | Time(s) 0.0047 | Loss 0.8085 | TrainAcc 0.6643 | ValAcc 0.7420 | ETputs(KTEPS) 2259.93
# Epoch 00179 | Time(s) 0.0047 | Loss 0.6598 | TrainAcc 0.6857 | ValAcc 0.7380 | ETputs(KTEPS) 2261.36
# Epoch 00180 | Time(s) 0.0047 | Loss 0.7059 | TrainAcc 0.6714 | ValAcc 0.7360 | ETputs(KTEPS) 2262.76
# Epoch 00181 | Time(s) 0.0047 | Loss 0.7952 | TrainAcc 0.6429 | ValAcc 0.7380 | ETputs(KTEPS) 2264.14
# Epoch 00182 | Time(s) 0.0047 | Loss 0.5452 | TrainAcc 0.7714 | ValAcc 0.7400 | ETputs(KTEPS) 2265.52
# Epoch 00183 | Time(s) 0.0047 | Loss 0.7318 | TrainAcc 0.6786 | ValAcc 0.7440 | ETputs(KTEPS) 2266.86
# Epoch 00184 | Time(s) 0.0047 | Loss 0.6159 | TrainAcc 0.7286 | ValAcc 0.7440 | ETputs(KTEPS) 2268.21
# Epoch 00185 | Time(s) 0.0047 | Loss 0.6481 | TrainAcc 0.7357 | ValAcc 0.7440 | ETputs(KTEPS) 2269.54
# Epoch 00186 | Time(s) 0.0046 | Loss 0.6049 | TrainAcc 0.7357 | ValAcc 0.7420 | ETputs(KTEPS) 2270.40
# Epoch 00187 | Time(s) 0.0046 | Loss 0.6484 | TrainAcc 0.7071 | ValAcc 0.7360 | ETputs(KTEPS) 2271.96
# Epoch 00188 | Time(s) 0.0046 | Loss 0.8576 | TrainAcc 0.6214 | ValAcc 0.7380 | ETputs(KTEPS) 2273.50
# Epoch 00189 | Time(s) 0.0046 | Loss 0.6770 | TrainAcc 0.6929 | ValAcc 0.7360 | ETputs(KTEPS) 2275.03
# Epoch 00190 | Time(s) 0.0046 | Loss 0.6540 | TrainAcc 0.7429 | ValAcc 0.7320 | ETputs(KTEPS) 2276.45
# Epoch 00191 | Time(s) 0.0046 | Loss 0.6595 | TrainAcc 0.7357 | ValAcc 0.7360 | ETputs(KTEPS) 2277.96
# Epoch 00192 | Time(s) 0.0046 | Loss 0.6316 | TrainAcc 0.7357 | ValAcc 0.7360 | ETputs(KTEPS) 2279.42
# Epoch 00193 | Time(s) 0.0046 | Loss 0.8071 | TrainAcc 0.6571 | ValAcc 0.7400 | ETputs(KTEPS) 2280.89
# Epoch 00194 | Time(s) 0.0046 | Loss 0.5579 | TrainAcc 0.7714 | ValAcc 0.7400 | ETputs(KTEPS) 2282.12
# Epoch 00195 | Time(s) 0.0046 | Loss 0.6746 | TrainAcc 0.7214 | ValAcc 0.7400 | ETputs(KTEPS) 2283.34
# Epoch 00196 | Time(s) 0.0046 | Loss 0.6958 | TrainAcc 0.7000 | ValAcc 0.7420 | ETputs(KTEPS) 2284.54
# Epoch 00197 | Time(s) 0.0046 | Loss 0.8593 | TrainAcc 0.6714 | ValAcc 0.7420 | ETputs(KTEPS) 2285.73
# Epoch 00198 | Time(s) 0.0046 | Loss 0.7024 | TrainAcc 0.6857 | ValAcc 0.7460 | ETputs(KTEPS) 2286.89
# Epoch 00199 | Time(s) 0.0046 | Loss 0.5697 | TrainAcc 0.7571 | ValAcc 0.7480 | ETputs(KTEPS) 2288.06
# Cora
# Time per epoch:  0.0046135056018829345

# %% [markdown]
# Test Model Accuracy

# %%
acc, _ = evaluate(model,features, labels, test_mask, loss_fcn)
print("Test Accuracy {:.4f}".format(acc))
# Out:
# Test Accuracy 0.7630

# %% [markdown]
# Calculating Mean and Standard Deviation

# %%
a= [ 0.1765,0.2973,0.2973]
mean_a = np.mean(a)
std_dev_a = np.std(a)
print(mean_a, std_dev_a)
# Out:
# 0.25703333333333334 0.05694566611155664
